# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.decomposition import PCA
import scipy

# %%
ph=1.5574E-4
times=[1,2,3,6,7,9,13,16,21,24,31] 
pxt=[(x) for x in list(range(3,50,1))]
neh=range(1,120)
# path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/liverpool_liver_31_test/"

# %%
all_AAs=['a', 'w', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'p','q', 'r', 's', 't', 'v', 'y']
def charcount(pepSeq):
    res={key: 0 for key in all_AAs}     
    for c in pepSeq.lower():
        if c.isalpha():
            res[c]+=1
    return res

# %%
def getPeptiedsInfo(protien,time):
    print(protien,time)
    peptides=[x.split(f'_{time}_')[0] for x in os.listdir(path) if (protien+".csv" in x)]
    peptides=[x  for x in peptides if 'A' in x]
    peptidesinfo=dict()
    print(len(peptides))
    

    for k in range(len(peptides)):
        print(f"{path}{peptides[k]}_{time}_{protien}.csv")
        data=pd.read_csv(f"{path}{peptides[k]}_{time}_{protien}.csv")
        data["pxt_neh"]=data.NEH*data.pxt
        data=data[["NEH","pxt","RMSE","pxt_neh","T_NEH","NH"]] 
        minval=min(data.RMSE)

        data=data[data.RMSE==minval]

        peptidesinfo[peptides[k]]={"pxt_neh":float(data.pxt_neh),"T_NEH":float(data.T_NEH),"Seq":peptides[k],
                               "charcount":charcount(peptides[k])}
           
    visited=set()
    visited.add(peptides[0].split('_')[1])
    coefficients=[]
    for k in range(0,len(peptides)-1):
        if(peptides[k+1].split('_')[1] in visited):
            continue

        pep1=peptidesinfo[peptides[k]]
        pep2=peptidesinfo[peptides[k+1]]    
        visited.add(peptides[k].split('_')[1])

        r=pep1["pxt_neh"]/pep2["pxt_neh"]
        coefficients.append([pep1["charcount"][c]-r*pep2["charcount"][c] for c in all_AAs])
        
    return peptides,peptidesinfo,all_AAs,np.array(coefficients)

# %%
def compute_result(peptides,peptidesinfo,all_AAs,sol):
    t_neh,e_neh=[],[]
    for i in range (len(peptides)):
        pep1=peptidesinfo[peptides[i]]
        p_neh=0
        for index,c in enumerate(all_AAs): 
            p_neh+=(pep1["charcount"][c]*sol[index]) 
        t_neh.append(pep1["T_NEH"])
        e_neh.append(p_neh)

    res=pd.DataFrame([peptides,t_neh,e_neh])
    res=res.transpose()
    res.columns=["peptides","True_NEH","e_NEH"]
    res["dif"]=abs(res.True_NEH-res.e_NEH)
#     print(np.mean(res.dif),np.median(res.dif),np.std(res.dif))
    return res.sort_values(by='dif')

# %%
time=9
a_val=4
w_val=0.08
# proteins=["CPSM_MOUSE","FAS_MOUSE","DHB4_MOUSE","ASSY_MOUSE","ATPA_MOUSE","ATPB_MOUSE","BHMT1_MOUSE",
#          "CLH1_MOUSE","DHE3_MOUSE","DHSO_MOUSE","ECHA_MOUSE",
#          "G3P_MOUSE","HMCS2_MOUSE","HYES_MOUSE","MYH9_MOUSE","PYC_MOUSE","PYGL_MOUSE","SAHH_MOUSE",
#          "SARDH_MOUSE","SBP1_MOUSE","THIM_MOUSE","TKT_MOUSE"]
# proteins=pd.read_csv("H:/Warehouse/Data/liverpool/liver/6_23_2022_c/"+"Analyzed_Proteins_and_Their_Rates.csv").Proteins.unique()

path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/" 
proteins=np.unique(["_".join(x.split('_')[4:]).replace('.csv','') for x in os.listdir(path) if ("_MOUSE.csv" in x)])

coefficients=np.array([])
_peptides,_peptidesinfo=[],[]
for protine in proteins:
    try:
        peptides1,peptidesinfo1,all_AAs1,coefficients1=getPeptiedsInfo(protine,time) 
        print(protine,len(all_AAs1)==20)
        if(coefficients.shape[0]==0):
            coefficients=coefficients1
        else:
            coefficients=np.concatenate((coefficients1,coefficients), axis=0)
        _peptides.append(peptides1)
        _peptidesinfo.append(peptidesinfo1)
    except:
        continue
    
# sol=list(scipy.optimize.nnls(coefficients[:,2 :],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])
# sol=list(scipy.optimize.nnls(coefficients[:,1:],-a_val*coefficients[:,0])[0])
sol=list(scipy.optimize.nnls(coefficients[:,2:],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])

print("====>",len(sol))
sol.insert(0,a_val) 
sol.insert(1,w_val) 
print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
res=pd.DataFrame()
for i in range(len(proteins)):
    res=pd.concat([res,compute_result(_peptides[i],_peptidesinfo[i],all_AAs1,sol)])

print("\nstats",np.mean(res.dif),np.median(res.dif),np.std(res.dif))
# Out:
# AL1L1_MOUSE 9
# 17
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_ADPLGLEAEKDGVPVFK_3_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AGLILFGNDDR_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DLGEAALNEYLR_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DTNHGPQNHEAHLR_3_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DTNHGPQNHEAHLR_4_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EGATLVcGGNQVPR_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GASAINWTLIHGDKK_3_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GASAINWTLIHGDK_3_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GNDKVPGAWTEAcGQK_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_IAVIGQSLFGQEVYcQLR_3_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_IQGATIPINQAR_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_LQAGTVFVNTYNK_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_PAQVTPLTALK_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_QLFIGGEFVDAEGAK_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_RPQPEEGATYEGIQK_3_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_TDVAAPFGGFK_2_9_AL1L1_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_VPGAWTEAcGQK_2_9_AL1L1_MOUSE.csv
# AL1L1_MOUSE True
# AL3A2_MOUSE 9
# 4
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EILAAIAADLSK_2_9_AL3A2_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EKPLALYVFSR_3_9_AL3A2_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FDHILYTGNTAVGK_3_9_AL3A2_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_YLAPTILTDVDPNSK_2_9_AL3A2_MOUSE.csv
# AL3A2_MOUSE True
# ALDOB_MOUSE 9
# 8
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_ALNDHHVYLEGTLLKPN_3_9_ALDOB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_ALQASALAAWGGK_2_9_ALDOB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_ALQASALAAWGGK_3_9_ALDOB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AMANcQAAQGQYVH_2_9_ALDOB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GILAADESVGTMGNR_2_9_ALDOB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_LDQGGAPLAGTNK_2_9_ALDOB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_SLAIQENANALAR_2_9_ALDOB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_YTPEQVAMATVTALHR_3_9_ALDOB_MOUSE.csv
# ALDOB_MOUSE True
# ASSY_MOUSE 9
# 10
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_APNSPDVLEIEFK_2_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EFVEEFIWPAVQ_2_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EQGYDVIAYLANIGQK_3_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FAELVYTGFWHSPEcEFVR_2_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FAELVYTGFWHSPEcEFVR_3_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FELTcYSLAPQIK_2_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GIYETPAGTILYH_2_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_HAHLDIEAFTMDR_3_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_TTSLELFMYLNEVAGK_2_9_ASSY_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_YLLGTSLARPc_2_9_ASSY_MOUSE.csv
# ASSY_MOUSE True
# ATPA_MOUSE 9
# 15
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AIEEQVAVIYAGVR_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AIEEQVAVIYAGVR_3_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AQFGSDLDAATQQLLSR_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AQFGSDLDAATQQLLSR_3_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EAYPGDVFYLHSR_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EAYPGDVFYLHSR_3_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EAYPGDVFYLH_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GIRPAINVGLSVSR_3_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_HALIIYDDLSK_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_LAPYSGcSMGEYFR_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_LYcIYVAIGQK_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_NVQAEEMVEFSSGLK_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_TGTAEMSSILEER_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_TSIAIDTIINQK_2_9_ATPA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_VVDALGNAIDGK_2_9_ATPA_MOUSE.csv
# ATPA_MOUSE True
# ATPB_MOUSE 9
# 15
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AHGGYSVFAGVGER_2_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AHGGYSVFAGVGER_3_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FLSQPFQVAEVFTGHMGK_3_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FLSQPFQVAEVFTGH_2_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FTQAGSEVSALLGR_2_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FTQAGSEVSALLGR_3_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_IGLFGGAGVGK_2_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_IMDPNIVGNEHYDVAR_3_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_IVGNEHYDVAR_3_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_LVLEVAQHLGESTVR_3_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_QVAEVFTGHMGK_3_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_SLQDIIAILGMDELSEEDK_2_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_VALTGLTVAEYFR_2_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_VALVYGQMNEPPGAR_2_9_ATPB_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_VLDSGAPIKIPVGPETLGR_3_9_ATPB_MOUSE.csv
# ATPB_MOUSE True
# BIP_MOUSE 9
# 8
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DAGTIAGLNVMR_2_9_BIP_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_IINEPTAAAIAYGLDK_2_9_BIP_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_IINEPTAAAIAYGLDK_3_9_BIP_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_NELESYAYSLK_2_9_BIP_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_TFAPEEISAMVLTK_2_9_BIP_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_TFAPEEISAMVLTK_3_9_BIP_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_VTHAVVTVPAYFNDAQR_2_9_BIP_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_VTHAVVTVPAYFNDAQR_3_9_BIP_MOUSE.csv
# BIP_MOUSE True
# CAH3_MOUSE 9
# 11
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EAPFTHFDPScLFPAcR_2_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EAPFTHFDPScLFPAcR_3_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EKGEFQILLDALDK_2_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EKGEFQILLDALDK_3_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EPMTVSSDQMAK_2_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GEFQILLDALDK_2_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_HDPSLQPWSASYDPGSAK_2_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_HDPSLQPWSASYDPGSAK_3_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_QPDGIAVVGIFLK_2_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_SLFSSAENEPPVPLVGN_2_9_CAH3_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_YAAELHLVHWNPK_3_9_CAH3_MOUSE.csv
# CAH3_MOUSE True
# CATA_MOUSE 9
# 11
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_ASQRPDVLTTGGGNPIGDK_2_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_ASQRPDVLTTGGGNPIGDK_3_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FNSANEDNVTQVR_2_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_FSTVTGESGSADTVR_2_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GAGAFGYFEVTHDITR_2_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_GAGAFGYFEVTHDITR_3_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_LAQEDPDYGLR_2_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_LVNADGEAVYcK_2_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_NFTDVHPDYGAR_2_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_SALEHSVQcAVDVK_2_9_CATA_MOUSE.csv
# C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_SALEHSVQcAVDVK_3_9_CATA_MOUSE.csv
# CATA_MOUSE True
# ====> 18
#
# Values
#  a= 4
# w= 0.08
# c= 1.7286997518858398
# d= 2.3019382674355526
# e= 3.3792780559016893
# f= 0.0
# g= 1.1837203190049972
# h= 1.1984777780232492
# i= 0.18318089050899436
# k= 0.0
# l= 0.7584955264120704
# m= 0.22748451810789225
# n= 0.8240007266468743
# p= 1.2453721208321489
# q= 2.3109418897115668
# r= 1.0951319230936751
# s= 1.2504583612379785
# t= 0.40167875271492837
# v= 0.6485530793918306
# y= 0.878622170191585
#
# stats 6.854167648003743 6.528376398464573 2.722740203964522

# %%
print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
# Out:
# Values
#  a= 4
# w= 0.08
# c= 1.7286997518858398
# d= 2.3019382674355526
# e= 3.3792780559016893
# f= 0.0
# g= 1.1837203190049972
# h= 1.1984777780232492
# i= 0.18318089050899436
# k= 0.0
# l= 0.7584955264120704
# m= 0.22748451810789225
# n= 0.8240007266468743
# p= 1.2453721208321489
# q= 2.3109418897115668
# r= 1.0951319230936751
# s= 1.2504583612379785
# t= 0.40167875271492837
# v= 0.6485530793918306
# y= 0.878622170191585

# %%
print("proteins",len(proteins),"peptides",res.shape[0])
# Out:
# proteins 9 peptides 99

# %%
res=res.sort_values(by='dif')
res.head(20)
# Out:
#                peptides True_NEH      e_NEH       dif
# 7       _LVNADGEAVYcK_2     22.0  20.351861  1.648139
# 12     _VALTGLTVAEYFR_2     20.0  18.154207  1.845793
# 6        _EAYPGDVFYLH_2     19.0  16.473079  2.526921
# 14      _VVDALGNAIDGK_2     21.0    18.0341    2.9659
# 15       _TDVAAPFGGFK_2     18.0  14.964983  3.035017
# 5       _GEFQILLDALDK_2     21.0  17.936484  3.063516
# 0       _EILAAIAADLSK_2     28.0  24.815028  3.184972
# 8        _HALIIYDDLSK_2     17.0  13.814788  3.185212
# 12       _PAQVTPLTALK_2     19.0  15.770588  3.229412
# 10       _LYcIYVAIGQK_2     16.0  12.754017  3.245983
# 3        _NELESYAYSLK_2     21.0  17.357709  3.642291
# 2       _DLGEAALNEYLR_2     27.0  23.317456  3.682544
# 2     _EKGEFQILLDALDK_2     25.0  21.315762  3.684238
# 3     _EKGEFQILLDALDK_3     25.0  21.315762  3.684238
# 3    _YLAPTILTDVDPNSK_2     21.0  17.199785  3.800215
# 9        _YLLGTSLARPc_2     18.0   14.05917   3.94083
# 2     _FDHILYTGNTAVGK_3     18.0  13.964067  4.035933
# 11     _LQAGTVFVNTYNK_2     17.0  12.880245  4.119755
# 8   _TTSLELFMYLNEVAGK_2     23.0  18.850239  4.149761
# 1        _AGLILFGNDDR_2     19.0  14.590622  4.409378

# %%
res.tail(20)
# Out:
#                   peptides True_NEH      e_NEH        dif
# 11  _SLQDIIAILGMDELSEEDK_2     39.0  30.091742   8.908258
# 3     _AQFGSDLDAATQQLLSR_3     40.0  30.993637   9.006363
# 2     _AQFGSDLDAATQQLLSR_2     40.0  30.993637   9.006363
# 13      _VALVYGQMNEPPGAR_2     33.0  23.629246   9.370754
# 1     _EAPFTHFDPScLFPAcR_3     35.0  25.578975   9.421025
# 0     _EAPFTHFDPScLFPAcR_2     35.0  25.578975   9.421025
# 7      _IMDPNIVGNEHYDVAR_3     31.0  21.123433   9.876567
# 10         _IQGATIPINQAR_2     29.0   17.92133   11.07867
# 14  _VLDSGAPIKIPVGPETLGR_3     34.0  22.896222  11.103778
# 9     _SLFSSAENEPPVPLVGN_2     35.0  23.891867  11.108133
# 9    _IAVIGQSLFGQEVYcQLR_3     36.0  24.812916  11.187084
# 2    _FLSQPFQVAEVFTGHMGK_3     32.0  20.747676  11.252324
# 14      _RPQPEEGATYEGIQK_3     38.0  26.176517  11.823483
# 6    _HDPSLQPWSASYDPGSAK_2     40.0  27.752084  12.247916
# 7    _HDPSLQPWSASYDPGSAK_3     40.0  27.752084  12.247916
# 0   _ASQRPDVLTTGGGNPIGDK_2     36.0  23.703622  12.296378
# 1   _ASQRPDVLTTGGGNPIGDK_3     36.0  23.703622  12.296378
# 7        _GIRPAINVGLSVSR_3     28.0  15.549958  12.450042
# 3        _DTNHGPQNHEAHLR_3     35.0  21.919992  13.080008
# 4        _DTNHGPQNHEAHLR_4     35.0  21.919992  13.080008

# %%
temp=pd.DataFrame(coefficients)
temp.columns=all_AAs1
temp
# Out:
#            a         w         c         d         e         f         g  \
# 0  -0.358696  0.000000  0.000000  0.641304 -1.358696 -1.358696  4.000000
# 1   0.070707  0.000000  0.000000  0.070707  0.070707  0.070707 -1.858586
# 2  -1.175824  0.000000  0.000000 -0.087912 -0.087912 -1.175824 -1.263736
# 3   0.217143  0.000000  0.000000  0.108571  0.108571  0.217143  0.325714
# 4   0.958333  0.000000  0.000000 -1.083333 -0.041667  2.000000  1.958333
# ..       ...       ...       ...       ...       ...       ...       ...
# 81 -0.927928  0.000000  0.000000  0.000000  0.000000  1.000000  1.000000
# 82  1.000000  0.000000  0.000000 -0.500000 -1.000000 -1.000000 -1.500000
# 83  1.000000  0.000000  0.000000  1.000000 -1.000000  2.000000  1.000000
# 84 -2.894736  0.000000  0.000000 -1.947368  3.000000 -3.894736 -1.894736
# 85  0.642857 -0.678571 -0.678571  1.000000 -0.678571  2.000000  0.642857
#
#            h         i         k         l    m         n         p         q  \
# 0   0.000000  1.000000  1.000000  1.000000  0.0 -3.076087  2.000000 -0.358696
# 1   0.000000  0.000000  0.000000  0.000000  0.0  3.000000  0.000000  1.000000
# 2  -1.087912 -1.087912  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 3   0.108571  0.108571  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 4   1.000000  1.000000  0.000000 -2.083333  0.0  0.000000 -1.041667 -1.041667
# ..       ...       ...       ...       ...  ...       ...       ...       ...
# 81  0.000000  0.000000  0.036036 -0.927928  0.0  2.000000 -1.927928  0.036036
# 82  0.000000 -0.500000  0.500000  1.500000  0.0  0.000000  2.000000  0.500000
# 83  0.000000  0.000000  0.000000  1.000000  0.0  0.000000 -2.000000 -1.000000
# 84  0.000000  1.000000 -0.947368  0.000000  0.0  0.000000  0.052632  2.000000
# 85  0.000000  0.000000  0.321429  0.000000  0.0  0.000000  0.321429 -0.678571
#
#            r         s         t         v         y
# 0  -0.358696 -0.358696  0.641304 -1.717391  0.000000
# 1   0.070707 -1.787878 -1.787878  0.141414  0.000000
# 2  -0.087912  3.000000  0.824176  0.912088 -1.087912
# 3   0.108571  0.000000  0.217143  0.108571  0.108571
# 4  -0.041667  0.000000  2.000000  1.000000 -0.041667
# ..       ...       ...       ...       ...       ...
# 81  0.000000  0.000000  0.072072  1.036036  1.000000
# 82  0.000000  0.000000  2.000000  0.500000  0.000000
# 83 -1.000000  0.000000 -1.000000  1.000000 -1.000000
# 84  1.000000  0.000000 -0.947368 -1.947368  1.000000
# 85  0.000000  0.000000  0.321429  0.321429  0.000000
#
# [86 rows x 20 columns]

# %%
# for c in range( len(coefficients)):
#     print(np.dot(coefficients[c],sol))
