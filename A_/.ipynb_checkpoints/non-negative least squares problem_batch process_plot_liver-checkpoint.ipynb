# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.decomposition import PCA
import scipy

# %%
ph=1.5574E-4
times=[1,2,3,6,7,9,13,16,21,24,31] 
pxt=[(x) for x in list(range(3,50,1))]
neh=range(1,120)
# path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/liverpool_liver_31_test/"

# %%
all_AAs=['a', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'p','q', 'r', 's', 't', 'v', 'w', 'y']
def charcount(pepSeq):
    res={key: 0 for key in all_AAs}     
    for c in pepSeq.lower():
        if c.isalpha():
            res[c]+=1
    return res

# %%
def getPeptiedsInfo(protien,time):
    print(protien,time)
    peptides=[x.split(f'_{time}_')[0] for x in os.listdir(path) if (protien+".csv" in x) and (f"_{time}_" in x)]
    peptides=[x  for x in peptides if 'A' in x]
    peptidesinfo=dict()
    print(len(peptides))
    

    for k in range(len(peptides)): 
        data=pd.read_csv(f"{path}{peptides[k]}_{time}_{protien}.csv")
        data["pxt_neh"]=data.NEH*data.pxt
        data=data[["NEH","pxt","RMSE","pxt_neh","T_NEH","NH"]] 
        minval=min(data.RMSE)

        data=data[data.RMSE==minval]

        peptidesinfo[peptides[k]]={"pxt_neh":float(data.pxt_neh),"T_NEH":float(data.T_NEH),"Seq":peptides[k],
                               "charcount":charcount(peptides[k])}
           
    visited=set()
    visited.add(peptides[0].split('_')[1])
    coefficients=[]
    for k in range(0,len(peptides)-1):
        if(peptides[k+1].split('_')[1] in visited):
            continue

        pep1=peptidesinfo[peptides[k]]
        pep2=peptidesinfo[peptides[k+1]]    
        visited.add(peptides[k].split('_')[1])

        r=pep1["pxt_neh"]/pep2["pxt_neh"]
        coefficients.append([pep1["charcount"][c]-r*pep2["charcount"][c] for c in all_AAs])
        
    return peptides,peptidesinfo,all_AAs,np.array(coefficients)

# %%
def compute_result(peptides,peptidesinfo,all_AAs,sol):
    t_neh,e_neh=[],[]
    for i in range (len(peptides)):
        pep1=peptidesinfo[peptides[i]]
        p_neh=0
        for index,c in enumerate(all_AAs): 
            p_neh+=(pep1["charcount"][c]*sol[index]) 
        t_neh.append(pep1["T_NEH"])
        e_neh.append(p_neh)

    res=pd.DataFrame([peptides,t_neh,e_neh])
    res=res.transpose()
    res.columns=["peptides","True_NEH","e_NEH"]
    res["dif"]=abs(res.True_NEH-res.e_NEH)
#     print(np.mean(res.dif),np.median(res.dif),np.std(res.dif))
    return res.sort_values(by='dif')

# %%
e_vals=[]
for time in times[3:]:
    print(time,"===========================================")
    # time=9
    a_val=4
    # w_val=0.08
    # proteins=["CPSM_MOUSE","FAS_MOUSE","DHB4_MOUSE","ASSY_MOUSE","ATPA_MOUSE","ATPB_MOUSE","BHMT1_MOUSE",
    #          "CLH1_MOUSE","DHE3_MOUSE","DHSO_MOUSE","ECHA_MOUSE",
    #          "G3P_MOUSE","HMCS2_MOUSE","HYES_MOUSE","MYH9_MOUSE","PYC_MOUSE","PYGL_MOUSE","SAHH_MOUSE",
    #          "SARDH_MOUSE","SBP1_MOUSE","THIM_MOUSE","TKT_MOUSE"]
    # proteins=pd.read_csv("H:/Warehouse/Data/liverpool/liver/6_23_2022_c/"+"Analyzed_Proteins_and_Their_Rates.csv").Proteins.unique()

    path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/second_r_liver/" 
    proteins=np.unique(["_".join(x.split('_')[4:]).replace('.csv','') for x in os.listdir(path) if ("_MOUSE.csv" in x)])

    coefficients=np.array([])
    _peptides,_peptidesinfo=[],[]
    for protine in proteins:
        try:
            peptides1,peptidesinfo1,all_AAs1,coefficients1=getPeptiedsInfo(protine,time) 
            print(protine,len(all_AAs1)==20)
            if(coefficients.shape[0]==0):
                coefficients=coefficients1
            else:
                coefficients=np.concatenate((coefficients1,coefficients), axis=0)
            _peptides.append(peptides1)
            _peptidesinfo.append(peptidesinfo1)
        except:
            continue

    # sol=list(scipy.optimize.nnls(coefficients[:,2 :],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])
    sol=list(scipy.optimize.nnls(coefficients[:,1:],-a_val*coefficients[:,0])[0])
    # sol=list(scipy.optimize.nnls(coefficients[:,2:],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])

    print("====>",len(sol))
    sol.insert(0,a_val) 
    # sol.insert(1,w_val) 
    print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
    res=pd.DataFrame()
    for i in range(len(proteins)):
        res=pd.concat([res,compute_result(_peptides[i],_peptidesinfo[i],all_AAs1,sol)])

    print("\nstats",np.mean(res.dif),np.median(res.dif),np.std(res.dif))    
    
    e_vals.append(sol)
# Out:
# 6 ===========================================
# AL1L1_MOUSE 6
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 6
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 6
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 6
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 6
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 6
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 6
# 15
# ATPB_MOUSE True
# BIP_MOUSE 6
# 8
# BIP_MOUSE True
# CAH3_MOUSE 6
# 11
# CAH3_MOUSE True
# CATA_MOUSE 6
# 11
# CATA_MOUSE True
# CPSM_MOUSE 6
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 6
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 6
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 6
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 6
# 9
# ECHA_MOUSE True
# EF2_MOUSE 6
# 5
# EF2_MOUSE True
# ENOA_MOUSE 6
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 6
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 6
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 6
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 6
# 7
# FAAA_MOUSE True
# FAS_MOUSE 6
# 13
# FAS_MOUSE True
# GRP75_MOUSE 6
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 6
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 6
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 6
# 8
# PGM1_MOUSE True
# PYC_MOUSE 6
# 9
# PYC_MOUSE True
# PYGL_MOUSE 6
# 8
# PYGL_MOUSE True
# RGN_MOUSE 6
# 6
# RGN_MOUSE True
# SAHH_MOUSE 6
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 6
# 8
# SARDH_MOUSE True
# THIL_MOUSE 6
# 7
# THIL_MOUSE True
# THIM_MOUSE 6
# 6
# THIM_MOUSE True
# UD11_MOUSE 6
# 5
# UD11_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.1100360921581676
# d= 2.018395947086133
# e= 2.881721525042378
# f= 0.0
# g= 0.9995206915587188
# h= 0.6516377602690183
# i= 0.0349431648438513
# k= 0.0
# l= 0.4996063462216525
# m= 0.0
# n= 0.4175804505139494
# p= 0.9952412018644337
# q= 2.4536535083832955
# r= 0.8556870446628544
# s= 0.9361801252451204
# t= 0.0
# v= 0.21123480675362888
# w= 0.0
# y= 0.4946496435332254
#
# stats 10.221063954754207 9.913574393521856 3.09471491212889
# 7 ===========================================
# AL1L1_MOUSE 7
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 7
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 7
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 7
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 7
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 7
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 7
# 15
# ATPB_MOUSE True
# BIP_MOUSE 7
# 8
# BIP_MOUSE True
# CAH3_MOUSE 7
# 11
# CAH3_MOUSE True
# CATA_MOUSE 7
# 11
# CATA_MOUSE True
# CPSM_MOUSE 7
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 7
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 7
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 7
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 7
# 9
# ECHA_MOUSE True
# EF2_MOUSE 7
# 5
# EF2_MOUSE True
# ENOA_MOUSE 7
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 7
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 7
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 7
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 7
# 7
# FAAA_MOUSE True
# FAS_MOUSE 7
# 13
# FAS_MOUSE True
# GRP75_MOUSE 7
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 7
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 7
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 7
# 8
# PGM1_MOUSE True
# PYC_MOUSE 7
# 9
# PYC_MOUSE True
# PYGL_MOUSE 7
# 8
# PYGL_MOUSE True
# RGN_MOUSE 7
# 6
# RGN_MOUSE True
# SAHH_MOUSE 7
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 7
# 8
# SARDH_MOUSE True
# THIL_MOUSE 7
# 7
# THIL_MOUSE True
# THIM_MOUSE 7
# 6
# THIM_MOUSE True
# UD11_MOUSE 7
# 5
# UD11_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.4185156179108638
# d= 1.8874169201551945
# e= 3.0651266371692594
# f= 0.18901741194703411
# g= 1.1170033492678828
# h= 1.1580044324133494
# i= 0.062249896037064614
# k= 0.0
# l= 0.47605576660826493
# m= 0.0
# n= 0.48189590175131175
# p= 1.216406617943642
# q= 2.851440501994958
# r= 1.2225745690982086
# s= 0.9482058691806992
# t= 0.0
# v= 0.29621425885856567
# w= 0.0
# y= 0.48256694235745023
#
# stats 8.969841123053172 8.52954950377302 2.7440289637090505
# 9 ===========================================
# AL1L1_MOUSE 9
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 9
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 9
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 9
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 9
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 9
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 9
# 15
# ATPB_MOUSE True
# BIP_MOUSE 9
# 8
# BIP_MOUSE True
# CAH3_MOUSE 9
# 11
# CAH3_MOUSE True
# CATA_MOUSE 9
# 11
# CATA_MOUSE True
# CPSM_MOUSE 9
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 9
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 9
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 9
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 9
# 9
# ECHA_MOUSE True
# EF2_MOUSE 9
# 5
# EF2_MOUSE True
# ENOA_MOUSE 9
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 9
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 9
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 9
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 9
# 7
# FAAA_MOUSE True
# FAS_MOUSE 9
# 13
# FAS_MOUSE True
# GRP75_MOUSE 9
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 9
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 9
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 9
# 8
# PGM1_MOUSE True
# PYC_MOUSE 9
# 9
# PYC_MOUSE True
# PYGL_MOUSE 9
# 8
# PYGL_MOUSE True
# RGN_MOUSE 9
# 6
# RGN_MOUSE True
# SAHH_MOUSE 9
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 9
# 8
# SARDH_MOUSE True
# THIL_MOUSE 9
# 7
# THIL_MOUSE True
# THIM_MOUSE 9
# 6
# THIM_MOUSE True
# UD11_MOUSE 9
# 5
# UD11_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.5427433099500676
# d= 2.0749085196986417
# e= 3.146998616003763
# f= 0.014630972588260677
# g= 1.07860709210146
# h= 1.0289457458082156
# i= 0.09508677058276216
# k= 0.0
# l= 0.5701886261132744
# m= 0.0
# n= 0.6280293023206904
# p= 1.3484081328471118
# q= 2.754042261597727
# r= 1.1445131558983541
# s= 1.1580434780466733
# t= 0.10964215084903314
# v= 0.4500330407899682
# w= 0.07509800498138733
# y= 0.35266923932264815
#
# stats 8.297625896252272 8.174633275846737 2.6182662455408536
# 13 ===========================================
# AL1L1_MOUSE 13
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 13
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 13
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 13
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 13
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 13
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 13
# 15
# ATPB_MOUSE True
# BIP_MOUSE 13
# 8
# BIP_MOUSE True
# CAH3_MOUSE 13
# 11
# CAH3_MOUSE True
# CATA_MOUSE 13
# 11
# CATA_MOUSE True
# CPSM_MOUSE 13
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 13
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 13
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 13
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 13
# 9
# ECHA_MOUSE True
# EF2_MOUSE 13
# 5
# EF2_MOUSE True
# ENOA_MOUSE 13
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 13
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 13
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 13
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 13
# 7
# FAAA_MOUSE True
# FAS_MOUSE 13
# 13
# FAS_MOUSE True
# GRP75_MOUSE 13
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 13
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 13
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 13
# 8
# PGM1_MOUSE True
# PYC_MOUSE 13
# 9
# PYC_MOUSE True
# PYGL_MOUSE 13
# 8
# PYGL_MOUSE True
# RGN_MOUSE 13
# 6
# RGN_MOUSE True
# SAHH_MOUSE 13
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 13
# 8
# SARDH_MOUSE True
# THIL_MOUSE 13
# 7
# THIL_MOUSE True
# THIM_MOUSE 13
# 6
# THIM_MOUSE True
# UD11_MOUSE 13
# 5
# UD11_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.4629837839296491
# d= 2.170096060088756
# e= 3.3232998974335604
# f= 0.24446123952443768
# g= 1.175731171736365
# h= 1.148571675034401
# i= 0.24374277460859098
# k= 0.0
# l= 0.6123112172704231
# m= 0.0
# n= 0.39338579786652816
# p= 1.1225479475359494
# q= 3.129040483751832
# r= 1.5941014410617693
# s= 1.2377773209577267
# t= 0.12955569533958367
# v= 0.46802991520316173
# w= 0.0
# y= 0.6267036608926329
#
# stats 7.2556144115285575 6.927102323795417 2.5560681245230303
# 16 ===========================================
# AL1L1_MOUSE 16
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 16
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 16
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 16
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 16
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 16
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 16
# 15
# ATPB_MOUSE True
# BIP_MOUSE 16
# 8
# BIP_MOUSE True
# CAH3_MOUSE 16
# 11
# CAH3_MOUSE True
# CATA_MOUSE 16
# 11
# CATA_MOUSE True
# CPSM_MOUSE 16
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 16
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 16
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 16
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 16
# 9
# ECHA_MOUSE True
# EF2_MOUSE 16
# 5
# EF2_MOUSE True
# ENOA_MOUSE 16
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 16
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 16
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 16
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 16
# 7
# FAAA_MOUSE True
# FAS_MOUSE 16
# 13
# FAS_MOUSE True
# GRP75_MOUSE 16
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 16
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 16
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 16
# 8
# PGM1_MOUSE True
# PYC_MOUSE 16
# 9
# PYC_MOUSE True
# PYGL_MOUSE 16
# 8
# PYGL_MOUSE True
# RGN_MOUSE 16
# 6
# RGN_MOUSE True
# SAHH_MOUSE 16
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 16
# 8
# SARDH_MOUSE True
# THIL_MOUSE 16
# 7
# THIL_MOUSE True
# THIM_MOUSE 16
# 6
# THIM_MOUSE True
# UD11_MOUSE 16
# 5
# UD11_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.3541213197282913
# d= 2.1551349804432847
# e= 3.450970389072667
# f= 0.19704495706939457
# g= 1.1660821085620343
# h= 1.4005368945275458
# i= 0.3043682917858334
# k= 0.0
# l= 0.5783609345935394
# m= 0.18143047680252172
# n= 0.6982887098600254
# p= 1.3665826500864429
# q= 3.111195121839147
# r= 1.6892797170069525
# s= 1.3659264957964437
# t= 0.1895640516893036
# v= 0.5827076592951392
# w= 0.0
# y= 0.6558649867359455
#
# stats 6.369987597724269 6.016113241872095 2.267173044073467
# 21 ===========================================
# AL1L1_MOUSE 21
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 21
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 21
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 21
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 21
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 21
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 21
# 15
# ATPB_MOUSE True
# BIP_MOUSE 21
# 8
# BIP_MOUSE True
# CAH3_MOUSE 21
# 11
# CAH3_MOUSE True
# CATA_MOUSE 21
# 11
# CATA_MOUSE True
# CPSM_MOUSE 21
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 21
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 21
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 21
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 21
# 9
# ECHA_MOUSE True
# EF2_MOUSE 21
# 5
# EF2_MOUSE True
# ENOA_MOUSE 21
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 21
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 21
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 21
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 21
# 7
# FAAA_MOUSE True
# FAS_MOUSE 21
# 13
# FAS_MOUSE True
# GRP75_MOUSE 21
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 21
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 21
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 21
# 8
# PGM1_MOUSE True
# PYC_MOUSE 21
# 9
# PYC_MOUSE True
# PYGL_MOUSE 21
# 8
# PYGL_MOUSE True
# RGN_MOUSE 21
# 6
# RGN_MOUSE True
# SAHH_MOUSE 21
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 21
# 8
# SARDH_MOUSE True
# THIL_MOUSE 21
# 7
# THIL_MOUSE True
# THIM_MOUSE 21
# 6
# THIM_MOUSE True
# UD11_MOUSE 21
# 5
# UD11_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.6992359304248084
# d= 2.3466973448690607
# e= 3.549909030422447
# f= 0.2648074760245357
# g= 1.4097928979580674
# h= 1.4228484211177936
# i= 0.29552163424504135
# k= 0.0
# l= 0.7145754465505568
# m= 0.0
# n= 0.8319125457099316
# p= 1.5276452223912598
# q= 3.370976368625984
# r= 1.5035460885256282
# s= 1.3570689565118506
# t= 0.10807835804209548
# v= 0.4873977859931231
# w= 0.0
# y= 0.7782560418857746
#
# stats 5.490329996857264 5.2475429918449095 2.195411985758049
# 24 ===========================================
# AL1L1_MOUSE 24
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 24
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 24
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 24
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 24
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 24
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 24
# 15
# ATPB_MOUSE True
# BIP_MOUSE 24
# 8
# BIP_MOUSE True
# CAH3_MOUSE 24
# 11
# CAH3_MOUSE True
# CATA_MOUSE 24
# 11
# CATA_MOUSE True
# CPSM_MOUSE 24
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 24
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 24
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 24
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 24
# 9
# ECHA_MOUSE True
# EF2_MOUSE 24
# 5
# EF2_MOUSE True
# ENOA_MOUSE 24
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 24
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 24
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 24
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 24
# 7
# FAAA_MOUSE True
# FAS_MOUSE 24
# 13
# FAS_MOUSE True
# GRP75_MOUSE 24
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 24
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 24
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 24
# 8
# PGM1_MOUSE True
# PYC_MOUSE 24
# 9
# PYC_MOUSE True
# PYGL_MOUSE 24
# 8
# PYGL_MOUSE True
# RGN_MOUSE 24
# 6
# RGN_MOUSE True
# SAHH_MOUSE 24
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 24
# 8
# SARDH_MOUSE True
# THIL_MOUSE 24
# 7
# THIL_MOUSE True
# THIM_MOUSE 24
# 6
# THIM_MOUSE True
# UD11_MOUSE 24
# 5
# UD11_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.5345138434773016
# d= 2.2180037510042694
# e= 3.3826345864772422
# f= 0.0493537123154508
# g= 1.2009191221446749
# h= 1.286629639113298
# i= 0.33468531230308796
# k= 0.0
# l= 0.801222553315097
# m= 0.23178869654297898
# n= 0.6343274945431013
# p= 1.377621393847424
# q= 3.201434444894661
# r= 1.6051868430894853
# s= 1.425663449763935
# t= 0.2740469162554747
# v= 0.6008187071122703
# w= 0.0
# y= 0.6000917283567047
#
# stats 6.030304333345836 5.813614651888681 2.293122868221468
# 31 ===========================================
# AL1L1_MOUSE 31
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 31
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 31
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 31
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 31
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 31
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 31
# 15
# ATPB_MOUSE True
# BIP_MOUSE 31
# 8
# BIP_MOUSE True
# CAH3_MOUSE 31
# 11
# CAH3_MOUSE True
# CATA_MOUSE 31
# 11
# CATA_MOUSE True
# CPSM_MOUSE 31
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 31
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 31
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 31
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 31
# 9
# ECHA_MOUSE True
# EF2_MOUSE 31
# 5
# EF2_MOUSE True
# ENOA_MOUSE 31
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 31
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 31
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 31
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 31
# 7
# FAAA_MOUSE True
# FAS_MOUSE 31
# 13
# FAS_MOUSE True
# GRP75_MOUSE 31
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 31
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 31
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 31
# 8
# PGM1_MOUSE True
# PYC_MOUSE 31
# 9
# PYC_MOUSE True
# PYGL_MOUSE 31
# 8
# PYGL_MOUSE True
# RGN_MOUSE 31
# 6
# RGN_MOUSE True
# SAHH_MOUSE 31
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 31
# 8
# SARDH_MOUSE True
# THIL_MOUSE 31
# 7
# THIL_MOUSE True
# THIM_MOUSE 31
# 6
# THIM_MOUSE True
# UD11_MOUSE 31
# 5
# UD11_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.1282459316154736
# d= 2.6674705622557777
# e= 3.7597801605656342
# f= 0.49662351406861877
# g= 1.3967272903048282
# h= 1.4168859894889176
# i= 0.455311641016075
# k= 0.0
# l= 0.5720292517011081
# m= 0.227711376015092
# n= 1.0544016045468196
# p= 1.907855498505004
# q= 3.550434735236768
# r= 1.8656758472232047
# s= 1.5881519572236626
# t= 0.0
# v= 0.6974677815552851
# w= 0.03905070578495089
# y= 0.9688996338613218
#
# stats 3.919546025840687 3.6364461100231438 1.913530840538735

# %%
evals2=np.array(e_vals)
trueval=[4.0,1.62,1.89,3.95,0.32,2.06,2.88,1.0,0.6,0.54,1.12,1.89,2.59,3.95,3.43,2.61,0.2,0.56,0.08,0.42]

# %%
for i in range(len(all_AAs1)):
    plt.scatter(range(8),evals2[:,i],c='k')
    plt.xticks(np.arange(8), times[3:])
    plt.title(all_AAs1[i]+f" ({trueval[i]})"+f"      t=31: ({evals2[:,i][-1]})")
#     plt.hlines(y=trueval[i],xmin=0,xmax=8)
    plt.show()

# %%
print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
# Out:
# Values
#  a= 4
# c= 1.1282459316154736
# d= 2.6674705622557777
# e= 3.7597801605656342
# f= 0.49662351406861877
# g= 1.3967272903048282
# h= 1.4168859894889176
# i= 0.455311641016075
# k= 0.0
# l= 0.5720292517011081
# m= 0.227711376015092
# n= 1.0544016045468196
# p= 1.907855498505004
# q= 3.550434735236768
# r= 1.8656758472232047
# s= 1.5881519572236626
# t= 0.0
# v= 0.6974677815552851
# w= 0.03905070578495089
# y= 0.9688996338613218

# %%
print("proteins",len(proteins),"peptides",res.shape[0])
# Out:
# proteins 34 peptides 303

# %%
res=res.sort_values(by='dif')
res.head(20)
# Out:
#                  peptides True_NEH      e_NEH       dif
# 6          _EAYPGDVFYLH_2     19.0  18.852639  0.147361
# 7        _YDYEEVEAEGANK_2     31.0  30.792987  0.207013
# 5         _GEFQILLDALDK_2     21.0  20.709906  0.290094
# 1          _DYYFALAHTVR_3     18.0  17.653952  0.346048
# 4         _VAVVAGYGDVGK_2     19.0  18.616423  0.383577
# 1   _DILQDVLDADLSNEAFPF_2     34.0   34.39262   0.39262
# 2       _EKGEFQILLDALDK_2     25.0  24.469686  0.530314
# 3       _EKGEFQILLDALDK_3     25.0  24.469686  0.530314
# 8       _TIEYLEEVAVNFAK_3     25.0  24.221542  0.778458
# 5         _VFDYSEYWEGAR_2     23.0  22.208527  0.791473
# 1         _DSVVAGFQWATK_2     20.0  19.133394  0.866606
# 2        _EGIPALDNFLDKL_2     21.0  20.121729  0.878271
# 0      _ADMVIEAVFEDLGVK_2     27.0  26.095308  0.904692
# 1      _ADMVIEAVFEDLGVK_3     27.0  26.095308  0.904692
# 15         _TDVAAPFGGFK_2     18.0  17.059495  0.940505
# 6      _VLVGANFEEVAFDEK_2     29.0   28.05562   0.94438
# 12       _VALTGLTVAEYFR_2     20.0  19.026701  0.973299
# 0        _ADFAQAcQDAGVR_2     35.0  34.020551  0.979449
# 6      _QEYFVVAATLQDVIR_2     29.0  27.979063  1.020937
# 3         _DFDPAINEYLQR_3     25.0  23.965953  1.034047

# %%
res.tail(20)
# Out:
#                   peptides True_NEH      e_NEH       dif
# 1      _APSSSSVGISEWLDQK_2     34.0  26.986887  7.013113
# 1      _GHEVVVIAPEASIHIK_3     34.0  26.704405  7.295595
# 2      _GHEVVVIAPEASIHIK_4     34.0  26.704405  7.295595
# 12    _WLSTSIPEAQWQSSLAR_2     38.0   30.66426   7.33574
# 1   _ASQRPDVLTTGGGNPIGDK_3     36.0  28.521034  7.478966
# 0   _ASQRPDVLTTGGGNPIGDK_2     36.0  28.521034  7.478966
# 7     _HIGSSVEFDWcAVSSIR_3     33.0  25.428627  7.571373
# 4    _LFDHPEVPTPPESASVSR_3     40.0  32.329059  7.670941
# 8     _HLGIVGEcNIQFALHPT_3     32.0  24.276718  7.723282
# 5       _MRPDNSKPPVYGAcR_2     31.0  23.183994  7.816006
# 1    _ENALLPNWLHLPVGYHGR_4     33.0  25.170732  7.829268
# 2    _GTSFEAAATSGGSASSEK_2     44.0  36.147125  7.852875
# 3    _GTSFEAAATSGGSASSEK_3     44.0  36.147125  7.852875
# 3     _GNAGQTNYGFANSTMER_2     36.0  27.810664  8.189336
# 8   _QGIQVLVSTSNVSSLEGAR_2     39.0  30.618563  8.381437
# 7        _GIRPAINVGLSVSR_3     28.0  19.540955  8.459045
# 2        _HLMESPANEMTPTR_3     31.0  22.287839  8.712161
# 1        _HLMESPANEMTPTR_2     31.0  22.287839  8.712161
# 3        _DTNHGPQNHEAHLR_3     35.0  26.079435  8.920565
# 4        _DTNHGPQNHEAHLR_4     35.0  26.079435  8.920565

# %%
temp=pd.DataFrame(coefficients)
temp.columns=all_AAs1
temp
# Out:
#             a        c         d         e         f         g         h  \
# 0   -0.960000  0.00000  1.000000 -0.960000  0.000000 -0.980000 -1.960000
# 1    0.163265  0.00000  0.000000  0.163265  0.000000  0.081633  0.163265
# 2    0.333333  0.00000 -1.666667  2.000000 -3.333333  1.000000  2.000000
# 3    0.265000  0.00000  1.000000 -0.735000  2.000000 -0.735000  0.000000
# 4   -2.272727  0.00000  2.000000 -0.090909  0.000000 -0.090909  1.000000
# ..        ...      ...       ...       ...       ...       ...       ...
# 255 -0.846154  0.00000  0.000000  0.000000  1.000000  1.000000  0.000000
# 256  0.916666  0.00000 -0.541667 -1.083334 -1.083334 -1.625001  0.000000
# 257  1.104373  0.00000  1.000000 -0.686880  2.000000  1.208746  0.000000
# 258 -3.224135  0.00000 -2.112067  3.000000 -4.224135 -2.224135  0.000000
# 259  0.642140 -0.67893  1.000000 -0.678930  2.000000  0.642140  0.000000
#
#             i         k         l         m         n         p         q  \
# 0   -1.940000 -0.980000  3.000000  1.000000  0.000000  0.020000  1.000000
# 1    0.244898  0.081633  0.000000  0.000000  0.000000  0.081633  0.000000
# 2    3.000000  1.000000 -3.333333  0.000000 -1.666667  1.000000 -1.666667
# 3   -0.735000 -0.735000  0.530000  0.000000  1.000000 -0.735000  0.265000
# 4    0.000000 -0.090909  0.818182 -2.181818 -1.090909 -1.090909  1.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 255  0.000000  0.076923 -0.846154  0.000000  2.000000 -1.846154  0.076923
# 256 -0.541667  0.458333  1.458333  0.000000  0.000000  2.000000  0.458333
# 257  0.104373  0.104373  1.000000  0.000000  0.000000 -1.791254 -0.791254
# 258  1.000000 -1.112067  0.000000  0.000000  0.000000 -0.112067  2.000000
# 259  0.000000  0.321070  0.000000  0.000000  0.000000  0.321070 -0.678930
#
#             r         s         t         v        w         y
# 0    1.000000  1.020000  1.000000 -0.940000  1.00000  0.000000
# 1    0.000000  0.081633  0.000000  0.244898  0.00000  0.000000
# 2   -1.666667 -0.666667 -1.666667  3.000000  0.00000  0.000000
# 3    1.000000 -0.470000  0.265000 -1.470000  0.00000 -1.470000
# 4    0.000000  0.000000  0.909091  1.000000  1.00000  0.000000
# ..        ...       ...       ...       ...      ...       ...
# 255  0.000000  0.000000  0.153846  1.076923  0.00000  1.000000
# 256  0.000000  0.000000  2.000000  0.458333  0.00000  0.000000
# 257 -0.895627  0.000000 -0.895627  1.000000  0.00000 -0.895627
# 258  1.000000  0.000000 -1.112067 -2.112067  0.00000  1.000000
# 259  0.000000  0.000000  0.321070  0.321070 -0.67893  0.000000
#
# [260 rows x 20 columns]

# %%
# for c in range( len(coefficients)):
#     print(np.dot(coefficients[c],sol))
