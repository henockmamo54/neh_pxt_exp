# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.decomposition import PCA
import scipy

# %%
ph=1.5574E-4
times=[1,2,3,6,7,9,13,16,21,24,31] 
pxt=[(x) for x in list(range(3,50,1))]
neh=range(1,120)
# path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/liverpool_liver_31_test/"

# %%
all_AAs=['a', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'p','q', 'r', 's', 't', 'v', 'w', 'y']
def charcount(pepSeq):
    res={key: 0 for key in all_AAs}     
    for c in pepSeq.lower():
        if c.isalpha():
            res[c]+=1
    return res

# %%
def sort_pep(peptidesinfo,peptides):
    temp={p: peptidesinfo[p]["T_NEH"] for i,p in enumerate(peptides)}
    temp=dict(sorted(temp.items(), key=lambda item: item[1])) 
    return list(temp.keys())

# %%
def getPeptiedsInfo(protien,time):
    print(protien,time)
    peptides=[x.split(f'_{time}_')[0] for x in os.listdir(path) if (protien+".csv" in x) and (f"_{time}_" in x)]
    peptides=[x  for x in peptides if 'A' in x]
    peptidesinfo=dict()
    print(len(peptides))
    

    for k in range(len(peptides)): 
        data=pd.read_csv(f"{path}{peptides[k]}_{time}_{protien}.csv")
        data["pxt_neh"]=data.NEH*data.pxt
        data=data[["NEH","pxt","RMSE","pxt_neh","T_NEH","NH"]] 
        minval=min(data.RMSE)

        data=data[data.RMSE==minval]

        peptidesinfo[peptides[k]]={"pxt_neh":float(data.pxt_neh),"T_NEH":float(data.T_NEH),"Seq":peptides[k],
                               "charcount":charcount(peptides[k])}
           
    visited=set()
    visited.add(peptides[0].split('_')[1])
    coefficients=[]
    peptides=sort_pep(peptidesinfo,peptides)
    for k in range(0,len(peptides)-1):
        if(peptides[k+1].split('_')[1] in visited):
            continue

        pep1=peptidesinfo[peptides[k]]
        pep2=peptidesinfo[peptides[k+1]]    
        visited.add(peptides[k].split('_')[1])

        r=pep1["pxt_neh"]/pep2["pxt_neh"]
        coefficients.append([pep1["charcount"][c]-r*pep2["charcount"][c] for c in all_AAs])
        
    return peptides,peptidesinfo,all_AAs,np.array(coefficients)

# %%
def compute_result(peptides,peptidesinfo,all_AAs,sol):
    t_neh,e_neh=[],[]
    for i in range (len(peptides)):
        pep1=peptidesinfo[peptides[i]]
        p_neh=0
        for index,c in enumerate(all_AAs): 
            p_neh+=(pep1["charcount"][c]*sol[index]) 
        t_neh.append(pep1["T_NEH"])
        e_neh.append(p_neh)

    res=pd.DataFrame([peptides,t_neh,e_neh])
    res=res.transpose()
    res.columns=["peptides","True_NEH","e_NEH"]
    res["dif"]=abs(res.True_NEH-res.e_NEH)
#     print(np.mean(res.dif),np.median(res.dif),np.std(res.dif))
    return res.sort_values(by='dif')

# %%
e_vals=[]
for time in times[3:]:
    print(time,"===========================================")
    # time=9
    a_val=4
    # w_val=0.08
    # proteins=["CPSM_MOUSE","FAS_MOUSE","DHB4_MOUSE","ASSY_MOUSE","ATPA_MOUSE","ATPB_MOUSE","BHMT1_MOUSE",
    #          "CLH1_MOUSE","DHE3_MOUSE","DHSO_MOUSE","ECHA_MOUSE",
    #          "G3P_MOUSE","HMCS2_MOUSE","HYES_MOUSE","MYH9_MOUSE","PYC_MOUSE","PYGL_MOUSE","SAHH_MOUSE",
    #          "SARDH_MOUSE","SBP1_MOUSE","THIM_MOUSE","TKT_MOUSE"]
    # proteins=pd.read_csv("H:/Warehouse/Data/liverpool/liver/6_23_2022_c/"+"Analyzed_Proteins_and_Their_Rates.csv").Proteins.unique()

    path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/second_r_heart/" 
    proteins=np.unique(["_".join(x.split('_')[4:]).replace('.csv','') for x in os.listdir(path) if ("_MOUSE.csv" in x)])

    coefficients=np.array([])
    _peptides,_peptidesinfo=[],[]
    for protine in proteins:
        try:
            peptides1,peptidesinfo1,all_AAs1,coefficients1=getPeptiedsInfo(protine,time) 
            print(protine,len(all_AAs1)==20)
            if(coefficients.shape[0]==0):
                coefficients=coefficients1
            else:
                coefficients=np.concatenate((coefficients1,coefficients), axis=0)
            _peptides.append(peptides1)
            _peptidesinfo.append(peptidesinfo1)
        except:
            continue

    # sol=list(scipy.optimize.nnls(coefficients[:,2 :],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])
    sol=list(scipy.optimize.nnls(coefficients[:,1:],-a_val*coefficients[:,0])[0])
    # sol=list(scipy.optimize.nnls(coefficients[:,2:],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])

    print("====>",len(sol))
    sol.insert(0,a_val) 
    # sol.insert(1,w_val) 
    print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
    res=pd.DataFrame()
    for i in range(len(proteins)):
        res=pd.concat([res,compute_result(_peptides[i],_peptidesinfo[i],all_AAs1,sol)])

    print("\nstats",np.mean(res.dif),np.median(res.dif),np.std(res.dif))    
    
    e_vals.append(sol)
# Out:
# 6 ===========================================
# ACADV_MOUSE 6
# 8
# ACADV_MOUSE True
# ACTN2_MOUSE 6
# 14
# ACTN2_MOUSE True
# ALBU_MOUSE 6
# 18
# ALBU_MOUSE True
# AT1A1_MOUSE 6
# 8
# AT1A1_MOUSE True
# AT2A2_MOUSE 6
# 10
# AT2A2_MOUSE True
# ATPA_MOUSE 6
# 12
# ATPA_MOUSE True
# ATPB_MOUSE 6
# 9
# ATPB_MOUSE True
# DESM_MOUSE 6
# 9
# DESM_MOUSE True
# ECHA_MOUSE 6
# 8
# ECHA_MOUSE True
# GRP75_MOUSE 6
# 7
# GRP75_MOUSE True
# KPYM_MOUSE 6
# 8
# KPYM_MOUSE True
# MYG_MOUSE 6
# 15
# MYG_MOUSE True
# MYH6_MOUSE 6
# 58
# MYH6_MOUSE True
# MYOM1_MOUSE 6
# 5
# MYOM1_MOUSE True
# MYPC3_MOUSE 6
# 13
# MYPC3_MOUSE True
# ODO1_MOUSE 6
# 10
# ODO1_MOUSE True
# PYGB_MOUSE 6
# 11
# PYGB_MOUSE True
# SDHA_MOUSE 6
# 8
# SDHA_MOUSE True
# THIL_MOUSE 6
# 8
# THIL_MOUSE True
# TITIN_MOUSE 6
# 80
# TITIN_MOUSE True
# TNNT2_MOUSE 6
# 7
# TNNT2_MOUSE True
# TPIS_MOUSE 6
# 8
# TPIS_MOUSE True
# TPM1_MOUSE 6
# 11
# TPM1_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.369451384852524
# d= 0.7339523713627886
# e= 0.8189447038919506
# f= 0.2868725574417118
# g= 0.0
# h= 0.773915145120114
# i= 0.062456757833711136
# k= 0.0
# l= 0.0078023564135933365
# m= 0.17880797184501623
# n= 0.27406471983002945
# p= 0.16405137770908676
# q= 1.5519830888438173
# r= 0.16298221707728913
# s= 0.1960494142372229
# t= 0.0
# v= 0.0
# w= 0.6225759450052216
# y= 0.0
#
# stats 18.950494515959043 18.81539947201118 4.330004271646918
# 7 ===========================================
# ACADV_MOUSE 7
# 8
# ACADV_MOUSE True
# ACTN2_MOUSE 7
# 14
# ACTN2_MOUSE True
# ALBU_MOUSE 7
# 18
# ALBU_MOUSE True
# AT1A1_MOUSE 7
# 8
# AT1A1_MOUSE True
# AT2A2_MOUSE 7
# 10
# AT2A2_MOUSE True
# ATPA_MOUSE 7
# 12
# ATPA_MOUSE True
# ATPB_MOUSE 7
# 9
# ATPB_MOUSE True
# DESM_MOUSE 7
# 9
# DESM_MOUSE True
# ECHA_MOUSE 7
# 8
# ECHA_MOUSE True
# GRP75_MOUSE 7
# 7
# GRP75_MOUSE True
# KPYM_MOUSE 7
# 8
# KPYM_MOUSE True
# MYG_MOUSE 7
# 15
# MYG_MOUSE True
# MYH6_MOUSE 7
# 58
# MYH6_MOUSE True
# MYOM1_MOUSE 7
# 5
# MYOM1_MOUSE True
# MYPC3_MOUSE 7
# 13
# MYPC3_MOUSE True
# ODO1_MOUSE 7
# 10
# ODO1_MOUSE True
# PYGB_MOUSE 7
# 11
# PYGB_MOUSE True
# SDHA_MOUSE 7
# 8
# SDHA_MOUSE True
# THIL_MOUSE 7
# 8
# THIL_MOUSE True
# TITIN_MOUSE 7
# 80
# TITIN_MOUSE True
# TNNT2_MOUSE 7
# 7
# TNNT2_MOUSE True
# TPIS_MOUSE 7
# 8
# TPIS_MOUSE True
# TPM1_MOUSE 7
# 11
# TPM1_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.5893091995635584
# d= 0.4842309205172707
# e= 0.771532109251499
# f= 0.549606217254944
# g= 0.0
# h= 0.4873822414729383
# i= 0.040320170116392696
# k= 0.0
# l= 0.11294835180013238
# m= 0.0
# n= 0.40428113487968215
# p= 0.14424727894008685
# q= 1.1359833194568458
# r= 0.0
# s= 0.1172058810332962
# t= 0.0
# v= 0.0
# w= 0.0
# y= 0.0
#
# stats 19.588415004737037 19.500155421193842 4.550999099232178
# 9 ===========================================
# ACADV_MOUSE 9
# 8
# ACADV_MOUSE True
# ACTN2_MOUSE 9
# 14
# ACTN2_MOUSE True
# ALBU_MOUSE 9
# 18
# ALBU_MOUSE True
# AT1A1_MOUSE 9
# 8
# AT1A1_MOUSE True
# AT2A2_MOUSE 9
# 10
# AT2A2_MOUSE True
# ATPA_MOUSE 9
# 12
# ATPA_MOUSE True
# ATPB_MOUSE 9
# 9
# ATPB_MOUSE True
# DESM_MOUSE 9
# 9
# DESM_MOUSE True
# ECHA_MOUSE 9
# 8
# ECHA_MOUSE True
# GRP75_MOUSE 9
# 7
# GRP75_MOUSE True
# KPYM_MOUSE 9
# 8
# KPYM_MOUSE True
# MYG_MOUSE 9
# 15
# MYG_MOUSE True
# MYH6_MOUSE 9
# 58
# MYH6_MOUSE True
# MYOM1_MOUSE 9
# 5
# MYOM1_MOUSE True
# MYPC3_MOUSE 9
# 13
# MYPC3_MOUSE True
# ODO1_MOUSE 9
# 10
# ODO1_MOUSE True
# PYGB_MOUSE 9
# 11
# PYGB_MOUSE True
# SDHA_MOUSE 9
# 8
# SDHA_MOUSE True
# THIL_MOUSE 9
# 8
# THIL_MOUSE True
# TITIN_MOUSE 9
# 80
# TITIN_MOUSE True
# TNNT2_MOUSE 9
# 7
# TNNT2_MOUSE True
# TPIS_MOUSE 9
# 8
# TPIS_MOUSE True
# TPM1_MOUSE 9
# 11
# TPM1_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.270675215017092
# d= 1.4888811726734408
# e= 2.0039875614792266
# f= 0.4982459762047719
# g= 0.005751685434765828
# h= 1.3331315213419621
# i= 0.3386730260936662
# k= 0.0
# l= 0.2190930662066965
# m= 0.36479760788034565
# n= 0.9253126998764701
# p= 0.5388328344729472
# q= 2.0910240462613214
# r= 0.19966917701743012
# s= 0.3391725218371249
# t= 0.0
# v= 0.4484051210948283
# w= 0.0
# y= 0.0
#
# stats 14.190457071551595 14.172577716062651 3.5917625111072153
# 13 ===========================================
# ACADV_MOUSE 13
# 8
# ACADV_MOUSE True
# ACTN2_MOUSE 13
# 14
# ACTN2_MOUSE True
# ALBU_MOUSE 13
# 18
# ALBU_MOUSE True
# AT1A1_MOUSE 13
# 8
# AT1A1_MOUSE True
# AT2A2_MOUSE 13
# 10
# AT2A2_MOUSE True
# ATPA_MOUSE 13
# 12
# ATPA_MOUSE True
# ATPB_MOUSE 13
# 9
# ATPB_MOUSE True
# DESM_MOUSE 13
# 9
# DESM_MOUSE True
# ECHA_MOUSE 13
# 8
# ECHA_MOUSE True
# GRP75_MOUSE 13
# 7
# GRP75_MOUSE True
# KPYM_MOUSE 13
# 8
# KPYM_MOUSE True
# MYG_MOUSE 13
# 15
# MYG_MOUSE True
# MYH6_MOUSE 13
# 58
# MYH6_MOUSE True
# MYOM1_MOUSE 13
# 5
# MYOM1_MOUSE True
# MYPC3_MOUSE 13
# 13
# MYPC3_MOUSE True
# ODO1_MOUSE 13
# 10
# ODO1_MOUSE True
# PYGB_MOUSE 13
# 11
# PYGB_MOUSE True
# SDHA_MOUSE 13
# 8
# SDHA_MOUSE True
# THIL_MOUSE 13
# 8
# THIL_MOUSE True
# TITIN_MOUSE 13
# 80
# TITIN_MOUSE True
# TNNT2_MOUSE 13
# 7
# TNNT2_MOUSE True
# TPIS_MOUSE 13
# 8
# TPIS_MOUSE True
# TPM1_MOUSE 13
# 11
# TPM1_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.970006213829589
# d= 1.7847304392346013
# e= 2.5800466069670795
# f= 1.072866173298252
# g= 0.11076759972172837
# h= 1.4467637742889539
# i= 0.5603293482966151
# k= 0.0
# l= 0.5148975562171472
# m= 0.899788321245206
# n= 0.6677584707302514
# p= 0.8253185248335367
# q= 2.5738590916315247
# r= 0.0
# s= 0.46703049337487756
# t= 0.0
# v= 0.7771279131451984
# w= 0.25479496769026705
# y= 0.2281738455080856
#
# stats 11.066106724938924 10.973088401882926 3.38457009880125
# 16 ===========================================
# ACADV_MOUSE 16
# 8
# ACADV_MOUSE True
# ACTN2_MOUSE 16
# 14
# ACTN2_MOUSE True
# ALBU_MOUSE 16
# 18
# ALBU_MOUSE True
# AT1A1_MOUSE 16
# 8
# AT1A1_MOUSE True
# AT2A2_MOUSE 16
# 10
# AT2A2_MOUSE True
# ATPA_MOUSE 16
# 12
# ATPA_MOUSE True
# ATPB_MOUSE 16
# 9
# ATPB_MOUSE True
# DESM_MOUSE 16
# 9
# DESM_MOUSE True
# ECHA_MOUSE 16
# 8
# ECHA_MOUSE True
# GRP75_MOUSE 16
# 7
# GRP75_MOUSE True
# KPYM_MOUSE 16
# 8
# KPYM_MOUSE True
# MYG_MOUSE 16
# 15
# MYG_MOUSE True
# MYH6_MOUSE 16
# 58
# MYH6_MOUSE True
# MYOM1_MOUSE 16
# 5
# MYOM1_MOUSE True
# MYPC3_MOUSE 16
# 13
# MYPC3_MOUSE True
# ODO1_MOUSE 16
# 10
# ODO1_MOUSE True
# PYGB_MOUSE 16
# 11
# PYGB_MOUSE True
# SDHA_MOUSE 16
# 8
# SDHA_MOUSE True
# THIL_MOUSE 16
# 8
# THIL_MOUSE True
# TITIN_MOUSE 16
# 80
# TITIN_MOUSE True
# TNNT2_MOUSE 16
# 7
# TNNT2_MOUSE True
# TPIS_MOUSE 16
# 8
# TPIS_MOUSE True
# TPM1_MOUSE 16
# 11
# TPM1_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 2.3055034481409384
# d= 1.8976933753274228
# e= 2.8442679331298173
# f= 1.0299270322673237
# g= 0.5464178902216407
# h= 1.6317258589700467
# i= 0.5068351762141738
# k= 0.0
# l= 0.5073407888689918
# m= 0.30973240758404075
# n= 0.5795521126437915
# p= 0.7251063151608572
# q= 2.889478078368173
# r= 0.6877379132626242
# s= 0.7316714410565398
# t= 0.12614428416694293
# v= 0.650593011508335
# w= 0.0
# y= 0.2927122315861718
#
# stats 9.56168731387111 9.358359241175144 3.0091553368162915
# 21 ===========================================
# ACADV_MOUSE 21
# 8
# ACADV_MOUSE True
# ACTN2_MOUSE 21
# 14
# ACTN2_MOUSE True
# ALBU_MOUSE 21
# 18
# ALBU_MOUSE True
# AT1A1_MOUSE 21
# 8
# AT1A1_MOUSE True
# AT2A2_MOUSE 21
# 10
# AT2A2_MOUSE True
# ATPA_MOUSE 21
# 12
# ATPA_MOUSE True
# ATPB_MOUSE 21
# 9
# ATPB_MOUSE True
# DESM_MOUSE 21
# 9
# DESM_MOUSE True
# ECHA_MOUSE 21
# 8
# ECHA_MOUSE True
# GRP75_MOUSE 21
# 7
# GRP75_MOUSE True
# KPYM_MOUSE 21
# 8
# KPYM_MOUSE True
# MYG_MOUSE 21
# 15
# MYG_MOUSE True
# MYH6_MOUSE 21
# 58
# MYH6_MOUSE True
# MYOM1_MOUSE 21
# 5
# MYOM1_MOUSE True
# MYPC3_MOUSE 21
# 13
# MYPC3_MOUSE True
# ODO1_MOUSE 21
# 10
# ODO1_MOUSE True
# PYGB_MOUSE 21
# 11
# PYGB_MOUSE True
# SDHA_MOUSE 21
# 8
# SDHA_MOUSE True
# THIL_MOUSE 21
# 8
# THIL_MOUSE True
# TITIN_MOUSE 21
# 80
# TITIN_MOUSE True
# TNNT2_MOUSE 21
# 7
# TNNT2_MOUSE True
# TPIS_MOUSE 21
# 8
# TPIS_MOUSE True
# TPM1_MOUSE 21
# 11
# TPM1_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.988386511725881
# d= 2.1353436542148208
# e= 2.848518428254367
# f= 0.9126354125717232
# g= 0.7063164222749092
# h= 1.8351121919835112
# i= 0.5884086508157492
# k= 0.0
# l= 0.4625432773411353
# m= 0.4771188979346416
# n= 0.8733010465646304
# p= 0.758723304989964
# q= 2.9964328542316663
# r= 0.8063247249542873
# s= 0.865387152094576
# t= 0.13374485903434455
# v= 0.4378157921086489
# w= 0.3984125814643548
# y= 0.1769869564256808
#
# stats 8.950725910287733 8.832968323394486 2.801015590993424
# 24 ===========================================
# ACADV_MOUSE 24
# 8
# ACADV_MOUSE True
# ACTN2_MOUSE 24
# 14
# ACTN2_MOUSE True
# ALBU_MOUSE 24
# 18
# ALBU_MOUSE True
# AT1A1_MOUSE 24
# 8
# AT1A1_MOUSE True
# AT2A2_MOUSE 24
# 10
# AT2A2_MOUSE True
# ATPA_MOUSE 24
# 12
# ATPA_MOUSE True
# ATPB_MOUSE 24
# 9
# ATPB_MOUSE True
# DESM_MOUSE 24
# 9
# DESM_MOUSE True
# ECHA_MOUSE 24
# 8
# ECHA_MOUSE True
# GRP75_MOUSE 24
# 7
# GRP75_MOUSE True
# KPYM_MOUSE 24
# 8
# KPYM_MOUSE True
# MYG_MOUSE 24
# 15
# MYG_MOUSE True
# MYH6_MOUSE 24
# 58
# MYH6_MOUSE True
# MYOM1_MOUSE 24
# 5
# MYOM1_MOUSE True
# MYPC3_MOUSE 24
# 13
# MYPC3_MOUSE True
# ODO1_MOUSE 24
# 10
# ODO1_MOUSE True
# PYGB_MOUSE 24
# 11
# PYGB_MOUSE True
# SDHA_MOUSE 24
# 8
# SDHA_MOUSE True
# THIL_MOUSE 24
# 8
# THIL_MOUSE True
# TITIN_MOUSE 24
# 80
# TITIN_MOUSE True
# TNNT2_MOUSE 24
# 7
# TNNT2_MOUSE True
# TPIS_MOUSE 24
# 8
# TPIS_MOUSE True
# TPM1_MOUSE 24
# 11
# TPM1_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.6610459246397498
# d= 2.440769391703759
# e= 3.355305643397693
# f= 0.8992807933117826
# g= 0.6381065642476078
# h= 1.7522677093575612
# i= 0.6467930310040672
# k= 0.0
# l= 0.5715344283461681
# m= 0.8822019179553777
# n= 0.9884736993341942
# p= 1.0484030533807598
# q= 3.4973346317478713
# r= 0.8170140081926731
# s= 1.1094294352748018
# t= 0.10601506784605698
# v= 0.8974418262885497
# w= 0.28297972255641596
# y= 0.47866119081050895
#
# stats 6.390221843307024 6.428733696561565 2.606216459504094
# 31 ===========================================
# ACADV_MOUSE 31
# 8
# ACADV_MOUSE True
# ACTN2_MOUSE 31
# 14
# ACTN2_MOUSE True
# ALBU_MOUSE 31
# 18
# ALBU_MOUSE True
# AT1A1_MOUSE 31
# 8
# AT1A1_MOUSE True
# AT2A2_MOUSE 31
# 10
# AT2A2_MOUSE True
# ATPA_MOUSE 31
# 12
# ATPA_MOUSE True
# ATPB_MOUSE 31
# 9
# ATPB_MOUSE True
# DESM_MOUSE 31
# 9
# DESM_MOUSE True
# ECHA_MOUSE 31
# 8
# ECHA_MOUSE True
# GRP75_MOUSE 31
# 7
# GRP75_MOUSE True
# KPYM_MOUSE 31
# 8
# KPYM_MOUSE True
# MYG_MOUSE 31
# 15
# MYG_MOUSE True
# MYH6_MOUSE 31
# 58
# MYH6_MOUSE True
# MYOM1_MOUSE 31
# 5
# MYOM1_MOUSE True
# MYPC3_MOUSE 31
# 13
# MYPC3_MOUSE True
# ODO1_MOUSE 31
# 10
# ODO1_MOUSE True
# PYGB_MOUSE 31
# 11
# PYGB_MOUSE True
# SDHA_MOUSE 31
# 8
# SDHA_MOUSE True
# THIL_MOUSE 31
# 8
# THIL_MOUSE True
# TITIN_MOUSE 31
# 80
# TITIN_MOUSE True
# TNNT2_MOUSE 31
# 7
# TNNT2_MOUSE True
# TPIS_MOUSE 31
# 8
# TPIS_MOUSE True
# TPM1_MOUSE 31
# 11
# TPM1_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.745042850173582
# d= 2.7073457453398966
# e= 3.6057007809168162
# f= 0.2593392198902075
# g= 0.8373234240103695
# h= 1.9003089494046068
# i= 0.4197706020961976
# k= 0.0
# l= 0.630174379115106
# m= 0.6691763821398747
# n= 1.0699997396420047
# p= 0.9331929475378555
# q= 3.7447902824357233
# r= 0.8481862485435483
# s= 1.2320956463535973
# t= 0.005368783277238798
# v= 0.7169250718858686
# w= 0.05677795936913049
# y= 0.1575364357613057
#
# stats 6.02684052085256 5.9974848863285 2.664545895652399

# %%
evals2=np.array(e_vals)
trueval=[4.0,1.62,1.89,3.95,0.32,2.06,2.88,1.0,0.6,0.54,1.12,1.89,2.59,3.95,3.43,2.61,0.2,0.56,0.08,0.42]

# %%
for i in range(len(all_AAs1)):
    plt.scatter(range(8),evals2[:,i],c='k')
    plt.xticks(np.arange(8), times[3:])
    plt.title(all_AAs1[i]+f" ({trueval[i]})"+f"      t=31: ({evals2[:,i][-1]})")
    plt.ylim([-0.1,4.3])
    plt.hlines(y=np.median(evals2[:,i]),xmin=0,xmax=8,linestyle="-.",color='r')
    plt.hlines(y=trueval[i],xmin=0,xmax=8,linestyle="-.")
    plt.show()

# %%
print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
# Out:
# Values
#  a= 4
# c= 1.745042850173582
# d= 2.7073457453398966
# e= 3.6057007809168162
# f= 0.2593392198902075
# g= 0.8373234240103695
# h= 1.9003089494046068
# i= 0.4197706020961976
# k= 0.0
# l= 0.630174379115106
# m= 0.6691763821398747
# n= 1.0699997396420047
# p= 0.9331929475378555
# q= 3.7447902824357233
# r= 0.8481862485435483
# s= 1.2320956463535973
# t= 0.005368783277238798
# v= 0.7169250718858686
# w= 0.05677795936913049
# y= 0.1575364357613057

# %%
print("proteins",len(proteins),"peptides",res.shape[0])
# Out:
# proteins 23 peptides 345

# %%
res=res.sort_values(by='dif')
res.head(20)
# Out:
#               peptides True_NEH      e_NEH       dif
# 11    _TcVADESAANcDK_2     28.0  27.534867  0.465133
# 19    _IEDEQALALQLQK_2     32.0  31.463412  0.536588
# 20    _IEDEQALALQLQK_3     32.0  31.463412  0.536588
# 44   _LQDAEEAVEAVNAK_3     37.0  36.403263  0.596737
# 43   _LQDAEEAVEAVNAK_2     37.0  36.403263  0.596737
# 5    _DAVLNAWAEDVDLR_2     29.0  28.396901  0.603099
# 1     _LTVELADPDAEVK_2     25.0  24.258854  0.741146
# 0   _LVDEAFQDLMTEVcK_3     25.0  25.744009  0.744009
# 4     _SIDDLEDELYAQK_2     27.0  26.147981  0.852019
# 5     _SIDDLEDELYAQK_3     27.0  26.147981  0.852019
# 4   _ADMVIEAVFEDLGVK_2     27.0  25.592652  1.407348
# 12   _KAITDAAMMAEELK_3     30.0  28.312414  1.687586
# 0      _LIVEGAVVEFVK_2     18.0  16.225709  1.774291
# 21    _KLAEKDEEMEQAK_3     32.0   30.17429   1.82571
# 22    _KLAEKDEEMEQAK_4     32.0   30.17429   1.82571
# 25     _LAEKDEEMEQAK_3     32.0   30.17429   1.82571
# 2   _VGEATETALTcLVEK_2     26.0  24.109774  1.890226
# 3      _ENYGELADccTK_2     22.0  20.109236  1.890764
# 22    _LEAPDIDLDLELR_2     26.0  24.055286  1.944714
# 0      _cNDSALDYNEAK_2     25.0  22.925241  2.074759

# %%
res.tail(20)
# Out:
#                   peptides True_NEH      e_NEH        dif
# 0         _NTGIIcTIGPASR_2     23.0  12.773214  10.226786
# 6      _DAEEGPVEDTKPKPSR_3     37.0  26.671272  10.328728
# 73  _DSGYYSLTAENSSGSDTQK_2     37.0  26.626292  10.373708
# 62  _VPAPAEVPVTPPTLVSGLK_2     33.0  22.479871  10.520129
# 3      _VNIHGGAVSLGHPIGM_3     29.0  17.957942  11.042058
# 4     _PSDLAGPVVAETRPGTK_3     34.0  22.942316  11.057684
# 6     _TPIGSFLGSLASQPATK_3     32.0  20.932306  11.067694
# 59  _AGDSIVLSAISILGKPLPK_3     33.0  21.811425  11.188575
# 7    _EVYMGNVIQGGEGQAPTR_2     39.0  27.587357  11.412643
# 75  _NAADSVSEPSESTGPITVK_2     40.0  28.485197  11.514803
# 2   _GGVSMPLSFAVTPYGYASK_2     31.0  19.387625  11.612375
# 7     _ENMASLQSSPQHQELFR_3     45.0  33.082612  11.917388
# 52  _YGVGPGITSASVVANYPFK_2     31.0  19.062874  11.937126
# 3         _ISNRPAFMPSEGK_3     28.0  16.040074  11.959926
# 76  _NAAGAISKPSDSTGPITAK_3     40.0  27.864944  12.135056
# 78  _NAAGVFSEPSESTGAITAR_2     46.0  32.840487  13.159513
# 63     _AGSSPPSKPTEYVTAR_3     34.0  20.672275  13.327725
# 72  _SSVSLAWNKPIYDGGAPVR_3     36.0  22.560961  13.439039
# 79  _NAAGAISPPSEPSDAITcR_2     48.0  34.154375  13.845625
# 54        _EPSYTPGPPSAPR_2     32.0  16.584272  15.415728

# %%
temp=pd.DataFrame(coefficients)
temp.columns=all_AAs1
temp
# Out:
#             a    c         d         e         f         g         h  \
# 0   -0.065134  0.0 -0.032567 -0.065134  0.000000  0.000000  0.000000
# 1    0.985422  0.0 -1.029156 -1.043734  0.000000 -1.014578  0.000000
# 2    0.086957  0.0  0.173913  0.260870  0.000000  0.086957  0.000000
# 3    0.176170  0.0 -0.471490  1.352340  0.000000  1.000000  0.000000
# 4   -0.041096  0.0 -0.123288 -0.082192  0.000000  0.000000  0.000000
# ..        ...  ...       ...       ...       ...       ...       ...
# 288  0.250000  0.0  0.000000 -0.500000  1.000000  3.250000 -0.750000
# 289  0.009009  0.0  0.000000  0.018018  0.000000  0.009009  0.009009
# 290 -1.317025  0.0 -0.579256  0.841487 -0.579256  0.420744  1.000000
# 291  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 292  2.849099  0.0  1.000000 -0.301802 -0.150901  1.000000 -1.150901
#
#             i         k         l         m         n         p         q  \
# 0    0.000000 -0.065134 -0.032567  0.000000  0.000000  0.000000 -0.032567
# 1    0.000000 -0.029156 -1.029156  0.000000  0.000000  0.000000  1.000000
# 2    0.000000  0.173913  0.173913  0.000000  0.000000  0.000000  0.000000
# 3   -0.823830  1.176170  0.352340  0.000000  0.000000  0.000000 -0.823830
# 4   -0.041096 -0.041096 -0.082192  0.000000  0.000000  0.000000 -0.041096
# ..        ...       ...       ...       ...       ...       ...       ...
# 288  0.000000  0.250000  1.250000  1.000000  2.000000  0.250000 -0.750000
# 289  0.000000  0.009009  0.009009  0.000000  0.000000  0.009009  0.009009
# 290  0.000000  0.420744 -0.158513  0.000000  0.000000  1.000000 -0.158513
# 291  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 292  0.000000  1.000000 -0.301802 -1.150901 -1.150901 -1.150901 -1.452703
#
#             r         s         t         v    w         y
# 0    0.000000 -0.032567  0.000000  0.000000  0.0 -0.032567
# 1    0.000000 -0.014578 -1.014578  0.000000  0.0 -0.014578
# 2    0.000000  0.086957  0.086957  0.000000  0.0  0.086957
# 3    0.000000  0.176170  1.000000  0.000000  0.0  0.176170
# 4    0.000000 -0.041096  0.000000  0.000000  0.0 -0.041096
# ..        ...       ...       ...       ...  ...       ...
# 288  0.000000 -1.500000 -0.750000  1.000000  0.0 -0.750000
# 289  0.000000  0.018018  0.009009  0.000000  0.0  0.009009
# 290  0.000000  1.420744  0.420744 -1.737769  0.0  1.000000
# 291  0.000000  0.000000  0.000000  0.000000  0.0  0.000000
# 292 -1.150901 -2.452703  1.000000  3.000000  0.0  0.000000
#
# [293 rows x 20 columns]

# %%
ypred=[np.dot(coefficients[c],sol) for c in range(coefficients.shape[0])]
sigma=sum([ (0-x)**2 for x in ypred])/(len(ypred)-20-1)
cov=((sigma**2)*np.linalg.inv(np.matmul(coefficients.transpose(),coefficients)))
var=[cov[x][x] for x in range(20)]
ci_ub=[coefficients[i]+1.96*var[i] for i in range(20)]
ci_lb=[coefficients[i]-1.96*var[i] for i in range(20)]
ci=[1.96*var[i] for i in range(20)]

# %%
temp=pd.DataFrame()
temp["AA"]=all_AAs1
temp["value"]=sol
temp["var"]=var
temp["CI"]=ci
temp.sort_values(by="var")
# Out:
#    AA     value       var        CI
# 9   l  0.630174  0.143001  0.280282
# 16  t  0.005369  0.144124  0.282483
# 7   i  0.419771  0.159993  0.313587
# 17  v  0.716925  0.170273  0.333734
# 12  p  0.933193  0.201496  0.394932
# 15  s  1.232096  0.207183  0.406079
# 5   g  0.837323  0.208877  0.409399
# 11  n  1.070000  0.260441  0.510464
# 4   f  0.259339  0.410329  0.804244
# 0   a  4.000000  0.422374  0.827853
# 19  y  0.157536  0.432814  0.848315
# 2   d  2.707346  0.502027  0.983972
# 8   k  0.000000  0.531784  1.042296
# 10  m  0.669176  0.569787  1.116782
# 3   e  3.605701  0.677288  1.327484
# 6   h  1.900309  0.707807  1.387303
# 14  r  0.848186  0.718283  1.407834
# 13  q  3.744790  0.786120  1.540796
# 1   c  1.745043  1.209536  2.370691
# 18  w  0.056778  1.216749  2.384828

# %%
ypred=[np.dot(coefficients[c],sol) for c in range(coefficients.shape[0])]
sigma=sum([ (0-x)**2 for x in ypred])/(len(ypred)-20-1)
cov=((sigma**2)*np.linalg.inv(np.matmul(coefficients[:,1:].transpose(),coefficients[:,1:])))
var=[cov[x][x] for x in range(19)]
ci_ub=[coefficients[i+1]+1.96*var[i] for i in range(19)]
ci_lb=[coefficients[i+1]-1.96*var[i] for i in range(19)]
ci=[1.96*var[i] for i in range(19)]

temp=pd.DataFrame()
temp["AA"]=all_AAs1[1:]
temp["E_value"]=sol[1:]
temp["T_value"]=trueval[1:]
temp["var"]=var
temp["CI"]=ci
temp.sort_values(by="var")
# Out:
#    AA   E_value  T_value       var        CI
# 8   l  0.630174     0.54  0.132845  0.260377
# 15  t  0.005369     0.20  0.144113  0.282461
# 6   i  0.419771     1.00  0.155782  0.305333
# 16  v  0.716925     0.56  0.156701  0.307133
# 14  s  1.232096     2.61  0.166140  0.325634
# 11  p  0.933193     2.59  0.177136  0.347187
# 4   g  0.837323     2.06  0.189417  0.371258
# 10  n  1.070000     1.89  0.230265  0.451319
# 1   d  2.707346     1.89  0.307975  0.603630
# 2   e  3.605701     3.95  0.327369  0.641644
# 3   f  0.259339     0.32  0.408793  0.801235
# 12  q  3.744790     3.95  0.416504  0.816348
# 18  y  0.157536     0.42  0.432157  0.847028
# 7   k  0.000000     0.60  0.530146  1.039087
# 9   m  0.669176     1.12  0.557540  1.092778
# 5   h  1.900309     2.88  0.616876  1.209076
# 13  r  0.848186     3.43  0.706365  1.384476
# 0   c  1.745043     1.62  1.131299  2.217346
# 17  w  0.056778     0.08  1.216659  2.384652
