# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.decomposition import PCA
import scipy

# %%
ph=1.5574E-4
times=[1,2,3,6,7,9,13,16,21,24,31] 
pxt=[(x) for x in list(range(3,50,1))]
neh=range(1,120)
path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/liverpool_liver_31_test/"

# %%
all_AAs=['a','w',  'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'p','q', 'r', 's', 't', 'v', 'y']
def charcount(pepSeq):
    res={key: 0 for key in all_AAs}     
    for c in pepSeq.lower():
        if c.isalpha():
            res[c]+=1
    return res

# %%
def getPeptiedsInfo(protien,time):
    
    peptides=[x.split('_1_')[0] for x in os.listdir(path) if ((protien+".csv" in x) and ("_1_" in x)) ]
    peptides=[x  for x in peptides if 'A' in x]
#     all_AAs=np.unique([c for c in ("".join(sorted([x.replace('_','').replace('2','').replace('3','') for x in peptides])).lower())])
    peptidesinfo=dict()
    len(peptides)
    

    for k in range(len(peptides)):
        data=pd.read_csv(f"{path}{peptides[k]}_{time}_{protien}.csv")
        data["pxt_neh"]=data.NEH*data.pxt
        data=data[["NEH","pxt","RMSE","pxt_neh","T_NEH","NH"]] 
        minval=min(data.RMSE)

        data=data[data.RMSE==minval]

        peptidesinfo[peptides[k]]={"pxt_neh":float(data.pxt_neh),"T_NEH":float(data.T_NEH),"Seq":peptides[k],
                               "charcount":charcount(peptides[k])}
        
    print(len(peptides))    
    visited=set()
    visited.add(peptides[0].split('_')[1])
    coefficients=[]
    for k in range(0,len(peptides)-1):
        if(peptides[k+1].split('_')[1] in visited):
            continue

        pep1=peptidesinfo[peptides[k]]
        pep2=peptidesinfo[peptides[k+1]]    
        visited.add(peptides[k].split('_')[1])

        r=pep1["pxt_neh"]/pep2["pxt_neh"]
        coefficients.append([pep1["charcount"][c]-r*pep2["charcount"][c] for c in all_AAs])
        
    return peptides,peptidesinfo,all_AAs,np.array(coefficients)

# %%
def compute_result(peptides,peptidesinfo,all_AAs,sol):
    t_neh,e_neh=[],[]
    for i in range (len(peptides)):
        pep1=peptidesinfo[peptides[i]]
        p_neh=0
        for index,c in enumerate(all_AAs): 
            p_neh+=(pep1["charcount"][c]*sol[index]) 
        t_neh.append(pep1["T_NEH"])
        e_neh.append(p_neh)

    res=pd.DataFrame([peptides,t_neh,e_neh])
    res=res.transpose()
    res.columns=["peptides","True_NEH","e_NEH"]
    res["dif"]=abs(res.True_NEH-res.e_NEH)
#     print(np.mean(res.dif),np.median(res.dif),np.std(res.dif))
    return res.sort_values(by='dif')

# %%
time=31
a_val=4
w_val=0
proteins=["CPSM_MOUSE","FAS_MOUSE","DHB4_MOUSE","ASSY_MOUSE","ATPA_MOUSE","ATPB_MOUSE","BHMT1_MOUSE",
         "CLH1_MOUSE","DHE3_MOUSE","DHSO_MOUSE","ECHA_MOUSE",
         "G3P_MOUSE","HMCS2_MOUSE","HYES_MOUSE","MYH9_MOUSE","PYC_MOUSE","PYGL_MOUSE","SAHH_MOUSE",
         "SARDH_MOUSE","SBP1_MOUSE","THIM_MOUSE","TKT_MOUSE"]
# proteins=["CPT2_MOUSE"],,"FAS_MOUSE",
coefficients=np.array([])
_peptides,_peptidesinfo=[],[]
for protine in proteins:
    try:
        peptides1,peptidesinfo1,all_AAs1,coefficients1=getPeptiedsInfo(protine,time) 
        print(protine,len(all_AAs1)==20)
        if(coefficients.shape[0]==0):
            coefficients=coefficients1
        else:
            coefficients=np.concatenate((coefficients1,coefficients), axis=0)
        _peptides.append(peptides1)
        _peptidesinfo.append(peptidesinfo1)
    except:
        continue
    
sol=list(scipy.optimize.nnls(coefficients[:,2 :],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])
# sol=list(scipy.optimize.lsq_linear(coefficients[:,1:],-a_val*coefficients[:,0])[0])
print("====>",len(sol))
sol.insert(0,a_val) 
sol.insert(1,w_val) 
print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
res=pd.DataFrame()
for i in range(len(proteins)):
    res=pd.concat([res,compute_result(_peptides[i],_peptidesinfo[i],all_AAs1,sol)])

print("\nstats",np.mean(res.dif),np.median(res.dif),np.std(res.dif))
# Out:
# CPSM_MOUSE 	 ['_AADTIGYPVMIR_2', '_AFAISGPFNVQFLVK_2', '_AFAmTNQILVER_2', '_ANPIIGNGGAPDTTAR_2', '_AVNTLNEALEFAN_2', '_FLGVAEQLHNEGFK_2', '_FLGVAEQLHNEGFK_3', '_HIGSSVEFDWcAVSSIR_3', '_HLGIVGEcNIQFALHPT_3', '_IALGIPLPEIK_2', '_IAPSFAVESMEDALK_2', '_IASVQTNEVGLK_2', '_LPTLEQPIIPSDYVAIK_3', '_QAFITAQNHGY_2', '_RLPTLEQPIIPSDYVAIK_2', '_SAYALGGLGSGIcPNK_3', '_SIFSAVLDELK_2', '_SMEYcIIEVNAR_2', '_TAHIVLEDGTK_3', '_TAVDSGIALLTNFQVTK_2', '_TAVDSGIALLTNFQVTK_3', '_TSAcFEPSLDYMVTK_2', '_TVLMNPNIASVQTNEVGLK_2', '_VLGTSVESIMATEDR_2']
# 24
# CPSM_MOUSE True
# FAS_MOUSE 	 ['_AcVDTALENLSTLK_2', '_DAMLENQTPELFQDVNKPK_3', '_FPQLDDTSFANSR_2', '_GNAGQTNYGFANSTMER_2', '_LFDHPEVPTPPESASVSR_3', '_LKEDTQVADVTTSR_3', '_LLLPEDPLISGLLNSQALK_2', '_LLLPEDPLISGLLNSQALK_3', '_QGIQVLVSTSNVSSLEGAR_2', '_SDEAVKPLGVK_2', '_SDEAVKPLGVK_3', '_VTAIYIDPATHR_3', '_WLSTSIPEAQWQSSLAR_2']
# 13
# FAS_MOUSE True
# DHB4_MOUSE 	 ['_AVANYDSVEAGEK_2', '_DATSLNQAALYR_2', '_HVLQQFADNDVSR_2', '_IDVVVNNAGILR_2', '_LGILGLcNTLAIEGR_2', '_VVLVTGAGGGLGR_2']
# 6
# DHB4_MOUSE True
# ASSY_MOUSE 	 ['_APNSPDVLEIEFK_2', '_EFVEEFIWPAVQ_2', '_EQGYDVIAYLANIGQK_3', '_FAELVYTGFWHSPEcEFVR_2', '_FAELVYTGFWHSPEcEFVR_3', '_FELTcYSLAPQIK_2', '_GIYETPAGTILYH_2', '_HAHLDIEAFTMDR_3', '_TTSLELFMYLNEVAGK_2', '_YLLGTSLARPc_2']
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 	 ['_AIEEQVAVIYAGVR_2', '_AIEEQVAVIYAGVR_3', '_AQFGSDLDAATQQLLSR_2', '_AQFGSDLDAATQQLLSR_3', '_EAYPGDVFYLHSR_2', '_EAYPGDVFYLHSR_3', '_EAYPGDVFYLH_2', '_GIRPAINVGLSVSR_3', '_HALIIYDDLSK_2', '_LAPYSGcSMGEYFR_2', '_LYcIYVAIGQK_2', '_NVQAEEMVEFSSGLK_2', '_TGTAEMSSILEER_2', '_TSIAIDTIINQK_2', '_VVDALGNAIDGK_2']
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 	 ['_AHGGYSVFAGVGER_2', '_AHGGYSVFAGVGER_3', '_FLSQPFQVAEVFTGHMGK_3', '_FLSQPFQVAEVFTGH_2', '_FTQAGSEVSALLGR_2', '_FTQAGSEVSALLGR_3', '_IGLFGGAGVGK_2', '_IMDPNIVGNEHYDVAR_3', '_IVGNEHYDVAR_3', '_LVLEVAQHLGESTVR_3', '_QVAEVFTGHMGK_3', '_SLQDIIAILGMDELSEEDK_2', '_VALTGLTVAEYFR_2', '_VALVYGQMNEPPGAR_2', '_VLDSGAPIKIPVGPETLGR_3']
# 15
# ATPB_MOUSE True
# BHMT1_MOUSE 	 ['_AGPWTPEAAVEHPEAVR_3', '_AYLMSQPLAYHTPDcGK_3', '_LNAGEVVIGDGGFVFALEK_3', '_TFYASEDKLENR_3']
# 4
# BHMT1_MOUSE True
# CLH1_MOUSE 	 ['_ESYVETELIFALAK_2', '_IHEGcEEPATHNALAK_4', '_RPISADSAIMNPASK_2', '_SVDPTLALSVYLR_2', '_VSQPIEGHAASFAQFK_3']
# 5
# CLH1_MOUSE True
# DHE3_MOUSE 	 ['_AGGVTVSYFEWLK_2', '_DIVHSGLAYTMER_3', '_GFIGPGIDVPAPDMSTGER_2', '_GVFHGIENFINEASYM_2', '_HGGTIPVVPTAEFQDR_2', '_HGGTIPVVPTAEFQDR_3']
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 	 ['_AMGAAQVVVTDLSASR_2', '_AMGAAQVVVTDLSASR_3', '_FcATPPDDGNLcR_2', '_GAGPVGMVTLLVAK_2', '_KPMVLGHEAAGTVTK_2', '_KPMVLGHEAAGTVTK_3', '_VLGHEAAGTVTK_2', '_VLVcGAGPVGMVTLLVAK_2', '_VLVcGAGPVGMVTLLVAK_3', '_VLVcGAGPVGMVTLLV_2']
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 	 ['_ADMVIEAVFEDLGVK_2', '_ADMVIEAVFEDLGVK_3', '_ALMGLYNGQVLcK_2', '_DTTASAVAVGLR_2', '_KYESAYGTQFTPc_2', '_LPAKPEVSSDEDVQYR_3', '_MVGVPAAFDMMLTGR_2', '_SLNSEMDNILANLR_2', '_TIEYLEEVAVNFAK_3']
# 9
# ECHA_MOUSE True
# G3P_MOUSE 	 ['_GAAQNIIPASTGAAK_2', '_VVDLMAYMASK_2']
# 2
# G3P_MOUSE True
# HMCS2_MOUSE 	 ['_AANWMESSYWDGR_2', '_IGAFSYGSGLAASFFSFR_2', '_PTGGAGAVAMLIGPK_2', '_SYGSGLAASFFSFR_2']
# 4
# HMCS2_MOUSE True
# HYES_MOUSE 	 ['_ASDETGFIAVHK_2', '_ASDETGFIAVHK_3', '_DMGMVTILVHNTASALR_3', '_YQIPALAQAGFR_2']
# 4
# HYES_MOUSE True
# MYH9_MOUSE 	 ['_ANLQIDQINTDLNLER_2', '_DLEAHIDTANK_2', '_ELEDATETADAMNR_2']
# 3
# MYH9_MOUSE True
# PYC_MOUSE 	 ['_ADFAQAcQDAGVR_2', '_AEAEAQAEELSFPR_2', '_DFTATFGPLDSLNTR_2', '_GLAPVQAYLHIPDIIK_3', '_QVGYENAGTVEFLVDK_2', '_VFDYSEYWEGAR_2', '_VVEIAPATHLDPQLR_3', '_YSLEYYMGLAEELVR_2', '_YSLEYYMGLAEELVR_3']
# 9
# PYC_MOUSE True
# PYGL_MOUSE 	 ['_ARPEFMLPVHFYGR_4', '_DYYFALAHTVR_3', '_GIVGVENVAELK_2', '_LITSVAEVVNNDPMVGSK_2', '_LITSVAEVVNNDPMVGSK_3', '_LKQEYFVVAATLQDVIR_3', '_QEYFVVAATLQDVIR_2', '_TFAYTNHTVLPEALER_3']
# 8
# PYGL_MOUSE True
# SAHH_MOUSE 	 ['_ALDIAENEMPGLMR_2', '_KLDEAVAEAHLGK_2', '_TVETAVLIETLVALGAEVR_3', '_VADIGLAAWGR_2', '_VAVVAGYGDVGK_2', '_VPAINVNDSVTK_2', '_WSScNIFSTQDHAAAAIAK_3']
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 	 ['_AYGIESHVLSPAETK_3', '_DILQDVLDADLSNEAFPF_2', '_GAAAVFNMSYFGK_2', '_GAQVIENcAVTGIR_2', '_LGVGGAVLLER_2', '_MGVTYAAQVHLK_2', '_NYSVVFPHDEPLAGR_3', '_VPLVAMHHAYVVTER_3']
# 8
# SARDH_MOUSE True
# SBP1_MOUSE 	 ['_EPLGPALAHELR_3', '_FLHDPSATQGFVGcAL_2']
# 2
# SBP1_MOUSE True
# THIM_MOUSE 	 ['_LEDTLWAGLTDQHVK_3', '_LPMGMTAENLAAK_2', '_TPFGAYGGLLK_2', '_VGVPTETGALTLNR_2', '_VGVPTETGALTLNR_3', '_VMQSSSDAAYLAR_2']
# 6
# THIM_MOUSE True
# TKT_MOUSE 	 ['_AVWAEAGFLPEAELLNLR_2', '_ILATPPQEDAPSVDIANIR_3', '_LGQSDPAPLQHQVDIYQK_3', '_MFGIDKDAIVQAVK_3', '_NMAEQIIQEIYSQVQSK_3', '_SVPMSTVFYPSDGVATEK_2']
# 6
# TKT_MOUSE True
# ====> 18
#
# Values
#  a= 4
# w= 0
# c= 2.090418607824715
# d= 2.7471482618938414
# e= 4.043553464482396
# f= 0.8910341752821783
# g= 1.4324195026693758
# h= 1.1116876439638832
# i= 0.8004780534742971
# k= 0.06308713516847347
# l= 0.9462391271525679
# m= 0.6366639504330963
# n= 1.4046397083572257
# p= 1.9688885256448223
# q= 3.961514207048809
# r= 2.042501387379062
# s= 1.6111917940968914
# t= 0.11533370133611517
# v= 0.8397193321488935
# y= 1.2342972654965518
#
# stats 1.799372139827646 1.45089474129062 1.3933894483818536

# %%
print("proteins",len(proteins),"peptides",res.shape[0])

# %%
res=res.sort_values(by='dif')
res.head(20)

# %%
res.tail(20)

# %%
temp=pd.DataFrame(coefficients)
temp.columns=all_AAs1
temp

# %%
# for c in range( len(coefficients)):
#     print(np.dot(coefficients[c],sol))
