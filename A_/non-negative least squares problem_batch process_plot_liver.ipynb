# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.decomposition import PCA
import scipy

# %%
ph=1.5574E-4
times=[1,2,3,6,7,9,13,16,21,24,31] 
pxt=[(x) for x in list(range(3,50,1))]
neh=range(1,120)
# path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/liverpool_liver_31_test/"

# %%
all_AAs=['a', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'p','q', 'r', 's', 't', 'v', 'w', 'y']
def charcount(pepSeq):
    res={key: 0 for key in all_AAs}     
    for c in pepSeq.lower():
        if c.isalpha():
            res[c]+=1
    return res

# %%
def getPeptiedsInfo(protien,time):
    print(protien,time)
    peptides=[x.split(f'_{time}_')[0] for x in os.listdir(path) if (protien+".csv" in x) and (f"_{time}_" in x)]
    peptides=[x  for x in peptides if 'A' in x]
    peptidesinfo=dict()
    print(len(peptides))
    

    for k in range(len(peptides)): 
        data=pd.read_csv(f"{path}{peptides[k]}_{time}_{protien}.csv")
        data["pxt_neh"]=data.NEH*data.pxt
        data=data[["NEH","pxt","RMSE","pxt_neh","T_NEH","NH"]] 
        minval=min(data.RMSE)

        data=data[data.RMSE==minval]

        peptidesinfo[peptides[k]]={"pxt_neh":float(data.pxt_neh),"T_NEH":float(data.T_NEH),"Seq":peptides[k],
                               "charcount":charcount(peptides[k])}
           
    visited=set()
    visited.add(peptides[0].split('_')[1])
    coefficients=[]
    for k in range(0,len(peptides)-1):
        if(peptides[k+1].split('_')[1] in visited):
            continue

        pep1=peptidesinfo[peptides[k]]
        pep2=peptidesinfo[peptides[k+1]]    
        visited.add(peptides[k].split('_')[1])

        r=pep1["pxt_neh"]/pep2["pxt_neh"]
        coefficients.append([pep1["charcount"][c]-r*pep2["charcount"][c] for c in all_AAs])
        
    return peptides,peptidesinfo,all_AAs,np.array(coefficients)

# %%
def compute_result(peptides,peptidesinfo,all_AAs,sol):
    t_neh,e_neh=[],[]
    for i in range (len(peptides)):
        pep1=peptidesinfo[peptides[i]]
        p_neh=0
        for index,c in enumerate(all_AAs): 
            p_neh+=(pep1["charcount"][c]*sol[index]) 
        t_neh.append(pep1["T_NEH"])
        e_neh.append(p_neh)

    res=pd.DataFrame([peptides,t_neh,e_neh])
    res=res.transpose()
    res.columns=["peptides","True_NEH","e_NEH"]
    res["dif"]=abs(res.True_NEH-res.e_NEH)
#     print(np.mean(res.dif),np.median(res.dif),np.std(res.dif))
    return res.sort_values(by='dif')

# %%
e_vals=[]
for time in times[3:]:
    print(time,"===========================================")
    # time=9
    a_val=4
    # w_val=0.08
    # proteins=["CPSM_MOUSE","FAS_MOUSE","DHB4_MOUSE","ASSY_MOUSE","ATPA_MOUSE","ATPB_MOUSE","BHMT1_MOUSE",
    #          "CLH1_MOUSE","DHE3_MOUSE","DHSO_MOUSE","ECHA_MOUSE",
    #          "G3P_MOUSE","HMCS2_MOUSE","HYES_MOUSE","MYH9_MOUSE","PYC_MOUSE","PYGL_MOUSE","SAHH_MOUSE",
    #          "SARDH_MOUSE","SBP1_MOUSE","THIM_MOUSE","TKT_MOUSE"]
    # proteins=pd.read_csv("H:/Warehouse/Data/liverpool/liver/6_23_2022_c/"+"Analyzed_Proteins_and_Their_Rates.csv").Proteins.unique()

    path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/" 
    proteins=np.unique(["_".join(x.split('_')[4:]).replace('.csv','') for x in os.listdir(path) if ("_MOUSE.csv" in x)])

    coefficients=np.array([])
    _peptides,_peptidesinfo=[],[]
    for protine in proteins:
        try:
            peptides1,peptidesinfo1,all_AAs1,coefficients1=getPeptiedsInfo(protine,time) 
            print(protine,len(all_AAs1)==20)
            if(coefficients.shape[0]==0):
                coefficients=coefficients1
            else:
                coefficients=np.concatenate((coefficients1,coefficients), axis=0)
            _peptides.append(peptides1)
            _peptidesinfo.append(peptidesinfo1)
        except:
            continue

    # sol=list(scipy.optimize.nnls(coefficients[:,2 :],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])
    sol=list(scipy.optimize.nnls(coefficients[:,1:],-a_val*coefficients[:,0])[0])
    # sol=list(scipy.optimize.nnls(coefficients[:,2:],-a_val*coefficients[:,0]-w_val*coefficients[:,1])[0])

    print("====>",len(sol))
    sol.insert(0,a_val) 
    # sol.insert(1,w_val) 
    print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
    res=pd.DataFrame()
    for i in range(len(proteins)):
        res=pd.concat([res,compute_result(_peptides[i],_peptidesinfo[i],all_AAs1,sol)])

    print("\nstats",np.mean(res.dif),np.median(res.dif),np.std(res.dif))    
    
    e_vals.append(sol)
# Out:
# 6 ===========================================
# AL1L1_MOUSE 6
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 6
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 6
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 6
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 6
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 6
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 6
# 15
# ATPB_MOUSE True
# BIP_MOUSE 6
# 8
# BIP_MOUSE True
# CAH3_MOUSE 6
# 11
# CAH3_MOUSE True
# CATA_MOUSE 6
# 11
# CATA_MOUSE True
# CPSM_MOUSE 6
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 6
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 6
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 6
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 6
# 9
# ECHA_MOUSE True
# EF2_MOUSE 6
# 5
# EF2_MOUSE True
# ENOA_MOUSE 6
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 6
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 6
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 6
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 6
# 7
# FAAA_MOUSE True
# FAS_MOUSE 6
# 13
# FAS_MOUSE True
# GRP75_MOUSE 6
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 6
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 6
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 6
# 8
# PGM1_MOUSE True
# PYC_MOUSE 6
# 9
# PYC_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 0.9153414556466422
# d= 1.8857152402874897
# e= 2.675536482675756
# f= 0.0
# g= 1.0752456892675506
# h= 0.724630138563562
# i= 0.0
# k= 0.0
# l= 0.4973410566397118
# m= 0.0
# n= 0.36729513849652073
# p= 0.9482544521942802
# q= 2.4027441166204384
# r= 0.7347595341858758
# s= 1.0347914643769973
# t= 0.0
# v= 0.08704345290566229
# w= 0.0
# y= 0.6497326600214572
#
# stats 10.662970263002 10.419937635693191 3.157721511822556
# 7 ===========================================
# AL1L1_MOUSE 7
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 7
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 7
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 7
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 7
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 7
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 7
# 15
# ATPB_MOUSE True
# BIP_MOUSE 7
# 8
# BIP_MOUSE True
# CAH3_MOUSE 7
# 11
# CAH3_MOUSE True
# CATA_MOUSE 7
# 11
# CATA_MOUSE True
# CPSM_MOUSE 7
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 7
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 7
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 7
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 7
# 9
# ECHA_MOUSE True
# EF2_MOUSE 7
# 5
# EF2_MOUSE True
# ENOA_MOUSE 7
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 7
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 7
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 7
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 7
# 7
# FAAA_MOUSE True
# FAS_MOUSE 7
# 13
# FAS_MOUSE True
# GRP75_MOUSE 7
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 7
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 7
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 7
# 8
# PGM1_MOUSE True
# PYC_MOUSE 7
# 9
# PYC_MOUSE True
# PYGL_MOUSE 7
# 8
# PYGL_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.271128129677368
# d= 1.7578747888280368
# e= 2.9589010431318683
# f= 0.2934511703018635
# g= 1.1638821662382424
# h= 1.1869370139861242
# i= 0.0
# k= 0.0
# l= 0.5006361944147564
# m= 0.0
# n= 0.4208755502731646
# p= 1.2002507662409378
# q= 2.800660294946646
# r= 1.1010092788351458
# s= 0.9981789821901949
# t= 0.0
# v= 0.1789123669009079
# w= 0.0
# y= 0.47965539061653845
#
# stats 9.357775344033435 8.944528846641404 2.798382238551989
# 9 ===========================================
# AL1L1_MOUSE 9
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 9
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 9
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 9
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 9
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 9
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 9
# 15
# ATPB_MOUSE True
# BIP_MOUSE 9
# 8
# BIP_MOUSE True
# CAH3_MOUSE 9
# 11
# CAH3_MOUSE True
# CATA_MOUSE 9
# 11
# CATA_MOUSE True
# CPSM_MOUSE 9
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 9
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 9
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 9
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 9
# 9
# ECHA_MOUSE True
# EF2_MOUSE 9
# 5
# EF2_MOUSE True
# ENOA_MOUSE 9
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 9
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 9
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 9
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 9
# 7
# FAAA_MOUSE True
# FAS_MOUSE 9
# 13
# FAS_MOUSE True
# GRP75_MOUSE 9
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 9
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 9
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 9
# 8
# PGM1_MOUSE True
# PYC_MOUSE 9
# 9
# PYC_MOUSE True
# PYGL_MOUSE 9
# 8
# PYGL_MOUSE True
# RGN_MOUSE 9
# 6
# RGN_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.4027075451390345
# d= 1.9401342701901485
# e= 3.0359445038417334
# f= 0.0793067981793357
# g= 1.13335754757139
# h= 1.0971477709395236
# i= 0.04612975482292267
# k= 0.0
# l= 0.5954392498508122
# m= 0.04871492682894376
# n= 0.5774496511181264
# p= 1.3445484638139984
# q= 2.657713597891151
# r= 1.0351356704206482
# s= 1.2425118674217197
# t= 0.04546125933120169
# v= 0.3864396057997244
# w= 0.030108067894468394
# y= 0.3595991480344366
#
# stats 8.637792909847343 8.39144310863726 2.640330775438636
# 13 ===========================================
# AL1L1_MOUSE 13
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 13
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 13
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 13
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 13
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 13
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 13
# 15
# ATPB_MOUSE True
# BIP_MOUSE 13
# 8
# BIP_MOUSE True
# CAH3_MOUSE 13
# 11
# CAH3_MOUSE True
# CATA_MOUSE 13
# 11
# CATA_MOUSE True
# CPSM_MOUSE 13
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 13
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 13
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 13
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 13
# 9
# ECHA_MOUSE True
# EF2_MOUSE 13
# 5
# EF2_MOUSE True
# ENOA_MOUSE 13
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 13
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 13
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 13
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 13
# 7
# FAAA_MOUSE True
# FAS_MOUSE 13
# 13
# FAS_MOUSE True
# GRP75_MOUSE 13
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 13
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 13
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 13
# 8
# PGM1_MOUSE True
# PYC_MOUSE 13
# 9
# PYC_MOUSE True
# PYGL_MOUSE 13
# 8
# PYGL_MOUSE True
# RGN_MOUSE 13
# 6
# RGN_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.293118235335475
# d= 1.9870910692001715
# e= 3.21035072196642
# f= 0.36676522166655556
# g= 1.2321688947781002
# h= 1.1248489664172328
# i= 0.24129762293022078
# k= 0.0
# l= 0.6408083577859628
# m= 0.21538878534259223
# n= 0.35698553510845504
# p= 1.1311026809696363
# q= 3.082708928953135
# r= 1.5536849955410608
# s= 1.3507036145718987
# t= 0.10501179972804316
# v= 0.4005502951746828
# w= 0.04619058583612001
# y= 0.6651392198159043
#
# stats 7.383865494996185 6.968442314577293 2.52655242273452
# 16 ===========================================
# AL1L1_MOUSE 16
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 16
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 16
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 16
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 16
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 16
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 16
# 15
# ATPB_MOUSE True
# BIP_MOUSE 16
# 8
# BIP_MOUSE True
# CAH3_MOUSE 16
# 11
# CAH3_MOUSE True
# CATA_MOUSE 16
# 11
# CATA_MOUSE True
# CPSM_MOUSE 16
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 16
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 16
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 16
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 16
# 9
# ECHA_MOUSE True
# EF2_MOUSE 16
# 5
# EF2_MOUSE True
# ENOA_MOUSE 16
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 16
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 16
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 16
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 16
# 7
# FAAA_MOUSE True
# FAS_MOUSE 16
# 13
# FAS_MOUSE True
# GRP75_MOUSE 16
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 16
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 16
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 16
# 8
# PGM1_MOUSE True
# PYC_MOUSE 16
# 9
# PYC_MOUSE True
# PYGL_MOUSE 16
# 8
# PYGL_MOUSE True
# RGN_MOUSE 16
# 6
# RGN_MOUSE True
# SAHH_MOUSE 16
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 16
# 8
# SARDH_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.294383337557692
# d= 2.1205343357933444
# e= 3.3884475857021568
# f= 0.218433314279861
# g= 1.1288003479181707
# h= 1.3315310753753749
# i= 0.314674831429515
# k= 0.0
# l= 0.6022389771541845
# m= 0.29418670328403357
# n= 0.7073194306655152
# p= 1.3776161516043839
# q= 3.072160982771661
# r= 1.6372846176276734
# s= 1.3996011763000982
# t= 0.17511741820831406
# v= 0.5688888396335803
# w= 0.0
# y= 0.6176242756559327
#
# stats 6.495548368113662 6.124744545275096 2.2848195489355705
# 21 ===========================================
# AL1L1_MOUSE 21
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 21
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 21
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 21
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 21
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 21
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 21
# 15
# ATPB_MOUSE True
# BIP_MOUSE 21
# 8
# BIP_MOUSE True
# CAH3_MOUSE 21
# 11
# CAH3_MOUSE True
# CATA_MOUSE 21
# 11
# CATA_MOUSE True
# CPSM_MOUSE 21
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 21
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 21
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 21
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 21
# 9
# ECHA_MOUSE True
# EF2_MOUSE 21
# 5
# EF2_MOUSE True
# ENOA_MOUSE 21
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 21
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 21
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 21
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 21
# 7
# FAAA_MOUSE True
# FAS_MOUSE 21
# 13
# FAS_MOUSE True
# GRP75_MOUSE 21
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 21
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 21
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 21
# 8
# PGM1_MOUSE True
# PYC_MOUSE 21
# 9
# PYC_MOUSE True
# PYGL_MOUSE 21
# 8
# PYGL_MOUSE True
# RGN_MOUSE 21
# 6
# RGN_MOUSE True
# SAHH_MOUSE 21
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 21
# 8
# SARDH_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.6731198673341914
# d= 2.3425074292112105
# e= 3.538708605407541
# f= 0.3348315397138472
# g= 1.4302418671911736
# h= 1.402180048227914
# i= 0.32131234951603
# k= 0.0
# l= 0.7755589690138694
# m= 0.005031915004196982
# n= 0.8294347682082023
# p= 1.5753051425778037
# q= 3.396738617485026
# r= 1.4388989886405767
# s= 1.465934797728856
# t= 0.1363240028468532
# v= 0.4798425538303113
# w= 0.0
# y= 0.7681889875002851
#
# stats 5.212261457781736 5.006320757856745 2.1486114831910776
# 24 ===========================================
# AL1L1_MOUSE 24
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 24
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 24
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 24
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 24
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 24
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 24
# 15
# ATPB_MOUSE True
# BIP_MOUSE 24
# 8
# BIP_MOUSE True
# CAH3_MOUSE 24
# 11
# CAH3_MOUSE True
# CATA_MOUSE 24
# 11
# CATA_MOUSE True
# CPSM_MOUSE 24
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 24
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 24
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 24
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 24
# 9
# ECHA_MOUSE True
# EF2_MOUSE 24
# 5
# EF2_MOUSE True
# ENOA_MOUSE 24
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 24
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 24
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 24
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 24
# 7
# FAAA_MOUSE True
# FAS_MOUSE 24
# 13
# FAS_MOUSE True
# GRP75_MOUSE 24
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 24
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 24
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 24
# 8
# PGM1_MOUSE True
# PYC_MOUSE 24
# 9
# PYC_MOUSE True
# PYGL_MOUSE 24
# 8
# PYGL_MOUSE True
# RGN_MOUSE 24
# 6
# RGN_MOUSE True
# SAHH_MOUSE 24
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 24
# 8
# SARDH_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.4718543866473084
# d= 2.169134187712841
# e= 3.319183540668531
# f= 0.08866870503081484
# g= 1.1817209250811553
# h= 1.2192269702894771
# i= 0.35829593239349955
# k= 0.0
# l= 0.8400362056650532
# m= 0.33258298193529773
# n= 0.6375114292253838
# p= 1.4103536164979913
# q= 3.151641007892111
# r= 1.5130084751860127
# s= 1.48478813628994
# t= 0.27537878951211536
# v= 0.5850905733329336
# w= 0.0
# y= 0.536103697121073
#
# stats 6.1106651685713596 5.893923940093895 2.2968651119605807
# 31 ===========================================
# AL1L1_MOUSE 31
# 17
# AL1L1_MOUSE True
# AL3A2_MOUSE 31
# 4
# AL3A2_MOUSE True
# ALDOB_MOUSE 31
# 8
# ALDOB_MOUSE True
# AMPL_MOUSE 31
# 7
# AMPL_MOUSE True
# ASSY_MOUSE 31
# 10
# ASSY_MOUSE True
# ATPA_MOUSE 31
# 15
# ATPA_MOUSE True
# ATPB_MOUSE 31
# 15
# ATPB_MOUSE True
# BIP_MOUSE 31
# 8
# BIP_MOUSE True
# CAH3_MOUSE 31
# 11
# CAH3_MOUSE True
# CATA_MOUSE 31
# 11
# CATA_MOUSE True
# CPSM_MOUSE 31
# 24
# CPSM_MOUSE True
# DHB4_MOUSE 31
# 6
# DHB4_MOUSE True
# DHE3_MOUSE 31
# 6
# DHE3_MOUSE True
# DHSO_MOUSE 31
# 10
# DHSO_MOUSE True
# ECHA_MOUSE 31
# 9
# ECHA_MOUSE True
# EF2_MOUSE 31
# 5
# EF2_MOUSE True
# ENOA_MOUSE 31
# 7
# ENOA_MOUSE True
# EST1D_MOUSE 31
# 5
# EST1D_MOUSE True
# ETFA_MOUSE 31
# 7
# ETFA_MOUSE True
# F16P1_MOUSE 31
# 10
# F16P1_MOUSE True
# FAAA_MOUSE 31
# 7
# FAAA_MOUSE True
# FAS_MOUSE 31
# 13
# FAS_MOUSE True
# GRP75_MOUSE 31
# 7
# GRP75_MOUSE True
# PBLD1_MOUSE 31
# 8
# PBLD1_MOUSE True
# PDIA1_MOUSE 31
# 9
# PDIA1_MOUSE True
# PGM1_MOUSE 31
# 8
# PGM1_MOUSE True
# PYC_MOUSE 31
# 9
# PYC_MOUSE True
# PYGL_MOUSE 31
# 8
# PYGL_MOUSE True
# RGN_MOUSE 31
# 6
# RGN_MOUSE True
# SAHH_MOUSE 31
# 7
# SAHH_MOUSE True
# SARDH_MOUSE 31
# 8
# SARDH_MOUSE True
# THIL_MOUSE 31
# 7
# THIL_MOUSE True
# ====> 19
#
# Values
#  a= 4
# c= 1.1144491898066369
# d= 2.652831398949756
# e= 3.7416282934916323
# f= 0.5162941689762687
# g= 1.386714782628185
# h= 1.3999210043817838
# i= 0.4500251842911072
# k= 0.0
# l= 0.5668047814951869
# m= 0.2586475344306715
# n= 1.0655847929972255
# p= 1.9035056025044514
# q= 3.541564824260651
# r= 1.8670211430315606
# s= 1.5882115397946233
# t= 0.0
# v= 0.680525058958436
# w= 0.0
# y= 0.9636970929472424
#
# stats 3.977021785801875 3.698369063968377 1.9188566172047141

# %%
evals2=np.array(e_vals)
trueval=[4.0,1.62,1.89,3.95,0.32,2.06,2.88,1.0,0.6,0.54,1.12,1.89,2.59,3.95,3.43,2.61,0.2,0.56,0.08,0.42]

# %%
for i in range(len(all_AAs1)):
    plt.scatter(range(8),evals2[:,i],c='k')
    plt.xticks(np.arange(8), times[3:])
    plt.title(all_AAs1[i]+f" ({trueval[i]})"+f"      t=31: ({evals2[:,i][-1]})")
#     plt.hlines(y=trueval[i],xmin=0,xmax=8)
    plt.show()

# %%
print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
# Out:
# Values
#  a= 4
# c= 1.1144491898066369
# d= 2.652831398949756
# e= 3.7416282934916323
# f= 0.5162941689762687
# g= 1.386714782628185
# h= 1.3999210043817838
# i= 0.4500251842911072
# k= 0.0
# l= 0.5668047814951869
# m= 0.2586475344306715
# n= 1.0655847929972255
# p= 1.9035056025044514
# q= 3.541564824260651
# r= 1.8670211430315606
# s= 1.5882115397946233
# t= 0.0
# v= 0.680525058958436
# w= 0.0
# y= 0.9636970929472424

# %%
print("proteins",len(proteins),"peptides",res.shape[0])
# Out:
# proteins 32 peptides 292

# %%
res=res.sort_values(by='dif')
res.head(20)
# Out:
#                  peptides True_NEH      e_NEH       dif
# 6          _EAYPGDVFYLH_2     19.0  18.775619  0.224381
# 1   _DILQDVLDADLSNEAFPF_2     34.0  34.315374  0.315374
# 7        _YDYEEVEAEGANK_2     31.0  30.679563  0.320437
# 5         _GEFQILLDALDK_2     21.0  20.642304  0.357696
# 1          _DYYFALAHTVR_3     18.0  17.610792  0.389208
# 4         _VAVVAGYGDVGK_2     19.0  18.498773  0.501227
# 2       _EKGEFQILLDALDK_2     25.0  24.383933  0.616067
# 3       _EKGEFQILLDALDK_3     25.0  24.383933  0.616067
# 8       _TIEYLEEVAVNFAK_3     25.0  24.148341  0.851659
# 5         _VFDYSEYWEGAR_2     23.0  22.102249  0.897751
# 2        _EGIPALDNFLDKL_2     21.0   20.06983   0.93017
# 1         _DSVVAGFQWATK_2     20.0  19.046667  0.953333
# 15         _TDVAAPFGGFK_2     18.0   17.04288   0.95712
# 1      _ADMVIEAVFEDLGVK_3     27.0  26.008981  0.991019
# 0      _ADMVIEAVFEDLGVK_2     27.0  26.008981  0.991019
# 6      _VLVGANFEEVAFDEK_2     29.0  27.970984  1.029016
# 12       _VALTGLTVAEYFR_2     20.0  18.970015  1.029985
# 0        _ADFAQAcQDAGVR_2     35.0  33.953797  1.046203
# 2         _DFDPAINEYLQR_2     25.0  23.921789  1.078211
# 3         _DFDPAINEYLQR_3     25.0  23.921789  1.078211

# %%
res.tail(20)
# Out:
#                   peptides True_NEH      e_NEH       dif
# 5     _TPIGSFLGSLASQPATK_3     32.0  24.986569  7.013431
# 6   _WSScNIFSTQDHAAAAIAK_3     43.0   35.95533   7.04467
# 1      _APSSSSVGISEWLDQK_2     34.0  26.864658  7.135342
# 12    _WLSTSIPEAQWQSSLAR_2     38.0  30.531766  7.468234
# 1   _ASQRPDVLTTGGGNPIGDK_3     36.0   28.41927   7.58073
# 0   _ASQRPDVLTTGGGNPIGDK_2     36.0   28.41927   7.58073
# 7     _HIGSSVEFDWcAVSSIR_3     33.0  25.292807  7.707193
# 4    _LFDHPEVPTPPESASVSR_3     40.0  32.225836  7.774164
# 8     _HLGIVGEcNIQFALHPT_3     32.0  24.170483  7.829517
# 5       _MRPDNSKPPVYGAcR_2     31.0   23.15522   7.84478
# 3    _GTSFEAAATSGGSASSEK_3     44.0  36.100753  7.899247
# 2    _GTSFEAAATSGGSASSEK_2     44.0  36.100753  7.899247
# 1    _ENALLPNWLHLPVGYHGR_4     33.0  25.031543  7.968457
# 3     _GNAGQTNYGFANSTMER_2     36.0  27.833963  8.166037
# 8   _QGIQVLVSTSNVSSLEGAR_2     39.0   30.50885   8.49115
# 7        _GIRPAINVGLSVSR_3     28.0  19.480891  8.519109
# 2        _HLMESPANEMTPTR_3     31.0  22.295106  8.704894
# 1        _HLMESPANEMTPTR_2     31.0  22.295106  8.704894
# 4        _DTNHGPQNHEAHLR_4     35.0  25.991003  9.008997
# 3        _DTNHGPQNHEAHLR_3     35.0  25.991003  9.008997

# %%
temp=pd.DataFrame(coefficients)
temp.columns=all_AAs1
temp
# Out:
#             a         c         d         e         f         g         h  \
# 0   -0.400000 -1.200000  0.000000 -0.200000  0.000000 -1.200000 -1.200000
# 1   -0.028985 -0.014493  0.000000 -0.014493  0.000000 -0.014493 -0.014493
# 2   -0.520000  1.000000  0.000000  0.160000  0.000000 -0.680000  1.000000
# 3    2.166667  0.000000 -0.833333  0.166667  0.000000  2.000000  0.000000
# 4   -1.166406  0.000000  1.000000  1.000000 -1.083203 -2.166406  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 246 -0.846154  0.000000  0.000000  0.000000  1.000000  1.000000  0.000000
# 247  0.916666  0.000000 -0.541667 -1.083334 -1.083334 -1.625001  0.000000
# 248  1.104373  0.000000  1.000000 -0.686880  2.000000  1.208746  0.000000
# 249 -3.224135  0.000000 -2.112067  3.000000 -4.224135 -2.224135  0.000000
# 250  0.642140 -0.678930  1.000000 -0.678930  2.000000  0.642140  0.000000
#
#             i         k         l         m         n         p         q  \
# 0    0.800000 -0.200000  1.000000 -1.200000 -1.400000  1.000000  0.000000
# 1   -0.014493 -0.014493  0.000000 -0.014493 -0.028985  0.000000  0.000000
# 2   -0.680000  0.160000 -0.840000  1.000000  2.000000  0.000000 -0.840000
# 3    2.000000  1.000000  0.166667  0.000000  0.000000  0.000000 -0.666666
# 4   -1.083203 -1.083203 -1.166406  0.000000  0.000000 -2.166406  0.916797
# ..        ...       ...       ...       ...       ...       ...       ...
# 246  0.000000  0.076923 -0.846154  0.000000  2.000000 -1.846154  0.076923
# 247 -0.541667  0.458333  1.458333  0.000000  0.000000  2.000000  0.458333
# 248  0.104373  0.104373  1.000000  0.000000  0.000000 -1.791254 -0.791254
# 249  1.000000 -1.112067  0.000000  0.000000  0.000000 -0.112067  2.000000
# 250  0.000000  0.321070  0.000000  0.000000  0.000000  0.321070 -0.678930
#
#             r         s         t         v        w         y
# 0    1.000000  2.000000 -0.200000  3.000000  0.00000  0.000000
# 1    0.000000  0.000000 -0.014493  0.000000  0.00000  0.000000
# 2    0.000000  0.000000  0.160000  0.000000  0.00000  0.000000
# 3   -0.833333 -1.666666 -0.666666  0.000000  0.00000 -1.666666
# 4    1.000000 -1.249610 -0.166406  0.000000  0.00000  2.000000
# ..        ...       ...       ...       ...      ...       ...
# 246  0.000000  0.000000  0.153846  1.076923  0.00000  1.000000
# 247  0.000000  0.000000  2.000000  0.458333  0.00000  0.000000
# 248 -0.895627  0.000000 -0.895627  1.000000  0.00000 -0.895627
# 249  1.000000  0.000000 -1.112067 -2.112067  0.00000  1.000000
# 250  0.000000  0.000000  0.321070  0.321070 -0.67893  0.000000
#
# [251 rows x 20 columns]

# %%
# for c in range( len(coefficients)):
#     print(np.dot(coefficients[c],sol))
