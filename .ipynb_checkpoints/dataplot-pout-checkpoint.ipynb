# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations

# %%
os.listdir("data/")
# Out:
# ['pxt_neh.csv',
#  '_AAMLGQEDPPQHGLPR_3_13_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_16_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_1_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_21_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_24_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_2_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_31_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_3_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_6_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_7_FAS_MOUSE.csv',
#  '_AAMLGQEDPPQHGLPR_3_9_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_13_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_16_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_1_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_21_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_24_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_2_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_31_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_3_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_6_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_7_FAS_MOUSE.csv',
#  '_AcVDTALENLSTLK_2_9_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_13_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_16_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_1_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_21_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_24_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_2_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_31_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_3_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_6_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_7_FAS_MOUSE.csv',
#  '_DPETLLGYSMVGcQR_2_9_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_13_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_16_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_1_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_21_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_24_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_2_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_31_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_3_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_6_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_7_FAS_MOUSE.csv',
#  '_DTSFEQHVLLHTGGK_3_9_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_13_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_16_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_1_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_21_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_24_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_2_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_31_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_3_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_6_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_7_FAS_MOUSE.csv',
#  '_GILLDALFEEANDSWR_2_9_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_13_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_16_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_1_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_21_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_24_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_2_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_31_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_3_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_6_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_7_FAS_MOUSE.csv',
#  '_HTQPSSSGAQLcTVY_2_9_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_13_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_16_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_1_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_21_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_24_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_2_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_31_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_3_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_6_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_7_FAS_MOUSE.csv',
#  '_LKEDTQVADVTTSR_3_9_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_13_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_16_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_1_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_21_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_24_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_2_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_31_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_3_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_6_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_7_FAS_MOUSE.csv',
#  '_VYATILNAGTNTDGSK_2_9_FAS_MOUSE.csv']

# %%
data=pd.read_csv("data/_LKEDTQVADVTTSR_3_31_FAS_MOUSE.csv")
# data=pd.read_csv("data/_DTSFEQHVLLHTGGK_3_21_FAS_MOUSE.csv")
data.head()
# Out:
#    NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0
# 0   21  0.0477  0.014001    0.814094   0.794509      1.866310     1.970602
# 1   21  0.0478  0.013796    0.814094   0.794509      1.868626     1.970602
# 2   21  0.0479  0.013593    0.814094   0.794509      1.870944     1.970602
# 3   21  0.0480  0.013390    0.814094   0.794509      1.873261     1.970602
# 4   21  0.0481  0.013187    0.814094   0.794509      1.875579     1.970602

# %%
ph=1.5574E-4
ph
# Out:
# 0.00015574

# %%
# data["const"]=data.NEH*data.pxt
# data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
# data["new_neh"]=data.const/data.new_pxt
# data=data.sort_values(by="RMSE",ascending=True)
# data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]

# # data["temp"]= (data.new_neh*data.new_pxt)/( (1-ph)*(1-ph-data.new_pxt) )
# # data["temp2"]=(data["exp_t_A1/A0"]-data["theo_A1/A0"])

# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
# data.head(290)

# %%
data["const"]=data.NEH*data.pxt
data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
data["new_neh"]=data.const/data.new_pxt
data=data.sort_values(by=["RMSE"],ascending=True)
# data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]

# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
data.head(290)
# Out:
#       NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0  \
# 123    23  0.0494  0.004395    0.814094   0.794509      2.009728     1.970602
# 124    23  0.0495  0.004400    0.814094   0.794509      2.012274     1.970602
# 122    23  0.0493  0.004403    0.814094   0.794509      2.007182     1.970602
# 125    23  0.0496  0.004415    0.814094   0.794509      2.014821     1.970602
# 121    23  0.0492  0.004421    0.814094   0.794509      2.004637     1.970602
# ...   ...     ...       ...         ...        ...           ...          ...
# 879    34  0.0330  0.004969    0.814094   0.794509      1.974751     1.970602
# 173    24  0.0464  0.004970    0.814094   0.794509      1.982257     1.970602
# 566    29  0.0400  0.004971    0.814094   0.794509      2.022815     1.970602
# 1063   37  0.0313  0.004972    0.814094   0.794509      2.009990     1.970602
# 480    28  0.0399  0.004973    0.814094   0.794509      1.978096     1.970602
#
#          const   new_pxt     new_neh
# 123   1.136206  0.017246   65.881293
# 124   1.138506  0.015257   74.620866
# 122   1.133906  0.019235   58.949176
# 125   1.140806  0.013268   85.982078
# 121   1.131606  0.021224   53.316353
# ...        ...       ...         ...
# 879   1.121999  0.029532   37.992317
# 173   1.113605  0.036792   30.267838
# 566   1.160003 -0.003333 -347.987288
# 1063  1.158099 -0.001687 -686.669713
# 480   1.117203  0.033680   33.170780
#
# [290 rows x 10 columns]

# %%
# np.dot(data[["NEH","pxt"]][318],data[["new_pxt","new_neh"]][318])/(norm(data[["NEH","pxt"]][318])*norm(data[["new_pxt","new_neh"]][318]))

# %%
from matplotlib import pyplot as plt
plt.scatter(data.const,data.RMSE)
print(data[data.new_pxt<0].shape)
# Out:
# (512, 10)

# %%
tempdata=data[data.RMSE<3*min(data.RMSE)]
tempdata=tempdata[(tempdata.new_pxt>0) & (tempdata.new_neh>0) & (tempdata.new_neh<118)]
tempdata["pxt_dif"]=(abs((tempdata.pxt) - (tempdata.new_pxt)))**2 + (abs((tempdata.NEH) - (tempdata.new_neh)))**2 #(abs((tempdata.pxt) - (tempdata.new_pxt))) #
plt.scatter(tempdata.const,tempdata.RMSE)

# %%
tempdata.sort_values(by=["pxt_dif"]).head(25)
# Out:
#       NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0  \
# 1053   37  0.0303  0.005070    0.814094   0.794509      1.970589     1.970602
# 247    25  0.0442  0.005451    0.814094   0.794509      1.970567     1.970602
# 619    30  0.0371  0.005224    0.814094   0.794509      1.970346     1.970602
# 1413   44  0.0256  0.005026    0.814094   0.794509      1.970451     1.970602
# 66     22  0.0499  0.005738    0.814094   0.794509      1.969927     1.970602
# 327    26  0.0426  0.005350    0.814094   0.794509      1.971350     1.970602
# 108    23  0.0479  0.005549    0.814094   0.794509      1.971596     1.970602
