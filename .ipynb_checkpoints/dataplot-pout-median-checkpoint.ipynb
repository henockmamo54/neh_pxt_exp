# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations

# %%
# os.listdir("data/")

# %%
# data=pd.read_csv("C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AAMLGQEDPPQHGLPR_3_6_FAS_MOUSE.csv")
data=pd.read_csv("C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AVNTLNEALEFAN_2_24_CPSM_MOUSE.csv")
# data=pd.read_csv("data/_DTSFEQHVLLHTGGK_3_21_FAS_MOUSE.csv")
data.head()
# Out:
#    NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0  \
# 0   18  0.0494  0.020499    0.765601    0.77927      1.701315     1.794512
# 1   18  0.0495  0.020310    0.765601    0.77927      1.703308     1.794512
# 2   18  0.0496  0.020122    0.765601    0.77927      1.705301     1.794512
# 3   18  0.0497  0.019933    0.765601    0.77927      1.707294     1.794512
# 4   18  0.0498  0.019745    0.765601    0.77927      1.709288     1.794512
#
#    NH  T_NEH
# 0  97     27
# 1  97     27
# 2  97     27
# 3  97     27
# 4  97     27

# %%
ph=1.5574E-4
ph
# Out:
# 0.00015574

# %%
# data["const"]=data.NEH*data.pxt
# data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
# data["new_neh"]=data.const/data.new_pxt
# data=data.sort_values(by="RMSE",ascending=True)
# data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]

# # data["temp"]= (data.new_neh*data.new_pxt)/( (1-ph)*(1-ph-data.new_pxt) )
# # data["temp2"]=(data["exp_t_A1/A0"]-data["theo_A1/A0"])

# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
# data.head(290)

# %%
data["const"]=data.NEH*data.pxt
data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
data["new_neh"]=data.const/data.new_pxt
data=data.sort_values(by=["RMSE"],ascending=True)
# data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]

# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
data.head(290)
# Out:
#       NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0  \
# 603    27  0.0399  0.006443    0.765601    0.77927      1.888032     1.794512
# 668    28  0.0385  0.006443    0.765601    0.77927      1.887125     1.794512
# 791    30  0.0359  0.006443    0.765601    0.77927      1.883061     1.794512
# 535    26  0.0414  0.006443    0.765601    0.77927      1.888850     1.794512
# 730    29  0.0371  0.006444    0.765601    0.77927      1.883312     1.794512
# ...   ...     ...       ...         ...        ...           ...          ...
# 1489   44  0.0241  0.006782    0.765601    0.77927      1.852529     1.794512
# 844    31  0.0341  0.006782    0.765601    0.77927      1.860368     1.794512
# 1118   36  0.0294  0.006786    0.765601    0.77927      1.856404     1.794512
# 595    27  0.0391  0.006786    0.765601    0.77927      1.864611     1.794512
# 458    25  0.0422  0.006787    0.765601    0.77927      1.867438     1.794512
#
#       NH  T_NEH     const   new_pxt    new_neh
# 603   97     27  1.077303 -0.047351 -22.751544
# 668   97     27  1.078002 -0.048031 -22.444006
# 791   97     27  1.077001 -0.047057 -22.886968
# 535   97     27  1.076403 -0.046477 -23.160132
# 730   97     27  1.075901 -0.045989 -23.394928
# ...   ..    ...       ...       ...        ...
# 1489  97     27  1.060399 -0.030919 -34.295851
# 844   97     27  1.057100 -0.027713 -38.145017
# 1118  97     27  1.058399 -0.028975 -36.528078
# 595   97     27  1.055702 -0.026354 -40.058298
# 458   97     27  1.055003 -0.025675 -41.091085
#
# [290 rows x 12 columns]

# %%
# np.dot(data[["NEH","pxt"]][318],data[["new_pxt","new_neh"]][318])/(norm(data[["NEH","pxt"]][318])*norm(data[["new_pxt","new_neh"]][318]))

# %%
from matplotlib import pyplot as plt
plt.scatter(data.const,data.RMSE)
print(data[data.new_pxt<0].shape)
# Out:
# (550, 12)

# %%
tempdata=data[data.RMSE<2*min(data.RMSE)]
tempdata=tempdata[(tempdata.new_pxt>0) & (tempdata.new_neh>0) & (tempdata.new_neh<data.NH[0])]
tempdata["pxt_dif"]=(abs((tempdata.pxt) - (tempdata.new_pxt))) #(abs((tempdata.pxt) - (tempdata.new_pxt)))**2 + (abs((tempdata.NEH) - (tempdata.new_neh)))**2 
plt.scatter(tempdata.const,tempdata.RMSE)

# %%
tempdata.sort_values(by=["pxt_dif"]).head(25)
# Out:
#       NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0  \
# 571    27  0.0367  0.010948    0.765601    0.77927      1.794581     1.794512
# 357    24  0.0411  0.011250    0.765601    0.77927      1.794611     1.794512
# 1250   39  0.0257  0.010224    0.765601    0.77927      1.794663     1.794512
# 281    23  0.0428  0.011391    0.765601    0.77927      1.794349     1.794512
# 129    21  0.0467  0.011644    0.765601    0.77927      1.794677     1.794512
# 1389   42  0.0239  0.010141    0.765601    0.77927      1.794302     1.794512
# 78     20  0.0489  0.011844    0.765601    0.77927      1.794219     1.794512
# 431    25  0.0395  0.011185    0.765601    0.77927      1.794041     1.794512
# 824    31  0.0321  0.010684    0.765601    0.77927      1.794028     1.794512
# 1600   47  0.0214  0.010034    0.765601    0.77927      1.793718     1.794512
# 201    22  0.0447  0.011444    0.765601    0.77927      1.795349     1.794512
# 1102   36  0.0278  0.010302    0.765601    0.77927      1.795343     1.794512
# 940    33  0.0302  0.010597    0.765601    0.77927      1.793559     1.794512
# 637    28  0.0354  0.010947    0.765601    0.77927      1.793504     1.794512
# 1640   48  0.0210  0.009870    0.765601    0.77927      1.795546     1.794512
# 1344   41  0.0245  0.010073    0.765601    0.77927      1.795653     1.794512
# 502    26  0.0381  0.010947    0.765601    0.77927      1.795767     1.794512
# 1297   40  0.0251  0.010100    0.765601    0.77927      1.795774     1.794512
# 996    34  0.0294  0.010368    0.765601    0.77927      1.795804     1.794512
# 1560   46  0.0219  0.009898    0.765601    0.77927      1.795880     1.794512
# 702    29  0.0343  0.010675    0.765601    0.77927      1.795958     1.794512
# 883    32  0.0311  0.010696    0.765601    0.77927      1.793069     1.794512
# 501    26  0.0380  0.011170    0.765601    0.77927      1.792956     1.794512
# 200    22  0.0446  0.011637    0.765601    0.77927      1.792938     1.794512
# 763    30  0.0331  0.010840    0.765601    0.77927      1.792920     1.794512
#
#       NH  T_NEH     const   new_pxt    new_neh   pxt_dif
# 571   97     27  0.990901  0.036636  27.047267  0.000064
# 357   97     27  0.986403  0.041009  24.053524  0.000091
# 1250  97     27  1.002298  0.025557  39.217632  0.000143
# 281   97     27  0.984403  0.042952  22.918572  0.000152
# 129   97     27  0.980705  0.046548  21.068821  0.000153
# 1389  97     27  1.003799  0.024099  41.653178  0.000199
# 78    97     27  0.978005  0.049172  19.889532  0.000272
# 431   97     27  0.987502  0.039940  24.724632  0.000440
# 824   97     27  0.995099  0.032556  30.566226  0.000456
# 1600  97     27  1.005799  0.022155  45.398242  0.000755
# 201   97     27  0.983404  0.043924  22.388877  0.000776
# 1102  97     27  1.000799  0.027015  37.045614  0.000785
# 940   97     27  0.996599  0.031098  32.047231  0.000898
# 637   97     27  0.991201  0.036345  27.272154  0.000945
# 1640  97     27  1.007999  0.020017  50.358319  0.000983
# 1344  97     27  1.004499  0.023419  42.893376  0.001081
# 502   97     27  0.990602  0.036927  26.825896  0.001173
# 1297  97     27  1.003998  0.023905  41.999705  0.001195
# 996   97     27  0.999599  0.028182  35.469790  0.001218
# 1560  97     27  1.007399  0.020600  48.903562  0.001300
# 702   97     27  0.994700  0.032943  30.194455  0.001357
# 883   97     27  0.995198  0.032459  30.660210  0.001359
# 501   97     27  0.988002  0.039454  25.041606  0.001454
# 200   97     27  0.981204  0.046062  21.301676  0.001462
# 763   97     27  0.993000  0.034596  28.702559  0.001496

# %%
(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5))
# Out:
# 571     27.047267
# 357     24.053524
# 1250    39.217632
# 281     22.918572
# 129     21.068821
# Name: new_neh, dtype: float64

# %%
np.median(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5))
# Out:
# 24.053523645273867

# %%
# plt.scatter(range(0,6),[3.94E+06,6.30E+06,8.23E+06,6.51E+06,3.99E+06,3.33E+06])

# %%
# plt.scatter(range(0,6),[4.77E+07,9.92E+07,1.11E+08,9.49E+07,5.45E+07,2.81E+07])
