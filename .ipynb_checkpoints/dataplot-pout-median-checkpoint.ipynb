# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations

# %%
# os.listdir("data/")

# %%
# data=pd.read_csv("C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AAMLGQEDPPQHGLPR_3_6_FAS_MOUSE.csv")
data=pd.read_csv("C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AcVDTALENLSTLK_2_21_FAS_MOUSE.csv")
# data=pd.read_csv("data/_DTSFEQHVLLHTGGK_3_21_FAS_MOUSE.csv")
data.head()
# Out:
#    NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0  \
# 0   21  0.0492  0.007157    0.786871   0.776111      1.873888     1.982345
# 1   21  0.0493  0.007069    0.786871   0.776111      1.876212     1.982345
# 2   21  0.0494  0.006985    0.786871   0.776111      1.878536     1.982345
# 3   21  0.0495  0.006907    0.786871   0.776111      1.880862     1.982345
# 4   21  0.0496  0.006834    0.786871   0.776111      1.883187     1.982345
#
#     NH  T_NEH
# 0  107     23
# 1  107     23
# 2  107     23
# 3  107     23
# 4  107     23

# %%
ph=1.5574E-4
ph
# Out:
# 0.00015574

# %%
# data["const"]=data.NEH*data.pxt
# data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
# data["new_neh"]=data.const/data.new_pxt
# data=data.sort_values(by="RMSE",ascending=True)
# data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]

# # data["temp"]= (data.new_neh*data.new_pxt)/( (1-ph)*(1-ph-data.new_pxt) )
# # data["temp2"]=(data["exp_t_A1/A0"]-data["theo_A1/A0"])

# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
# data.head(290)

# %%
data["const"]=data.NEH*data.pxt
data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
data["new_neh"]=data.const/data.new_pxt
data=data.sort_values(by=["RMSE"],ascending=True)
# data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]

# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
data.head(20)
# Out:
#     NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0  \
# 21   22  0.0484  0.006522    0.786871   0.776111      1.906192     1.982345
# 22   22  0.0485  0.006525    0.786871   0.776111      1.908622     1.982345
# 20   22  0.0483  0.006527    0.786871   0.776111      1.903762     1.982345
# 23   22  0.0486  0.006535    0.786871   0.776111      1.911053     1.982345
# 19   22  0.0482  0.006539    0.786871   0.776111      1.901332     1.982345
# 24   22  0.0487  0.006551    0.786871   0.776111      1.913485     1.982345
# 18   22  0.0481  0.006558    0.786871   0.776111      1.898903     1.982345
# 25   22  0.0488  0.006575    0.786871   0.776111      1.915917     1.982345
# 17   22  0.0480  0.006584    0.786871   0.776111      1.896474     1.982345
# 48   23  0.0463  0.006595    0.786871   0.776111      1.903831     1.982345
# 49   23  0.0464  0.006597    0.786871   0.776111      1.906361     1.982345
# 47   23  0.0462  0.006601    0.786871   0.776111      1.901302     1.982345
# 50   23  0.0465  0.006606    0.786871   0.776111      1.908891     1.982345
# 26   22  0.0489  0.006606    0.786871   0.776111      1.918350     1.982345
# 46   23  0.0461  0.006615    0.786871   0.776111      1.898773     1.982345
# 16   22  0.0479  0.006617    0.786871   0.776111      1.894046     1.982345
# 51   23  0.0466  0.006623    0.786871   0.776111      1.911422     1.982345
# 45   23  0.0460  0.006636    0.786871   0.776111      1.896244     1.982345
# 27   22  0.0490  0.006644    0.786871   0.776111      1.920783     1.982345
# 52   23  0.0467  0.006648    0.786871   0.776111      1.913954     1.982345
#
#      NH  T_NEH     const   new_pxt    new_neh
# 21  107     23  1.064806  0.109008   9.768125
# 22  107     23  1.067006  0.107168   9.956418
# 20  107     23  1.062605  0.110849   9.586068
# 23  107     23  1.069206  0.105327  10.151291
# 19  107     23  1.060405  0.112689   9.409976
# 24  107     23  1.071406  0.103486  10.353095
# 18  107     23  1.058205  0.114530   9.239544
# 25  107     23  1.073605  0.101646  10.562209
# 17  107     23  1.056005  0.116371   9.074502
# 48  107     23  1.064905  0.108925   9.776490
# 49  107     23  1.067205  0.107001   9.973798
# 47  107     23  1.062605  0.110849   9.586032
# 50  107     23  1.069505  0.105077  10.178333
# 26  107     23  1.075805  0.099805  10.779035
# 46  107     23  1.060305  0.112774   9.402073
# 16  107     23  1.053805  0.118211   8.914601
# 51  107     23  1.071805  0.103152  10.390520
# 45  107     23  1.058005  0.114698   9.224269
# 27  107     23  1.078006  0.097965  11.004031
# 52  107     23  1.074105  0.101228  10.610752

# %%
# np.dot(data[["NEH","pxt"]][318],data[["new_pxt","new_neh"]][318])/(norm(data[["NEH","pxt"]][318])*norm(data[["new_pxt","new_neh"]][318]))

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(15,6))
plt.scatter(data.const,data.RMSE,s=1)
print(data[data.new_pxt<0].shape)
# Out:
# (503, 12)

# %%
plt.figure(figsize=(15,6))
tempdata=data[data.RMSE<2*min(data.RMSE)]
tempdata=tempdata[(tempdata.new_pxt>0) & (tempdata.new_neh>0) & (tempdata.new_neh<data.NH[0])]
tempdata["pxt_dif"]=(abs((tempdata.pxt) - (tempdata.new_pxt))) #(abs((tempdata.pxt) - (tempdata.new_pxt)))**2 + (abs((tempdata.NEH) - (tempdata.new_neh)))**2 
plt.scatter(tempdata.const,tempdata.RMSE,s=1)

# %%
tempdata.sort_values(by=["pxt_dif"]).head(25)
# Out:
#       NEH     pxt      RMSE  theo_A1/A0  exp_A1/A0  theo_t_A1/A0  exp_t_A1/A0  \
# 708    32  0.0360  0.010687    0.786871   0.776111      1.982272     1.982345
# 1536   47  0.0248  0.011708    0.786871   0.776111      1.982488     1.982345
# 79     23  0.0494  0.009506    0.786871   0.776111      1.982505     1.982345
# 572    30  0.0383  0.010464    0.786871   0.776111      1.982012     1.982345
# 1582   48  0.0243  0.011767    0.786871   0.776111      1.982696     1.982345
# 1077   38  0.0305  0.011211    0.786871   0.776111      1.982709     1.982345
# 351    27  0.0424  0.010146    0.786871   0.776111      1.982744     1.982345
# 1019   37  0.0313  0.011143    0.786871   0.776111      1.982767     1.982345
# 1187   40  0.0290  0.011289    0.786871   0.776111      1.981891     1.982345
# 1627   49  0.0238  0.011755    0.786871   0.776111      1.981878     1.982345
# 190    25  0.0456  0.009793    0.786871   0.776111      1.981725     1.982345
# 501    29  0.0396  0.010415    0.786871   0.776111      1.983006     1.982345
# 641    31  0.0371  0.010547    0.786871   0.776111      1.981665     1.982345
# 899    35  0.0330  0.010915    0.786871   0.776111      1.981664     1.982345
# 125    24  0.0474  0.009615    0.786871   0.776111      1.981463     1.982345
# 1240   41  0.0283  0.011313    0.786871   0.776111      1.981339     1.982345
# 427    28  0.0409  0.010182    0.786871   0.776111      1.981290     1.982345
# 1489   46  0.0253  0.011576    0.786871   0.776111      1.981254     1.982345
# 960    36  0.0321  0.010961    0.786871   0.776111      1.981173     1.982345
# 271    26  0.0439  0.009900    0.786871   0.776111      1.981064     1.982345
# 1132   39  0.0297  0.011164    0.786871   0.776111      1.981001     1.982345
# 1442   45  0.0259  0.011697    0.786871   0.776111      1.983736     1.982345
# 1292   42  0.0277  0.011539    0.786871   0.776111      1.983791     1.982345
# 272    26  0.0440  0.010081    0.786871   0.776111      1.983910     1.982345
# 838    34  0.0340  0.010982    0.786871   0.776111      1.983938     1.982345
#
#        NH  T_NEH     const   new_pxt    new_neh   pxt_dif
# 708   107     23  1.152001  0.036059  31.948067  0.000059
# 1536  107     23  1.165599  0.024683  47.223115  0.000117
# 79    107     23  1.136206  0.049273  23.059309  0.000127
# 572   107     23  1.149002  0.038568  29.791800  0.000268
# 1582  107     23  1.166399  0.024014  48.572561  0.000286
# 1077  107     23  1.158998  0.030205  38.371623  0.000295
# 351   107     23  1.144804  0.042080  27.205334  0.000320
# 1019  107     23  1.158099  0.030957  37.409309  0.000342
# 1187  107     23  1.159998  0.029368  39.498692  0.000368
# 1627  107     23  1.166199  0.024181  48.228133  0.000381
# 190   107     23  1.140005  0.046095  24.731710  0.000495
# 501   107     23  1.148403  0.039069  29.394199  0.000531
# 641   107     23  1.150102  0.037648  30.548882  0.000548
# 899   107     23  1.154999  0.033550  34.425838  0.000550
# 125   107     23  1.137606  0.048102  23.649701  0.000702
# 1240  107     23  1.160298  0.029117  39.849422  0.000817
# 427   107     23  1.145203  0.041746  27.432763  0.000846
# 1489  107     23  1.163798  0.026189  44.438314  0.000889
# 960   107     23  1.155599  0.033049  34.966539  0.000949
# 271   107     23  1.141404  0.044924  25.407402  0.001024
# 1132  107     23  1.158298  0.030790  37.619014  0.001090
# 1442  107     23  1.165498  0.024767  47.058920  0.001133
# 1292  107     23  1.163398  0.026524  43.862786  0.001176
# 272   107     23  1.144004  0.042749  26.761037  0.001251
# 838   107     23  1.156000  0.032713  35.337464  0.001287

# %%
(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5))
# Out:
# 141    26.890388
# 91     25.545407
# 92     26.628244
# 205    26.802115
# 140    25.746862
# Name: new_neh, dtype: float64

# %%
np.median(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5))
# Out:
# 24.7828794086218

# %%
# plt.scatter(range(0,6),[3.94E+06,6.30E+06,8.23E+06,6.51E+06,3.99E+06,3.33E+06])

# %%
# plt.scatter(range(0,6),[4.77E+07,9.92E+07,1.11E+08,9.49E+07,5.45E+07,2.81E+07])
