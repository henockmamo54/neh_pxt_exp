# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.decomposition import PCA
import scipy

# %%
ph=1.5574E-4
times=[1,2,3,6,7,9,13,16,21,24,31] 
pxt=[(x) for x in list(range(3,50,1))]
neh=range(1,120)

# %%
all_AAs=['a', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'p','q', 'r', 's', 't', 'v', 'w', 'y']
def charcount(pepSeq):
    res={key: 0 for key in all_AAs}     
    for c in pepSeq.lower():
        if c.isalpha():
            res[c]+=1
    return res

# %%
def sort_pep(peptidesinfo,peptides):
    temp={p: peptidesinfo[p]["T_NEH"] for i,p in enumerate(peptides)}
    temp=dict(sorted(temp.items(), key=lambda item: item[1])) 
    return list(temp.keys())

# %%
def getPeptiedsInfo(protien,time):
    
    peptides=[x.split(f'_{time}_')[0] for x in os.listdir(path) if (protien+".csv" in x) and (f"_{time}_" in x)]
    peptides=[x  for x in peptides if 'A' in x]
    peptidesinfo=dict()   
    

    for k in range(len(peptides)): 
        data=pd.read_csv(f"{path}{peptides[k]}_{time}_{protien}.csv")
        data["pxt_neh"]=data.NEH*data.pxt
        data=data[["NEH","pxt","RMSE","pxt_neh","T_NEH","NH"]] 
        minval=min(data.RMSE)

        data=data[data.RMSE==minval]

        peptidesinfo[peptides[k]]={"pxt_neh":float(data.pxt_neh),"T_NEH":float(data.T_NEH),"Seq":peptides[k],
                               "charcount":charcount(peptides[k])}
           
    visited=set()
    visited.add(peptides[0].split('_')[1])
    coefficients=[]
    peptides=sort_pep(peptidesinfo,peptides)
    for k in range(0,len(peptides)-1):
        if(peptides[k+1].split('_')[1] in visited):
            continue

        pep1=peptidesinfo[peptides[k]]
        pep2=peptidesinfo[peptides[k+1]]    
        visited.add(peptides[k].split('_')[1])

        r=pep1["pxt_neh"]/pep2["pxt_neh"]
        coefficients.append([pep1["charcount"][c]-r*pep2["charcount"][c] for c in all_AAs])
        
    return peptides,peptidesinfo,all_AAs,np.array(coefficients)

# %%
def compute_result(peptides,peptidesinfo,all_AAs,sol):
    t_neh,e_neh=[],[]
    for i in range (len(peptides)):
        pep1=peptidesinfo[peptides[i]]
        p_neh=0
        for index,c in enumerate(all_AAs): 
            p_neh+=(pep1["charcount"][c]*sol[index]) 
        t_neh.append(pep1["T_NEH"])
        e_neh.append(p_neh)

    res=pd.DataFrame([peptides,t_neh,e_neh])
    res=res.transpose()
    res.columns=["peptides","True_NEH","e_NEH"]
    res["dif"]=abs(res.True_NEH-res.e_NEH)
#     print(np.mean(res.dif),np.median(res.dif),np.std(res.dif))
    return res.sort_values(by='dif')

# %%
e_vals=[]
for time in times[3:]:
    print(time,"===========================================")
    a_val=4
    # proteins=["CPSM_MOUSE","FAS_MOUSE","DHB4_MOUSE","ASSY_MOUSE","ATPA_MOUSE","ATPB_MOUSE","BHMT1_MOUSE",
    #          "CLH1_MOUSE","DHE3_MOUSE","DHSO_MOUSE","ECHA_MOUSE",
    #          "G3P_MOUSE","HMCS2_MOUSE","HYES_MOUSE","MYH9_MOUSE","PYC_MOUSE","PYGL_MOUSE","SAHH_MOUSE",
    #          "SARDH_MOUSE","SBP1_MOUSE","THIM_MOUSE","TKT_MOUSE"]
    # proteins=pd.read_csv("H:/Warehouse/Data/liverpool/liver/6_23_2022_c/"+"Analyzed_Proteins_and_Their_Rates.csv").Proteins.unique()

    path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/second_r_liver/" 
    proteins=np.unique(["_".join(x.split('_')[4:]).replace('.csv','') for x in os.listdir(path) if ("_MOUSE.csv" in x)])

    coefficients=np.array([])
    _peptides,_peptidesinfo=[],[]
    for protine in proteins:
        try:
            peptides1,peptidesinfo1,all_AAs1,coefficients1=getPeptiedsInfo(protine,time) 
            
            if(coefficients.shape[0]==0):
                coefficients=coefficients1
            else:
                coefficients=np.concatenate((coefficients1,coefficients), axis=0)
            _peptides.append(peptides1)
            _peptidesinfo.append(peptidesinfo1)
        except:
            continue

    sol=list(scipy.optimize.nnls(coefficients[:,1:],-a_val*coefficients[:,0])[0])

    
    sol.insert(0,a_val) 
    
    print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))
    res=pd.DataFrame()
    for i in range(len(proteins)):
        res=pd.concat([res,compute_result(_peptides[i],_peptidesinfo[i],all_AAs1,sol)])

#     print("\nstats",np.mean(res.dif),np.median(res.dif),np.std(res.dif))    
    
    e_vals.append(sol)
# Out:
# 6 ===========================================
# AL1L1_MOUSE 6
# 17
# AL3A2_MOUSE 6
# 4
# ALDOB_MOUSE 6
# 8
# AMPL_MOUSE 6
# 7
# ASSY_MOUSE 6
# 10
# ATPA_MOUSE 6
# 15
# ATPB_MOUSE 6
# 15
# BIP_MOUSE 6
# 8
# CAH3_MOUSE 6
# 11
# CATA_MOUSE 6
# 11
# CPSM_MOUSE 6
# 24
# DHB4_MOUSE 6
# 6
# DHE3_MOUSE 6
# 6
# DHSO_MOUSE 6
# 10
# ECHA_MOUSE 6
# 9
# EF2_MOUSE 6
# 5
# ENOA_MOUSE 6
# 7
# EST1D_MOUSE 6
# 5
# ETFA_MOUSE 6
# 7
# F16P1_MOUSE 6
# 10
# FAAA_MOUSE 6
# 7
# FAS_MOUSE 6
# 13
# GRP75_MOUSE 6
# 7
# PBLD1_MOUSE 6
# 8
# PDIA1_MOUSE 6
# 9
# PGM1_MOUSE 6
# 8
# PYC_MOUSE 6
# 9
# PYGL_MOUSE 6
# 8
# RGN_MOUSE 6
# 6
# SAHH_MOUSE 6
# 7
# SARDH_MOUSE 6
# 8
# THIL_MOUSE 6
# 7
# THIM_MOUSE 6
# 6
# UD11_MOUSE 6
# 5
#
# Values
#  a= 4
# c= 1.232497713118259
# d= 1.8441078801961532
# e= 2.896263826176506
# f= 0.0
# g= 0.9598606459919001
# h= 0.6068013861899942
# i= 0.019433227597241254
# k= 0.0
# l= 0.2030120959526481
# m= 0.4144202466890291
# n= 0.4397546179204506
# p= 0.6947146964378872
# q= 2.1959025430492005
# r= 0.7497202916451076
# s= 0.7736086508823011
# t= 0.0
# v= 0.24907973305237413
# w= 0.0
# y= 0.13060824870549737
# 7 ===========================================
# AL1L1_MOUSE 7
# 17
# AL3A2_MOUSE 7
# 4
# ALDOB_MOUSE 7
# 8
# AMPL_MOUSE 7
# 7
# ASSY_MOUSE 7
# 10
# ATPA_MOUSE 7
# 15
# ATPB_MOUSE 7
# 15
# BIP_MOUSE 7
# 8
# CAH3_MOUSE 7
# 11
# CATA_MOUSE 7
# 11
# CPSM_MOUSE 7
# 24
# DHB4_MOUSE 7
# 6
# DHE3_MOUSE 7
# 6
# DHSO_MOUSE 7
# 10
# ECHA_MOUSE 7
# 9
# EF2_MOUSE 7
# 5
# ENOA_MOUSE 7
# 7
# EST1D_MOUSE 7
# 5
# ETFA_MOUSE 7
# 7
# F16P1_MOUSE 7
# 10
# FAAA_MOUSE 7
# 7
# FAS_MOUSE 7
# 13
# GRP75_MOUSE 7
# 7
# PBLD1_MOUSE 7
# 8
# PDIA1_MOUSE 7
# 9
# PGM1_MOUSE 7
# 8
# PYC_MOUSE 7
# 9
# PYGL_MOUSE 7
# 8
# RGN_MOUSE 7
# 6
# SAHH_MOUSE 7
# 7
# SARDH_MOUSE 7
# 8
# THIL_MOUSE 7
# 7
# THIM_MOUSE 7
# 6
# UD11_MOUSE 7
# 5
#
# Values
#  a= 4
# c= 1.7868004211033752
# d= 1.8345128486771305
# e= 3.0315529909226075
# f= 0.10259381156929917
# g= 1.2246624624386084
# h= 0.9882736719330725
# i= 0.2124812765631877
# k= 0.0
# l= 0.20974205807172772
# m= 0.2451721904182438
# n= 0.7702774773197985
# p= 1.353171121859509
# q= 2.5807942616775383
# r= 1.075423615850202
# s= 1.1610509338948345
# t= 0.0
# v= 0.4599137671226031
# w= 0.0
# y= 0.22825178090760415
# 9 ===========================================
# AL1L1_MOUSE 9
# 17
# AL3A2_MOUSE 9
# 4
# ALDOB_MOUSE 9
# 8
# AMPL_MOUSE 9
# 7
# ASSY_MOUSE 9
# 10
# ATPA_MOUSE 9
# 15
# ATPB_MOUSE 9
# 15
# BIP_MOUSE 9
# 8
# CAH3_MOUSE 9
# 11
# CATA_MOUSE 9
# 11
# CPSM_MOUSE 9
# 24
# DHB4_MOUSE 9
# 6
# DHE3_MOUSE 9
# 6
# DHSO_MOUSE 9
# 10
# ECHA_MOUSE 9
# 9
# EF2_MOUSE 9
# 5
# ENOA_MOUSE 9
# 7
# EST1D_MOUSE 9
# 5
# ETFA_MOUSE 9
# 7
# F16P1_MOUSE 9
# 10
# FAAA_MOUSE 9
# 7
# FAS_MOUSE 9
# 13
# GRP75_MOUSE 9
# 7
# PBLD1_MOUSE 9
# 8
# PDIA1_MOUSE 9
# 9
# PGM1_MOUSE 9
# 8
# PYC_MOUSE 9
# 9
# PYGL_MOUSE 9
# 8
# RGN_MOUSE 9
# 6
# SAHH_MOUSE 9
# 7
# SARDH_MOUSE 9
# 8
# THIL_MOUSE 9
# 7
# THIM_MOUSE 9
# 6
# UD11_MOUSE 9
# 5
#
# Values
#  a= 4
# c= 1.6102288957198463
# d= 1.8118848862254382
# e= 2.956285952120788
# f= 0.0
# g= 0.9757494146506916
# h= 0.8149446758717529
# i= 0.18617369974643114
# k= 0.0
# l= 0.2496213886057708
# m= 0.4927076790089753
# n= 0.6779162309123787
# p= 1.1491307329790337
# q= 2.4939063218341686
# r= 0.9634310503874843
# s= 1.1155858320001164
# t= 0.0
# v= 0.45740829490533147
# w= 0.0
# y= 0.017003577878425314
# 13 ===========================================
# AL1L1_MOUSE 13
# 17
# AL3A2_MOUSE 13
# 4
# ALDOB_MOUSE 13
# 8
# AMPL_MOUSE 13
# 7
# ASSY_MOUSE 13
# 10
# ATPA_MOUSE 13
# 15
# ATPB_MOUSE 13
# 15
# BIP_MOUSE 13
# 8
# CAH3_MOUSE 13
# 11
# CATA_MOUSE 13
# 11
# CPSM_MOUSE 13
# 24
# DHB4_MOUSE 13
# 6
# DHE3_MOUSE 13
# 6
# DHSO_MOUSE 13
# 10
# ECHA_MOUSE 13
# 9
# EF2_MOUSE 13
# 5
# ENOA_MOUSE 13
# 7
# EST1D_MOUSE 13
# 5
# ETFA_MOUSE 13
# 7
# F16P1_MOUSE 13
# 10
# FAAA_MOUSE 13
# 7
# FAS_MOUSE 13
# 13
# GRP75_MOUSE 13
# 7
# PBLD1_MOUSE 13
# 8
# PDIA1_MOUSE 13
# 9
# PGM1_MOUSE 13
# 8
# PYC_MOUSE 13
# 9
# PYGL_MOUSE 13
# 8
# RGN_MOUSE 13
# 6
# SAHH_MOUSE 13
# 7
# SARDH_MOUSE 13
# 8
# THIL_MOUSE 13
# 7
# THIM_MOUSE 13
# 6
# UD11_MOUSE 13
# 5
#
# Values
#  a= 4
# c= 1.7234480477291267
# d= 2.4433117108984304
# e= 3.708786276414103
# f= 0.16015165407971652
# g= 1.4477335603299883
# h= 1.0596584671263127
# i= 0.41281557003091734
# k= 0.0
# l= 0.4608269327609142
# m= 0.5334659257571012
# n= 0.7669976379069393
# p= 1.0323874954211938
# q= 3.1725480116010902
# r= 1.4721937311835502
# s= 1.4470575467797324
# t= 0.06718372252193781
# v= 0.6148895643075362
# w= 0.0
# y= 0.4107583361820998
# 16 ===========================================
# AL1L1_MOUSE 16
# 17
# AL3A2_MOUSE 16
# 4
# ALDOB_MOUSE 16
# 8
# AMPL_MOUSE 16
# 7
# ASSY_MOUSE 16
# 10
# ATPA_MOUSE 16
# 15
# ATPB_MOUSE 16
# 15
# BIP_MOUSE 16
# 8
# CAH3_MOUSE 16
# 11
# CATA_MOUSE 16
# 11
# CPSM_MOUSE 16
# 24
# DHB4_MOUSE 16
# 6
# DHE3_MOUSE 16
# 6
# DHSO_MOUSE 16
# 10
# ECHA_MOUSE 16
# 9
# EF2_MOUSE 16
# 5
# ENOA_MOUSE 16
# 7
# EST1D_MOUSE 16
# 5
# ETFA_MOUSE 16
# 7
# F16P1_MOUSE 16
# 10
# FAAA_MOUSE 16
# 7
# FAS_MOUSE 16
# 13
# GRP75_MOUSE 16
# 7
# PBLD1_MOUSE 16
# 8
# PDIA1_MOUSE 16
# 9
# PGM1_MOUSE 16
# 8
# PYC_MOUSE 16
# 9
# PYGL_MOUSE 16
# 8
# RGN_MOUSE 16
# 6
# SAHH_MOUSE 16
# 7
# SARDH_MOUSE 16
# 8
# THIL_MOUSE 16
# 7
# THIM_MOUSE 16
# 6
# UD11_MOUSE 16
# 5
#
# Values
#  a= 4
# c= 1.4557481693066658
# d= 2.197857083478384
# e= 3.5139425148698655
# f= 0.19087824174785423
# g= 1.3502649544592935
# h= 1.296857694469274
# i= 0.4161844381065624
# k= 0.0
# l= 0.5006558389991694
# m= 0.6514070523618242
# n= 0.8151645920151246
# p= 1.1914073071946396
# q= 3.1911977343660163
# r= 1.5711317881474756
# s= 1.4563777650854393
# t= 0.0
# v= 0.6167448150625612
# w= 0.0
# y= 0.3593242195722228
# 21 ===========================================
# AL1L1_MOUSE 21
# 17
# AL3A2_MOUSE 21
# 4
# ALDOB_MOUSE 21
# 8
# AMPL_MOUSE 21
# 7
# ASSY_MOUSE 21
# 10
# ATPA_MOUSE 21
# 15
# ATPB_MOUSE 21
# 15
# BIP_MOUSE 21
# 8
# CAH3_MOUSE 21
# 11
# CATA_MOUSE 21
# 11
# CPSM_MOUSE 21
# 24
# DHB4_MOUSE 21
# 6
# DHE3_MOUSE 21
# 6
# DHSO_MOUSE 21
# 10
# ECHA_MOUSE 21
# 9
# EF2_MOUSE 21
# 5
# ENOA_MOUSE 21
# 7
# EST1D_MOUSE 21
# 5
# ETFA_MOUSE 21
# 7
# F16P1_MOUSE 21
# 10
# FAAA_MOUSE 21
# 7
# FAS_MOUSE 21
# 13
# GRP75_MOUSE 21
# 7
# PBLD1_MOUSE 21
# 8
# PDIA1_MOUSE 21
# 9
# PGM1_MOUSE 21
# 8
# PYC_MOUSE 21
# 9
# PYGL_MOUSE 21
# 8
# RGN_MOUSE 21
# 6
# SAHH_MOUSE 21
# 7
# SARDH_MOUSE 21
# 8
# THIL_MOUSE 21
# 7
# THIM_MOUSE 21
# 6
# UD11_MOUSE 21
# 5
#
# Values
#  a= 4
# c= 2.1499694460115335
# d= 2.5226351318539963
# e= 3.727317142735503
# f= 0.2798755126002788
# g= 1.524142795195301
# h= 1.4807547910652685
# i= 0.48927223552210025
# k= 0.0
# l= 0.603705888107293
# m= 0.3957946562971203
# n= 1.1535389444380726
# p= 1.6546693951257767
# q= 3.217037357034056
# r= 1.460582771830579
# s= 1.3956464146715193
# t= 0.08919421894375006
# v= 0.6661606896947444
# w= 0.0
# y= 0.5478631473428174
# 24 ===========================================
# AL1L1_MOUSE 24
# 17
# AL3A2_MOUSE 24
# 4
# ALDOB_MOUSE 24
# 8
# AMPL_MOUSE 24
# 7
# ASSY_MOUSE 24
# 10
# ATPA_MOUSE 24
# 15
# ATPB_MOUSE 24
# 15
# BIP_MOUSE 24
# 8
# CAH3_MOUSE 24
# 11
# CATA_MOUSE 24
# 11
# CPSM_MOUSE 24
# 24
# DHB4_MOUSE 24
# 6
# DHE3_MOUSE 24
# 6
# DHSO_MOUSE 24
# 10
# ECHA_MOUSE 24
# 9
# EF2_MOUSE 24
# 5
# ENOA_MOUSE 24
# 7
# EST1D_MOUSE 24
# 5
# ETFA_MOUSE 24
# 7
# F16P1_MOUSE 24
# 10
# FAAA_MOUSE 24
# 7
# FAS_MOUSE 24
# 13
# GRP75_MOUSE 24
# 7
# PBLD1_MOUSE 24
# 8
# PDIA1_MOUSE 24
# 9
# PGM1_MOUSE 24
# 8
# PYC_MOUSE 24
# 9
# PYGL_MOUSE 24
# 8
# RGN_MOUSE 24
# 6
# SAHH_MOUSE 24
# 7
# SARDH_MOUSE 24
# 8
# THIL_MOUSE 24
# 7
# THIM_MOUSE 24
# 6
# UD11_MOUSE 24
# 5
#
# Values
#  a= 4
# c= 1.8302714506001008
# d= 2.5568210735512196
# e= 3.5802175906580374
# f= 0.32697909257910984
# g= 1.3930368512465812
# h= 1.2842539889437832
# i= 0.46873535652900683
# k= 0.0
# l= 0.5951333428252523
# m= 0.5518375570167395
# n= 0.8992091206615441
# p= 1.2317487449347913
# q= 3.191052812928445
# r= 1.504546243889764
# s= 1.6014742801701571
# t= 0.26937973458060793
# v= 0.6875475169117492
# w= 0.0
# y= 0.5211891648805805
# 31 ===========================================
# AL1L1_MOUSE 31
# 17
# AL3A2_MOUSE 31
# 4
# ALDOB_MOUSE 31
# 8
# AMPL_MOUSE 31
# 7
# ASSY_MOUSE 31
# 10
# ATPA_MOUSE 31
# 15
# ATPB_MOUSE 31
# 15
# BIP_MOUSE 31
# 8
# CAH3_MOUSE 31
# 11
# CATA_MOUSE 31
# 11
# CPSM_MOUSE 31
# 24
# DHB4_MOUSE 31
# 6
# DHE3_MOUSE 31
# 6
# DHSO_MOUSE 31
# 10
# ECHA_MOUSE 31
# 9
# EF2_MOUSE 31
# 5
# ENOA_MOUSE 31
# 7
# EST1D_MOUSE 31
# 5
# ETFA_MOUSE 31
# 7
# F16P1_MOUSE 31
# 10
# FAAA_MOUSE 31
# 7
# FAS_MOUSE 31
# 13
# GRP75_MOUSE 31
# 7
# PBLD1_MOUSE 31
# 8
# PDIA1_MOUSE 31
# 9
# PGM1_MOUSE 31
# 8
# PYC_MOUSE 31
# 9
# PYGL_MOUSE 31
# 8
# RGN_MOUSE 31
# 6
# SAHH_MOUSE 31
# 7
# SARDH_MOUSE 31
# 8
# THIL_MOUSE 31
# 7
# THIM_MOUSE 31
# 6
# UD11_MOUSE 31
# 5
#
# Values
#  a= 4
# c= 1.211542241490482
# d= 2.5239387193761162
# e= 3.461243896950947
# f= 0.21186284228283267
# g= 1.1159229625331908
# h= 1.3421793480441
# i= 0.3887463008614752
# k= 0.0
# l= 0.41777701666399125
# m= 0.3812393740766204
# n= 0.8116177308251439
# p= 1.6174462505125207
# q= 3.0558767289185846
# r= 1.494107102794045
# s= 1.4883246408352508
# t= 0.0
# v= 0.6157728449152433
# w= 0.49979734393898306
# y= 0.6039079327928845

# %%
evals2=np.array(e_vals)
trueval=[4.0,1.62,1.89,3.95,0.32,2.06,2.88,1.0,0.6,0.54,1.12,1.89,2.59,3.95,3.43,2.61,0.2,0.56,0.08,0.42]
# print("\nValues\n","\n".join([all_AAs1[index]+"= "+str(x) for index,x in enumerate(sol)]))

# %%
evals2.shape
# Out:
# (8, 20)

# %%
print("proteins",len(proteins),"peptides",res.shape[0])
# Out:
# proteins 34 peptides 303

# %%
ypred=[np.dot(coefficients[c],sol) for c in range(coefficients.shape[0])]
sigma=sum([ (0-x)**2 for x in ypred])/(len(ypred)-20-1)
cov=((sigma**2)*np.linalg.inv(np.matmul(coefficients.transpose(),coefficients)))
var=[cov[x][x] for x in range(20)]
ci_ub=[coefficients[i]+1.96*var[i] for i in range(20)] #, coefficients[i] has to be sol[i]
ci_lb=[coefficients[i]-1.96*var[i] for i in range(20)]
ci=[1.96*var[i] for i in range(20)]

temp=pd.DataFrame()
temp["AA"]=all_AAs1
temp["E_value"]=sol
temp["T_value"]=trueval
temp["var"]=var
temp["CI"]=ci
temp.sort_values(by="var")
# Out:
#    AA   E_value  T_value       var        CI
# 9   l  0.417777     0.54  0.075053  0.147104
# 17  v  0.615773     0.56  0.084506  0.165632
# 16  t  0.000000     0.20  0.105464  0.206710
# 5   g  1.115923     2.06  0.126332  0.247610
# 7   i  0.388746     1.00  0.127825  0.250537
# 11  n  0.811618     1.89  0.153811  0.301470
# 4   f  0.211863     0.32  0.172398  0.337899
# 15  s  1.488325     2.61  0.205834  0.403434
# 19  y  0.603908     0.42  0.245581  0.481339
# 12  p  1.617446     2.59  0.246035  0.482228
# 10  m  0.381239     1.12  0.294153  0.576539
# 6   h  1.342179     2.88  0.296460  0.581061
# 2   d  2.523939     1.89  0.366262  0.717873
# 0   a  4.000000     4.00  0.407301  0.798310
# 8   k  0.000000     0.60  0.485286  0.951160
# 1   c  1.211542     1.62  0.537231  1.052973
# 13  q  3.055877     3.95  0.548952  1.075946
# 3   e  3.461244     3.95  0.556416  1.090575
# 14  r  1.494107     3.43  0.635203  1.244997
# 18  w  0.499797     0.08  0.981084  1.922925

# %%
ypred=[np.dot(coefficients[c],sol) for c in range(coefficients.shape[0])]
sigma=sum([ (0-x)**2 for x in ypred])/(len(ypred)-20-1)
cov=((sigma**2)*np.linalg.inv(np.matmul(coefficients[:,1:].transpose(),coefficients[:,1:])))
var=[cov[x][x] for x in range(19)]
ci_ub=[coefficients[i+1]+1.96*var[i] for i in range(19)]
ci_lb=[coefficients[i+1]-1.96*var[i] for i in range(19)]
ci=[1.96*var[i] for i in range(19)]

temp=pd.DataFrame()
temp["AA"]=all_AAs1[1:]
temp["E_value"]=sol[1:]
temp["T_value"]=trueval[1:]
temp["var"]=var
temp["CI"]=ci
temp.sort_values(by="var")
# Out:
#    AA   E_value  T_value       var        CI
# 8   l  0.417777     0.54  0.070647  0.138469
# 16  v  0.615773     0.56  0.074419  0.145861
# 4   g  1.115923     2.06  0.093378  0.183021
# 15  t  0.000000     0.20  0.104868  0.205542
# 6   i  0.388746     1.00  0.123757  0.242563
# 10  n  0.811618     1.89  0.138186  0.270845
# 14  s  1.488325     2.61  0.146153  0.286461
# 11  p  1.617446     2.59  0.168176  0.329624
# 3   f  0.211863     0.32  0.171778  0.336684
# 1   d  2.523939     1.89  0.202031  0.395981
# 18  y  0.603908     0.42  0.237330  0.465166
# 2   e  3.461244     3.95  0.249331  0.488690
# 5   h  1.342179     2.88  0.251332  0.492611
# 9   m  0.381239     1.12  0.290476  0.569334
# 12  q  3.055877     3.95  0.301669  0.591271
# 7   k  0.000000     0.60  0.473729  0.928509
# 0   c  1.211542     1.62  0.499903  0.979811
# 13  r  1.494107     3.43  0.607924  1.191531
# 17  w  0.499797     0.08  0.976876  1.914677
