# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.decomposition import PCA

# %%
ph=1.5574E-4
times=[1,2,3,6,7,9,13,16,21,24,31]

# %%
def islinear(data):
    pca = PCA() # Compute PCA
    pca.fit_transform(data)
    eigenvalues = pca.explained_variance_ # Get eigenvalues
    eigenvalues = np.round(eigenvalues, 7) # Round off eigenvalues
    islin=len([x for x in eigenvalues if x >0])!=2
    print("is linear ",islin)
    return islin

# %%
path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/"
pept=[x.split('_1_')[0] for x in os.listdir(path) if ((".csv" in x) and ("_1_" in x)) ]

# %%
from sklearn.metrics import r2_score,mean_squared_error 
def estimateneh(const):
    
    if not const or len(const)==0:
        return None
    plt.scatter(times,const,c='k',s=120)
    plt.ylabel("px(t)*NEH")
    plt.xlabel("Time")
    
#     ========================

    res=[]
    for neh in range(100):
        sum_er=0 
        for i in range(len(times)):
            pxt=[(x/10000) for x in list(range(1,500,1))]
            diff=[abs(const[i]-neh*x) for x in pxt]
            sum_er+=min(diff)
        res.append(sum_er)
    
    # bet neh val    
    nehval=res.index(min(res))
    
    # compute the points for best neh val
    temp_const=[]
    for i in range(11):
        pxt=[(x/10000) for x in list(range(1,500,1))]
        diff=[abs(const[i]-nehval*x) for x in pxt]
        temp_const.append(pxt[diff.index(min(diff))]*nehval) 
    
    plt.scatter(times,temp_const,c='r',s=40)    
    plt.show()
    
    corr_matrix = np.corrcoef(const, temp_const)
    corr = corr_matrix[0,1]
    R_sq = corr**2
    r2=r2_score(const, temp_const)
    rmse=(mean_squared_error(const, temp_const))**0.5

    print("**************","RMSE=",rmse,"R square=",r2)
    print(temp_const)
    
    print("\n estimated NEH",nehval)
    plt.figure(figsize=(10,6))
    plt.scatter(range(100),res,s=10,c='k')
    plt.xlabel("NEH")
    plt.ylabel("Error")
    plt.show()
#     ========================
    
    return nehval

# %%
vals=[]
temp_kk=[]
temp_neh=[]
# protien="FAS_MOUSE"
protien="ACON_MOUSE"
for pep in pept:
    neh_coll=[]
    pxt_neh=[]
    for time in times:
        try:
            print(f"\n {pep} Time",time,"==================================>")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AAMLGQEDPPQHGLPR_3_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AcVDTALENLSTLK_2_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DAMLENQTPELFQDVNKPK_3_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DcMLGMEFSGR_2_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DPETLLGYSMVGcQR_2_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DTSFEQHVLLHTGGK_3_{time}_FAS_MOUSE.csv") 
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EGGFLLVHTVLK_2_{time}_FAS_MOUSE.csv") 
            data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/{pep}_{time}_{protien}.csv")

            data["const"]=data.NEH*data.pxt
            data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["exp_A1/A0"]) ) )
            data["new_neh"]=data.const/data.new_pxt
            data=data.sort_values(by=["RMSE"],ascending=True)
            data=data[data.NEH<=data.NH]

            plt.scatter(data.const,data.RMSE,s=1,c='k')
#             plt.hlines(y=2.5*min(data.RMSE),xmin=min(data.const),xmax=max(data.const),color='r')
            plt.show()
            
            print("pxt*NEH =",float(data[data.RMSE==min(data.RMSE)].const),"real_NEH=",data.T_NEH[0], "ratio =",float(data[data.RMSE==min(data.RMSE)].const/data.T_NEH[0]),"\n")
            print("vals",(data.loc[0,"exp_t_A1/A0"]-data.loc[0,"exp_A1/A0"])*(1-ph))
            
            pxt_neh.append(float(data[data.RMSE==min(data.RMSE)].const))
#             if(not islinear(data[["const","RMSE"]])):
            tempdata=data[data.RMSE<2.5*min(data.RMSE)]
            tempdata=tempdata[(tempdata.new_pxt>0) & (tempdata.new_neh>0) & (tempdata.new_neh<data.NH[0])]
            tempdata["pxt_dif"]=((abs((tempdata.pxt) - (tempdata.new_pxt)))**2 + (abs((tempdata.NEH) - (tempdata.new_neh)))**2)**0.5 #(abs((tempdata.pxt) - (tempdata.new_pxt))) 
            tempdata=tempdata.sort_values(by=["pxt_dif"])
#             print(data.T_NEH[0],np.array(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5)))
            neh_coll=neh_coll+list(np.array(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5)))
            
        except:
            print("Error",time)

#     print(neh_coll)
    print("\n",pxt_neh)
    temp_kk.append(pxt_neh)
    temp_neh.append(data.T_NEH[0])
    
#     plt.hist(neh_coll,color='k',bins=50)
#     print("\nTrue NEH =",data.T_NEH[0],"\t estimated NEHs median",np.median(neh_coll))
    eneh=estimateneh(pxt_neh)
    print("\nTrue NEH =",data.T_NEH[0],"\t estimated NEHs median",eneh)
#     vals.append([pep,data.T_NEH[0],np.median(neh_coll)])
    vals.append([pep,data.T_NEH[0],eneh])
    print("===============================================================\n")
    print("===============================================================\n")
    print("===============================================================\n")
# Out:
#  _ASNTSEVYFDGVK_2 Time 1 ==================================>
# pxt*NEH = 0.0264 real_NEH= 21 ratio = 0.001257142857142857
#
# vals 0.022327919897861242
#
#  _ASNTSEVYFDGVK_2 Time 2 ==================================>
# pxt*NEH = 0.0224 real_NEH= 21 ratio = 0.0010666666666666667
#
# vals 0.007548352906684917
#
#  _ASNTSEVYFDGVK_2 Time 3 ==================================>
# pxt*NEH = 0.0589 real_NEH= 21 ratio = 0.002804761904761905
#
# vals 0.04606603154047467
#
#  _ASNTSEVYFDGVK_2 Time 6 ==================================>
# pxt*NEH = 0.126 real_NEH= 21 ratio = 0.006
#
# vals 0.09267089195349847
#
#  _ASNTSEVYFDGVK_2 Time 7 ==================================>
# pxt*NEH = 0.162 real_NEH= 21 ratio = 0.007714285714285714
#
# vals 0.13298931251008347
#
#  _ASNTSEVYFDGVK_2 Time 9 ==================================>
# pxt*NEH = 0.231 real_NEH= 21 ratio = 0.011000000000000001
#
# vals 0.19172220883130617
#
#  _ASNTSEVYFDGVK_2 Time 13 ==================================>
# pxt*NEH = 0.362700093 real_NEH= 21 ratio = 0.017271433
#
# vals 0.2506903483617098
#
#  _ASNTSEVYFDGVK_2 Time 16 ==================================>
# pxt*NEH = 0.46999990599999997 real_NEH= 21 ratio = 0.022380947904761903
#
# vals 0.35151740691008565
#
#  _ASNTSEVYFDGVK_2 Time 21 ==================================>
# pxt*NEH = 0.5075998119999999 real_NEH= 21 ratio = 0.024171419619047615
#
# vals 0.3440822943554411
#
#  _ASNTSEVYFDGVK_2 Time 24 ==================================>
# pxt*NEH = 0.620399624 real_NEH= 21 ratio = 0.02954283923809524
#
# vals 0.4531119720159113
#
#  _ASNTSEVYFDGVK_2 Time 31 ==================================>
# pxt*NEH = 0.709799454 real_NEH= 21 ratio = 0.033799973999999997
#
# vals 0.5947085519260734
#
#  [0.0264, 0.0224, 0.0589, 0.126, 0.162, 0.231, 0.362700093, 0.46999990599999997, 0.5075998119999999, 0.620399624, 0.709799454]
# ************** RMSE= 0.00039077413754575445 R square= 0.9999972492388053
# [0.027, 0.0225, 0.058499999999999996, 0.126, 0.162, 0.231, 0.363, 0.46950000000000003, 0.5069999999999999, 0.621, 0.7095]
#
#  estimated NEH 15
# True NEH = 21 	 estimated NEHs median 15
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _ENMASLQSSPQHQELFR_3 Time 1 ==================================>
# pxt*NEH = 0.02909996 real_NEH= 45 ratio = 0.0006466657777777778
#
# vals 0.08480582956406237
#
#  _ENMASLQSSPQHQELFR_3 Time 2 ==================================>
# pxt*NEH = 0.111 real_NEH= 45 ratio = 0.0024666666666666665
#
# vals 0.10096911423282735
#
#  _ENMASLQSSPQHQELFR_3 Time 3 ==================================>
# pxt*NEH = 0.13019999999999998 real_NEH= 45 ratio = 0.002893333333333333
#
# vals 0.14492832079072387
#
#  _ENMASLQSSPQHQELFR_3 Time 6 ==================================>
# pxt*NEH = 0.309 real_NEH= 45 ratio = 0.006866666666666667
#
# vals 0.19784481093493206
#
#  _ENMASLQSSPQHQELFR_3 Time 7 ==================================>
# pxt*NEH = 0.34500000000000003 real_NEH= 45 ratio = 0.007666666666666667
#
# vals 0.2974522090997234
#
#  _ENMASLQSSPQHQELFR_3 Time 9 ==================================>
# pxt*NEH = 0.4284 real_NEH= 45 ratio = 0.00952
#
# vals 0.2636835914938029
#
#  _ENMASLQSSPQHQELFR_3 Time 13 ==================================>
# pxt*NEH = 0.649599768 real_NEH= 45 ratio = 0.014435550399999999
#
# vals 0.3638673826094236
#
#  _ENMASLQSSPQHQELFR_3 Time 16 ==================================>
# pxt*NEH = 0.82359942 real_NEH= 45 ratio = 0.018302209333333333
#
# vals 0.436647072207153
#
#  _ENMASLQSSPQHQELFR_3 Time 21 ==================================>
# pxt*NEH = 0.927999304 real_NEH= 45 ratio = 0.020622206755555556
#
# vals 0.5474670446312865
#
#  _ENMASLQSSPQHQELFR_3 Time 24 ==================================>
# pxt*NEH = 1.0799985 real_NEH= 45 ratio = 0.023999966666666667
#
# vals 0.6683407395643157
#
#  _ENMASLQSSPQHQELFR_3 Time 31 ==================================>
# pxt*NEH = 1.3349985 real_NEH= 45 ratio = 0.029666633333333334
#
# vals 0.9695022286171869
#
#  [0.02909996, 0.111, 0.13019999999999998, 0.309, 0.34500000000000003, 0.4284, 0.649599768, 0.82359942, 0.927999304, 1.0799985, 1.3349985]
# ************** RMSE= 0.0007079674733309042 R square= 0.9999970652791406
# [0.029, 0.1102, 0.13049999999999998, 0.31029999999999996, 0.3451, 0.4292, 0.6496, 0.8236, 0.928, 1.0788, 1.334]
#
#  estimated NEH 29
# True NEH = 45 	 estimated NEHs median 29
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _FGMAATLAGTMK_2 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 20 ratio = 0.00015000000000000001
#
# vals -0.001003331666535733
#
#  _FGMAATLAGTMK_2 Time 2 ==================================>
# pxt*NEH = 0.01159999 real_NEH= 20 ratio = 0.0005799994999999999
#
# vals 0.01665262039472941
#
#  _FGMAATLAGTMK_2 Time 3 ==================================>
# pxt*NEH = 0.054 real_NEH= 20 ratio = 0.0027
#
# vals 0.048738439238731474
#
#  _FGMAATLAGTMK_2 Time 6 ==================================>
# pxt*NEH = 0.1147 real_NEH= 20 ratio = 0.005735
#
# vals 0.10387305886389347
#
#  _FGMAATLAGTMK_2 Time 7 ==================================>
# pxt*NEH = 0.105 real_NEH= 20 ratio = 0.0052499999999999995
#
# vals 0.10146687773103095
#
#  _FGMAATLAGTMK_2 Time 9 ==================================>
# pxt*NEH = 0.171 real_NEH= 20 ratio = 0.00855
#
# vals 0.1539409216899424
#
#  _FGMAATLAGTMK_2 Time 13 ==================================>
# pxt*NEH = 0.2728 real_NEH= 20 ratio = 0.01364
#
# vals 0.2334907855767764
#
#  _FGMAATLAGTMK_2 Time 16 ==================================>
# pxt*NEH = 0.3567 real_NEH= 20 ratio = 0.017835
#
# vals 0.3275109844739469
#
#  _FGMAATLAGTMK_2 Time 21 ==================================>
# pxt*NEH = 0.38399952 real_NEH= 20 ratio = 0.019199976
#
# vals 0.391911900679007
#
#  _FGMAATLAGTMK_2 Time 24 ==================================>
# pxt*NEH = 0.46200154 real_NEH= 20 ratio = 0.023100077
#
# vals 0.46867009881010396
#
#  _FGMAATLAGTMK_2 Time 31 ==================================>
# pxt*NEH = 0.56949966 real_NEH= 20 ratio = 0.028474983
#
# vals 0.54722319150322
#
#  [0.003, 0.01159999, 0.054, 0.1147, 0.105, 0.171, 0.2728, 0.3567, 0.38399952, 0.46200154, 0.56949966]
# ************** RMSE= 0.0003060526867446793 R square= 0.9999972393599809
# [0.003, 0.012, 0.054, 0.114, 0.105, 0.171, 0.273, 0.35700000000000004, 0.384, 0.462, 0.57]
#
#  estimated NEH 15
# True NEH = 20 	 estimated NEHs median 15
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _NPFGNVGLLMGEAGK_2 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 26 ratio = 0.00011538461538461538
#
# vals 0.027120317179092253
#
#  _NPFGNVGLLMGEAGK_2 Time 2 ==================================>
# pxt*NEH = 0.04410017 real_NEH= 26 ratio = 0.0016961603846153846
#
# vals 0.06774119406273658
#
#  _NPFGNVGLLMGEAGK_2 Time 3 ==================================>
# pxt*NEH = 0.069 real_NEH= 26 ratio = 0.002653846153846154
#
# vals 0.08149189661806813
#
#  _NPFGNVGLLMGEAGK_2 Time 6 ==================================>
# pxt*NEH = 0.1632 real_NEH= 26 ratio = 0.0062769230769230775
#
# vals 0.1586717853745375
#
#  _NPFGNVGLLMGEAGK_2 Time 7 ==================================>
# pxt*NEH = 0.1815 real_NEH= 26 ratio = 0.0069807692307692305
#
# vals 0.16754020369988695
#
#  _NPFGNVGLLMGEAGK_2 Time 9 ==================================>
# pxt*NEH = 0.225 real_NEH= 26 ratio = 0.008653846153846154
#
# vals 0.20359133380647765
#
#  _NPFGNVGLLMGEAGK_2 Time 13 ==================================>
# pxt*NEH = 0.3399 real_NEH= 26 ratio = 0.013073076923076922
#
# vals 0.31359219506019537
#
#  _NPFGNVGLLMGEAGK_2 Time 16 ==================================>
# pxt*NEH = 0.428000107 real_NEH= 26 ratio = 0.016461542576923078
#
# vals 0.27748746370709093
#
#  _NPFGNVGLLMGEAGK_2 Time 21 ==================================>
# pxt*NEH = 0.4601 real_NEH= 26 ratio = 0.017696153846153848
#
# vals 0.34994349525236723
#
#  _NPFGNVGLLMGEAGK_2 Time 24 ==================================>
# pxt*NEH = 0.540599894 real_NEH= 26 ratio = 0.020792303615384613
#
# vals 0.43477087814385146
#
#  _NPFGNVGLLMGEAGK_2 Time 31 ==================================>
# pxt*NEH = 0.659199691 real_NEH= 26 ratio = 0.02535383426923077
#
# vals 0.5578090413406361
#
#  [0.003, 0.04410017, 0.069, 0.1632, 0.1815, 0.225, 0.3399, 0.428000107, 0.4601, 0.540599894, 0.659199691]
# ************** RMSE= 0.00042434055224399776 R square= 0.9999958106580805
# [0.0023, 0.0437, 0.069, 0.1633, 0.18170000000000003, 0.2254, 0.34040000000000004, 0.42779999999999996, 0.46, 0.5405, 0.6601]
#
#  estimated NEH 23
# True NEH = 26 	 estimated NEHs median 23
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _SGELAVQALDQFATVVEAK_2 Time 1 ==================================>
# pxt*NEH = 0.114 real_NEH= 42 ratio = 0.0027142857142857142
#
# vals 0.013389654561672579
#
#  _SGELAVQALDQFATVVEAK_2 Time 2 ==================================>
# pxt*NEH = 0.189 real_NEH= 42 ratio = 0.0045
#
# vals 0.040905488601650164
#
#  _SGELAVQALDQFATVVEAK_2 Time 3 ==================================>
# pxt*NEH = 0.198 real_NEH= 42 ratio = 0.004714285714285714
#
# vals 0.0672092123787542
#
#  _SGELAVQALDQFATVVEAK_2 Time 6 ==================================>
# pxt*NEH = 0.4329 real_NEH= 42 ratio = 0.010307142857142857
#
# vals 0.10872618002126481
#
#  _SGELAVQALDQFATVVEAK_2 Time 7 ==================================>
# pxt*NEH = 0.40950000000000003 real_NEH= 42 ratio = 0.00975
#
# vals 0.15989194660875025
#
#  _SGELAVQALDQFATVVEAK_2 Time 9 ==================================>
# pxt*NEH = 0.591599884 real_NEH= 42 ratio = 0.014085711523809523
#
# vals 0.20366218990831844
#
#  _SGELAVQALDQFATVVEAK_2 Time 13 ==================================>
# pxt*NEH = 0.785399524 real_NEH= 42 ratio = 0.018699988666666667
#
# vals 0.27863386380450855
#
#  _SGELAVQALDQFATVVEAK_2 Time 16 ==================================>
# pxt*NEH = 1.020799188 real_NEH= 42 ratio = 0.024304742571428572
#
# vals 0.3246664268147141
#
#  _SGELAVQALDQFATVVEAK_2 Time 21 ==================================>
# pxt*NEH = 1.1324985 real_NEH= 42 ratio = 0.026964250000000002
#
# vals 0.4540256464377401
#
#  _SGELAVQALDQFATVVEAK_2 Time 24 ==================================>
# pxt*NEH = 1.2674984999999999 real_NEH= 42 ratio = 0.03017853571428571
#
# vals 0.5835542802698576
#
#  _SGELAVQALDQFATVVEAK_2 Time 31 ==================================>
# pxt*NEH = 1.52999775 real_NEH= 42 ratio = 0.03642851785714286
#
# vals 0.7984391408479782
#
#  [0.114, 0.189, 0.198, 0.4329, 0.40950000000000003, 0.591599884, 0.785399524, 1.020799188, 1.1324985, 1.2674984999999999, 1.52999775]
# ************** RMSE= 0.0006685785778171256 R square= 0.9999978916484653
# [0.1152, 0.1888, 0.1984, 0.432, 0.4096, 0.592, 0.784, 1.0208, 1.1328, 1.2672, 1.5296]
#
#  estimated NEH 32
# True NEH = 42 	 estimated NEHs median 32
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _SGELAVQALDQFATVVEAK_3 Time 1 ==================================>
# pxt*NEH = 0.08839999999999999 real_NEH= 42 ratio = 0.0021047619047619044
#
# vals 0.03337353356778275
#
#  _SGELAVQALDQFATVVEAK_3 Time 2 ==================================>
# pxt*NEH = 0.147 real_NEH= 42 ratio = 0.0034999999999999996
#
# vals 0.046546492310599034
#
#  _SGELAVQALDQFATVVEAK_3 Time 3 ==================================>
# pxt*NEH = 0.156 real_NEH= 42 ratio = 0.0037142857142857142
#
# vals -0.006082506572402366
#
#  _SGELAVQALDQFATVVEAK_3 Time 6 ==================================>
# pxt*NEH = 0.36269999999999997 real_NEH= 42 ratio = 0.008635714285714285
#
# vals 0.04848182139708856
#
#  _SGELAVQALDQFATVVEAK_3 Time 7 ==================================>
# pxt*NEH = 0.3808 real_NEH= 42 ratio = 0.009066666666666667
#
# vals 0.10841169932054827
#
#  _SGELAVQALDQFATVVEAK_3 Time 9 ==================================>
# pxt*NEH = 0.5309999999999999 real_NEH= 42 ratio = 0.012642857142857141
#
# vals 0.07195331716594888
#
#  _SGELAVQALDQFATVVEAK_3 Time 13 ==================================>
# pxt*NEH = 0.761599643 real_NEH= 42 ratio = 0.018133324833333336
#
# vals 0.24631446588513817
#
#  _SGELAVQALDQFATVVEAK_3 Time 16 ==================================>
# pxt*NEH = 0.997599188 real_NEH= 42 ratio = 0.02375236161904762
#
# vals 0.3274072801230804
#
#  _SGELAVQALDQFATVVEAK_3 Time 21 ==================================>
# pxt*NEH = 1.1249985 real_NEH= 42 ratio = 0.02678567857142857
#
# vals 0.49406232513270154
#
#  _SGELAVQALDQFATVVEAK_3 Time 24 ==================================>
# pxt*NEH = 1.2899985 real_NEH= 42 ratio = 0.030714250000000002
#
# vals 0.6050670718985965
#
#  _SGELAVQALDQFATVVEAK_3 Time 31 ==================================>
# pxt*NEH = 1.52249775 real_NEH= 42 ratio = 0.03624994642857143
#
# vals 0.7429319181005936
#
#  [0.08839999999999999, 0.147, 0.156, 0.36269999999999997, 0.3808, 0.5309999999999999, 0.761599643, 0.997599188, 1.1249985, 1.2899985, 1.52249775]
# ************** RMSE= 0.0007941769180783272 R square= 0.9999972328759531
# [0.08839999999999999, 0.1462, 0.15639999999999998, 0.36379999999999996, 0.38079999999999997, 0.5304, 0.7615999999999999, 0.9962, 1.1254, 1.2886000000000002, 1.5231999999999999]
#
#  estimated NEH 34
# True NEH = 42 	 estimated NEHs median 34
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _SLSEGYPTAQHEK_2 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 30 ratio = 0.0001
#
# vals 0.0060396907717919866
#
#  _SLSEGYPTAQHEK_2 Time 2 ==================================>
# pxt*NEH = 0.05879992 real_NEH= 30 ratio = 0.0019599973333333334
#
# vals 0.08290376945026899
#
#  _SLSEGYPTAQHEK_2 Time 3 ==================================>
# pxt*NEH = 0.045 real_NEH= 30 ratio = 0.0015
#
# vals 0.008503471895341664
#
#  _SLSEGYPTAQHEK_2 Time 6 ==================================>
# pxt*NEH = 0.159 real_NEH= 30 ratio = 0.0053
#
# vals 0.08351970127424305
#
#  _SLSEGYPTAQHEK_2 Time 7 ==================================>
# pxt*NEH = 0.23700000000000002 real_NEH= 30 ratio = 0.0079
#
# vals 0.18189648294021704
#
#  _SLSEGYPTAQHEK_2 Time 9 ==================================>
# pxt*NEH = 0.20400000000000001 real_NEH= 30 ratio = 0.0068000000000000005
#
# vals 0.14028887477071392
#
#  _SLSEGYPTAQHEK_2 Time 13 ==================================>
# pxt*NEH = 0.4416 real_NEH= 30 ratio = 0.01472
#
# vals 0.30931528388668783
#
#  _SLSEGYPTAQHEK_2 Time 16 ==================================>
# pxt*NEH = 0.547199808 real_NEH= 30 ratio = 0.0182399936
#
# vals 0.41469495249800187
#
#  _SLSEGYPTAQHEK_2 Time 21 ==================================>
# pxt*NEH = 0.669599535 real_NEH= 30 ratio = 0.0223199845
#
# vals 0.5558371278242272
#
#  _SLSEGYPTAQHEK_2 Time 24 ==================================>
# pxt*NEH = 0.6839995249999999 real_NEH= 30 ratio = 0.022799984166666665
#
# vals 0.47523884748523876
#
#  _SLSEGYPTAQHEK_2 Time 31 ==================================>
# pxt*NEH = 0.883499163 real_NEH= 30 ratio = 0.0294499721
#
# vals 0.6845218038495369
#
#  [0.003, 0.05879992, 0.045, 0.159, 0.23700000000000002, 0.20400000000000001, 0.4416, 0.547199808, 0.669599535, 0.6839995249999999, 0.883499163]
# ************** RMSE= 0.0005195546157031599 R square= 0.999996750505303
# [0.0024000000000000002, 0.0576, 0.0456, 0.15839999999999999, 0.23760000000000003, 0.20400000000000001, 0.4416, 0.5472, 0.6696, 0.684, 0.8832]
#
#  estimated NEH 24
# True NEH = 30 	 estimated NEHs median 24
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _SLSEGYPTAQHEK_3 Time 1 ==================================>
# pxt*NEH = 0.019200000000000002 real_NEH= 30 ratio = 0.00064
#
# vals -0.023871825188828015
#
#  _SLSEGYPTAQHEK_3 Time 2 ==================================>
# pxt*NEH = 0.03 real_NEH= 30 ratio = 0.001
#
# vals -0.043540780769102096
#
#  _SLSEGYPTAQHEK_3 Time 3 ==================================>
# pxt*NEH = 0.09 real_NEH= 30 ratio = 0.003
#
# vals 0.03713567220990001
#
#  _SLSEGYPTAQHEK_3 Time 6 ==================================>
# pxt*NEH = 0.168 real_NEH= 30 ratio = 0.0056
#
# vals 0.08146182624085117
#
#  _SLSEGYPTAQHEK_3 Time 7 ==================================>
# pxt*NEH = 0.171 real_NEH= 30 ratio = 0.0057
#
# vals 0.05604071953723486
#
#  _SLSEGYPTAQHEK_3 Time 9 ==================================>
# pxt*NEH = 0.255 real_NEH= 30 ratio = 0.0085
#
# vals 0.1458228126481176
#
#  _SLSEGYPTAQHEK_3 Time 13 ==================================>
# pxt*NEH = 0.479999904 real_NEH= 30 ratio = 0.0159999968
#
# vals 0.24880201464090404
#
#  _SLSEGYPTAQHEK_3 Time 16 ==================================>
# pxt*NEH = 0.579599724 real_NEH= 30 ratio = 0.019319990800000002
#
# vals 0.3277373100791628
#
#  _SLSEGYPTAQHEK_3 Time 21 ==================================>
# pxt*NEH = 0.678899535 real_NEH= 30 ratio = 0.0226299845
#
# vals 0.508069189591386
#
#  _SLSEGYPTAQHEK_3 Time 24 ==================================>
# pxt*NEH = 0.7532994419999999 real_NEH= 30 ratio = 0.025109981399999995
#
# vals 0.5945231083211111
#
#  _SLSEGYPTAQHEK_3 Time 31 ==================================>
# pxt*NEH = 0.883499163 real_NEH= 30 ratio = 0.0294499721
#
# vals 0.6555551659043832
#
#  [0.019200000000000002, 0.03, 0.09, 0.168, 0.171, 0.255, 0.479999904, 0.579599724, 0.678899535, 0.7532994419999999, 0.883499163]
# ************** RMSE= 0.0005116952674066477 R square= 0.9999970387285002
# [0.0186, 0.031, 0.0899, 0.16740000000000002, 0.17049999999999998, 0.25420000000000004, 0.4805, 0.5797, 0.6789, 0.7533, 0.8835000000000001]
#
#  estimated NEH 31
# True NEH = 30 	 estimated NEHs median 31
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 1 ==================================>
# pxt*NEH = 0.003900001 real_NEH= 36 ratio = 0.00010833336111111111
#
# vals -0.004030457673888075
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 2 ==================================>
# pxt*NEH = 0.062 real_NEH= 36 ratio = 0.0017222222222222222
#
# vals 0.06918073052599161
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 3 ==================================>
# pxt*NEH = 0.0713 real_NEH= 36 ratio = 0.0019805555555555557
#
# vals 0.03123040114652572
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 6 ==================================>
# pxt*NEH = 0.195 real_NEH= 36 ratio = 0.005416666666666667
#
# vals 0.1002638613736161
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 7 ==================================>
# pxt*NEH = 0.222 real_NEH= 36 ratio = 0.006166666666666667
#
# vals 0.1261767020123327
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 9 ==================================>
# pxt*NEH = 0.303 real_NEH= 36 ratio = 0.008416666666666666
#
# vals 0.20672304971647953
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 13 ==================================>
# pxt*NEH = 0.4797 real_NEH= 36 ratio = 0.013325
#
# vals 0.24381565581412643
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 16 ==================================>
# pxt*NEH = 0.637199764 real_NEH= 36 ratio = 0.017699993444444444
#
# vals 0.41607916337558576
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 21 ==================================>
# pxt*NEH = 0.690199762 real_NEH= 36 ratio = 0.019172215611111112
#
# vals 0.48998925910754165
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 24 ==================================>
# pxt*NEH = 0.7972995239999999 real_NEH= 36 ratio = 0.022147208999999998
#
# vals 0.5621394173272497
#
#  _TGIGSGLSLSGIVHPELSR_3 Time 31 ==================================>
# pxt*NEH = 0.927999304 real_NEH= 36 ratio = 0.025777758444444444
#
# vals 0.6601359797797715
#
#  [0.003900001, 0.062, 0.0713, 0.195, 0.222, 0.303, 0.4797, 0.637199764, 0.690199762, 0.7972995239999999, 0.927999304]
# ************** RMSE= 0.0005847259982506797 R square= 0.9999964035966744
# [0.004, 0.062, 0.072, 0.194, 0.222, 0.302, 0.48, 0.6379999999999999, 0.6900000000000001, 0.7979999999999999, 0.9279999999999999]
#
#  estimated NEH 20
# True NEH = 36 	 estimated NEHs median 20
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _VPSENVLGEVGDGFK_2 Time 1 ==================================>
# pxt*NEH = 0.0339 real_NEH= 26 ratio = 0.001303846153846154
#
# vals 0.09073055155968558
#
#  _VPSENVLGEVGDGFK_2 Time 2 ==================================>
# pxt*NEH = 0.053200014 real_NEH= 26 ratio = 0.0020461543846153844
#
# vals 0.09549556724418365
#
#  _VPSENVLGEVGDGFK_2 Time 3 ==================================>
# pxt*NEH = 0.0891 real_NEH= 26 ratio = 0.003426923076923077
#
# vals 0.14201396874650454
#
#  _VPSENVLGEVGDGFK_2 Time 6 ==================================>
# pxt*NEH = 0.177 real_NEH= 26 ratio = 0.006807692307692307
#
# vals 0.17421167436762183
#
#  _VPSENVLGEVGDGFK_2 Time 7 ==================================>
# pxt*NEH = 0.21389999999999998 real_NEH= 26 ratio = 0.008226923076923076
#
# vals 0.20819038135271192
#
#  _VPSENVLGEVGDGFK_2 Time 9 ==================================>
# pxt*NEH = 0.279 real_NEH= 26 ratio = 0.010730769230769231
#
# vals 0.23609937741640813
#
#  _VPSENVLGEVGDGFK_2 Time 13 ==================================>
# pxt*NEH = 0.4558 real_NEH= 26 ratio = 0.01753076923076923
#
# vals 0.35746331697462697
#
#  _VPSENVLGEVGDGFK_2 Time 16 ==================================>
# pxt*NEH = 0.599199786 real_NEH= 26 ratio = 0.023046145615384615
#
# vals 0.3928837529940266
#
#  _VPSENVLGEVGDGFK_2 Time 21 ==================================>
# pxt*NEH = 0.626399784 real_NEH= 26 ratio = 0.024092299384615382
#
# vals 0.5224625690296503
#
#  _VPSENVLGEVGDGFK_2 Time 24 ==================================>
# pxt*NEH = 0.748999572 real_NEH= 26 ratio = 0.028807675846153846
#
# vals 0.5966713406858322
#
#  _VPSENVLGEVGDGFK_2 Time 31 ==================================>
# pxt*NEH = 0.8855993520000001 real_NEH= 26 ratio = 0.03406151353846154
#
# vals 0.7263288147699133
#
#  [0.0339, 0.053200014, 0.0891, 0.177, 0.21389999999999998, 0.279, 0.4558, 0.599199786, 0.626399784, 0.748999572, 0.8855993520000001]
# ************** RMSE= 0.00045024162157022686 R square= 0.9999975125984533
# [0.0342, 0.054, 0.0882, 0.1764, 0.2142, 0.279, 0.45539999999999997, 0.5994, 0.6264, 0.7487999999999999, 0.8856]
#
#  estimated NEH 18
# True NEH = 26 	 estimated NEHs median 18
# ===============================================================
#
# ===============================================================
#
# ===============================================================

# %%
res=pd.DataFrame(vals,columns=["Peptieds","True NEH","Estimated NEH"])
res["diff"]=abs(res["True NEH"]-res["Estimated NEH"])
res.sort_values(by="diff")
# Out:
#                  Peptieds  True NEH  Estimated NEH  diff
# 7        _SLSEGYPTAQHEK_3        30             31     1
# 3      _NPFGNVGLLMGEAGK_2        26             23     3
# 2         _FGMAATLAGTMK_2        20             15     5
# 0        _ASNTSEVYFDGVK_2        21             15     6
# 6        _SLSEGYPTAQHEK_2        30             24     6
# 5  _SGELAVQALDQFATVVEAK_3        42             34     8
# 9      _VPSENVLGEVGDGFK_2        26             18     8
# 4  _SGELAVQALDQFATVVEAK_2        42             32    10
# 1    _ENMASLQSSPQHQELFR_3        45             29    16
# 8  _TGIGSGLSLSGIVHPELSR_3        36             20    16

# %%
print( float(res[["diff"]].mean()),float(res[["diff"]].median()),float(res[["diff"]].std()))
# Out:
# 7.9 7.0 4.976611966656298

# %%
temp_kk
# Out:
# [[0.0264,
#   0.0224,
#   0.0589,
#   0.126,
#   0.162,
#   0.231,
#   0.362700093,
#   0.46999990599999997,
#   0.5075998119999999,
#   0.620399624,
#   0.709799454],
#  [0.02909996,
#   0.111,
#   0.13019999999999998,
#   0.309,
#   0.34500000000000003,
#   0.4284,
#   0.649599768,
#   0.82359942,
#   0.927999304,
#   1.0799985,
#   1.3349985],
#  [0.003,
#   0.01159999,
#   0.054,
#   0.1147,
#   0.105,
#   0.171,
#   0.2728,
#   0.3567,
#   0.38399952,
#   0.46200154,
#   0.56949966],
#  [0.003,
#   0.04410017,
#   0.069,
#   0.1632,
#   0.1815,
#   0.225,
#   0.3399,
#   0.428000107,
#   0.4601,
#   0.540599894,
#   0.659199691],
#  [0.114,
#   0.189,
#   0.198,
#   0.4329,
#   0.40950000000000003,
#   0.591599884,
#   0.785399524,
#   1.020799188,
#   1.1324985,
#   1.2674984999999999,
#   1.52999775],
#  [0.08839999999999999,
#   0.147,
#   0.156,
#   0.36269999999999997,
#   0.3808,
#   0.5309999999999999,
#   0.761599643,
#   0.997599188,
#   1.1249985,
#   1.2899985,
#   1.52249775],
#  [0.003,
#   0.05879992,
#   0.045,
#   0.159,
#   0.23700000000000002,
#   0.20400000000000001,
#   0.4416,
#   0.547199808,
#   0.669599535,
#   0.6839995249999999,
#   0.883499163],
#  [0.019200000000000002,
#   0.03,
#   0.09,
#   0.168,
#   0.171,
#   0.255,
#   0.479999904,
#   0.579599724,
#   0.678899535,
#   0.7532994419999999,
#   0.883499163],
#  [0.003900001,
#   0.062,
#   0.0713,
#   0.195,
#   0.222,
#   0.303,
#   0.4797,
#   0.637199764,
#   0.690199762,
#   0.7972995239999999,
#   0.927999304],
#  [0.0339,
#   0.053200014,
#   0.0891,
#   0.177,
#   0.21389999999999998,
#   0.279,
#   0.4558,
#   0.599199786,
#   0.626399784,
#   0.748999572,
#   0.8855993520000001]]

# %%
temp_neh
# Out:
# [21, 45, 20, 26, 42, 42, 30, 30, 36, 26]

# %%
# data=pd.read_csv("C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AAMLGQEDPPQHGLPR_3_24_FAS_MOUSE.csv")
data=pd.read_csv("C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DPETLLGYSMVGcQR_2_24_FAS_MOUSE.csv")
# data=pd.read_csv("data/_DTSFEQHVLLHTGGK_3_21_FAS_MOUSE.csv")
data.head()

# %%
ph

# %%
# data["const"]=data.NEH*data.pxt
# data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
# data["new_neh"]=data.const/data.new_pxt
# data=data.sort_values(by="RMSE",ascending=True)
# data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]

# # data["temp"]= (data.new_neh*data.new_pxt)/( (1-ph)*(1-ph-data.new_pxt) )
# # data["temp2"]=(data["exp_t_A1/A0"]-data["theo_A1/A0"])

# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
# data.head(290)

# %%
data["const"]=data.NEH*data.pxt
data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
data["new_neh"]=data.const/data.new_pxt
data=data.sort_values(by=["RMSE"],ascending=True)

data["test"]= 1-ph-data.pxt == (data.NEH*data.pxt)/( (1-ph)*(data["exp_t_A1/A0"]-data["exp_A1/A0"]) )

data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]



# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
data.head(20)

# %%
# np.dot(data[["NEH","pxt"]][318],data[["new_pxt","new_neh"]][318])/(norm(data[["NEH","pxt"]][318])*norm(data[["new_pxt","new_neh"]][318]))

from sklearn.decomposition import PCA

pca = PCA() # Compute PCA
pca.fit_transform(  data[["const","RMSE"]])
eigenvalues = pca.explained_variance_ # Get eigenvalues
eigenvalues = np.round(eigenvalues, 8) # Round off eigenvalues
eigenvalues

# %%
from matplotlib import pyplot as plt
# plt.figure(figsize=(15,6))
plt.scatter(data.const,data.RMSE,s=1)
print(data[data.new_pxt<0].shape)

# %%
tempdata=data[data.RMSE<2*min(data.RMSE)]
tempdata=tempdata[(tempdata.new_pxt>0) & (tempdata.new_neh>0) & (tempdata.new_neh<data.NH[0])]
tempdata["pxt_dif"]=(abs((tempdata.pxt) - (tempdata.new_pxt))) #(abs((tempdata.pxt) - (tempdata.new_pxt)))**2 + (abs((tempdata.NEH) - (tempdata.new_neh)))**2 
tempdata.sort_values(by=["pxt_dif"]).head(25)

# %%
plt.figure(figsize=(15,6))
plt.scatter(tempdata.const,tempdata.RMSE,s=1)

# %%
np.array(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5))

# %%
np.median(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5))

# %%
# plt.scatter(range(0,6),[3.94E+06,6.30E+06,8.23E+06,6.51E+06,3.99E+06,3.33E+06])

# %%
# plt.scatter(range(0,6),[4.77E+07,9.92E+07,1.11E+08,9.49E+07,5.45E+07,2.81E+07])

# %%
np.array([0.2475, 0.47250000000000003, 0.345, 1.3425, 0.9825, 1.2075, 1.0725, 1.1925000000000001, 1.1775, 1.1175, 1.335])/75

# %%
np.array([[0.16119999999999998, 0.3952, 0.41340000000000005, 0.9229999999999999, 0.9776, 0.9672, 1.0842, 1.183, 1.0608, 1.1258, 1.0972]])/26
