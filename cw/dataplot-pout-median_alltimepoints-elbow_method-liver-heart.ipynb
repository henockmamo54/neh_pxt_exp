# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.decomposition import PCA

# %%
ph=1.5574E-4
times=[1,2,3,6,7,9,13,16,21,24,31]

# %%
def islinear(data):
    pca = PCA() # Compute PCA
    pca.fit_transform(data)
    eigenvalues = pca.explained_variance_ # Get eigenvalues
    eigenvalues = np.round(eigenvalues, 7) # Round off eigenvalues
    islin=len([x for x in eigenvalues if x >0])!=2
    print("is linear ",islin)
    return islin

# %%
path="C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/"
pept=[x.split('_1_')[0] for x in os.listdir(path) if ((".csv" in x) and ("_1_" in x)) ]

# %%
from sklearn.metrics import r2_score,mean_squared_error 
def estimateneh(const):
    
    if not const or len(const)==0:
        return None
    plt.scatter(times,const,c='k',s=120)
    plt.ylabel("px(t)*NEH")
    plt.xlabel("Time")
    
#     ========================

    res=[]
    for neh in range(100):
        sum_er=0 
        for i in range(len(times)):
            pxt=[(x/10000) for x in list(range(1,500,1))]
            diff=[abs(const[i]-neh*x) for x in pxt]
            sum_er+=min(diff)
        res.append(sum_er)
    
    # bet neh val    
    nehval=res.index(min(res))
    
    # compute the points for best neh val
    temp_const=[]
    for i in range(11):
        pxt=[(x/10000) for x in list(range(1,500,1))]
        diff=[abs(const[i]-nehval*x) for x in pxt]
        temp_const.append(pxt[diff.index(min(diff))]*nehval) 
    
    plt.scatter(times,temp_const,c='r',s=40)    
    plt.show()
    
    corr_matrix = np.corrcoef(const, temp_const)
    corr = corr_matrix[0,1]
    R_sq = corr**2
    r2=r2_score(const, temp_const)
    rmse=(mean_squared_error(const, temp_const))**0.5

    print("**************","RMSE=",rmse,"R square=",r2)
    print(temp_const)
    
    print("\n estimated NEH",nehval)
    plt.figure(figsize=(10,6))
    plt.scatter(range(100),res,s=10,c='k')
    plt.xlabel("NEH")
    plt.ylabel("Error")
    plt.show()
#     ========================
    
    return nehval

# %%
vals=[]
temp_kk=[]
temp_neh=[]
# protien="FAS_MOUSE"
protien="ACON_MOUSE"
for pep in pept:
    neh_coll=[]
    pxt_neh=[]
    for time in times:
        try:
            print(f"\n {pep} Time",time,"==================================>")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AAMLGQEDPPQHGLPR_3_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AcVDTALENLSTLK_2_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DAMLENQTPELFQDVNKPK_3_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DcMLGMEFSGR_2_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DPETLLGYSMVGcQR_2_{time}_FAS_MOUSE.csv")
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DTSFEQHVLLHTGGK_3_{time}_FAS_MOUSE.csv") 
    #         data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_EGGFLLVHTVLK_2_{time}_FAS_MOUSE.csv") 
            data=pd.read_csv(f"C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/{pep}_{time}_{protien}.csv")

            data["const"]=data.NEH*data.pxt
            data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["exp_A1/A0"]) ) )
            data["new_neh"]=data.const/data.new_pxt
            data=data.sort_values(by=["RMSE"],ascending=True)
            data=data[data.NEH<=data.NH]

            plt.scatter(data.const,data.RMSE,s=1,c='k')
#             plt.hlines(y=2.5*min(data.RMSE),xmin=min(data.const),xmax=max(data.const),color='r')
            plt.show()
            
            print("pxt*NEH =",float(data[data.RMSE==min(data.RMSE)].const),"real_NEH=",data.T_NEH[0], "ratio =",float(data[data.RMSE==min(data.RMSE)].const/data.T_NEH[0]),"\n")
            print("vals",(data.loc[0,"exp_t_A1/A0"]-data.loc[0,"exp_A1/A0"])*(1-ph))
            
            pxt_neh.append(float(data[data.RMSE==min(data.RMSE)].const))
#             if(not islinear(data[["const","RMSE"]])):
            tempdata=data[data.RMSE<2.5*min(data.RMSE)]
            tempdata=tempdata[(tempdata.new_pxt>0) & (tempdata.new_neh>0) & (tempdata.new_neh<data.NH[0])]
            tempdata["pxt_dif"]=((abs((tempdata.pxt) - (tempdata.new_pxt)))**2 + (abs((tempdata.NEH) - (tempdata.new_neh)))**2)**0.5 #(abs((tempdata.pxt) - (tempdata.new_pxt))) 
            tempdata=tempdata.sort_values(by=["pxt_dif"])
#             print(data.T_NEH[0],np.array(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5)))
            neh_coll=neh_coll+list(np.array(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5)))
            
        except:
            print("Error",time)

#     print(neh_coll)
    print("\n",pxt_neh)
    temp_kk.append(pxt_neh)
    temp_neh.append(data.T_NEH[0])
    
#     plt.hist(neh_coll,color='k',bins=50)
#     print("\nTrue NEH =",data.T_NEH[0],"\t estimated NEHs median",np.median(neh_coll))
    eneh=estimateneh(pxt_neh)
    print("\nTrue NEH =",data.T_NEH[0],"\t estimated NEHs median",eneh)
#     vals.append([pep,data.T_NEH[0],np.median(neh_coll)])
    vals.append([pep,data.T_NEH[0],eneh])
    print("===============================================================\n")
    print("===============================================================\n")
    print("===============================================================\n")
# Out:
#  _cTTDHISAAGPWLK_3 Time 1 ==================================>
# pxt*NEH = 0.015 real_NEH= 24 ratio = 0.000625
#
# vals -0.006778435587338381
#
#  _cTTDHISAAGPWLK_3 Time 2 ==================================>
# pxt*NEH = 0.0352 real_NEH= 24 ratio = 0.0014666666666666667
#
# vals 0.013690644533387863
#
#  _cTTDHISAAGPWLK_3 Time 3 ==================================>
# pxt*NEH = 0.066 real_NEH= 24 ratio = 0.0027500000000000003
#
# vals 0.04510713299841228
#
#  _cTTDHISAAGPWLK_3 Time 6 ==================================>
# pxt*NEH = 0.124 real_NEH= 24 ratio = 0.005166666666666667
#
# vals 0.08020907852013727
#
#  _cTTDHISAAGPWLK_3 Time 7 ==================================>
# pxt*NEH = 0.138 real_NEH= 24 ratio = 0.005750000000000001
#
# vals 0.10942001058747515
#
#  _cTTDHISAAGPWLK_3 Time 9 ==================================>
# pxt*NEH = 0.189 real_NEH= 24 ratio = 0.007875
#
# vals 0.13654057309128345
#
#  _cTTDHISAAGPWLK_3 Time 13 ==================================>
# pxt*NEH = 0.243 real_NEH= 24 ratio = 0.010125
#
# vals 0.1784275468850872
#
#  _cTTDHISAAGPWLK_3 Time 16 ==================================>
# pxt*NEH = 0.32 real_NEH= 24 ratio = 0.013333333333333334
#
# vals 0.21787254383929627
#
#  _cTTDHISAAGPWLK_3 Time 21 ==================================>
# pxt*NEH = 0.372400098 real_NEH= 24 ratio = 0.015516670750000001
#
# vals 0.2860176613564104
#
#  _cTTDHISAAGPWLK_3 Time 24 ==================================>
# pxt*NEH = 0.42419999999999997 real_NEH= 24 ratio = 0.017675
#
# vals 0.30792460202266664
#
#  _cTTDHISAAGPWLK_3 Time 31 ==================================>
# pxt*NEH = 0.5399997999999999 real_NEH= 24 ratio = 0.022499991666666663
#
# vals 0.43602563097402997
#
#  [0.015, 0.0352, 0.066, 0.124, 0.138, 0.189, 0.243, 0.32, 0.372400098, 0.42419999999999997, 0.5399997999999999]
# ************** RMSE= 0.00033575944440842893 R square= 0.9999957884383524
# [0.015, 0.0345, 0.066, 0.1245, 0.138, 0.189, 0.243, 0.3195, 0.372, 0.4245, 0.5399999999999999]
#
#  estimated NEH 15
# True NEH = 24 	 estimated NEHs median 15
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _DINQEVYNFLATAGAK_3 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 31 ratio = 9.67741935483871e-05
#
# vals -0.003215645785837837
#
#  _DINQEVYNFLATAGAK_3 Time 2 ==================================>
# pxt*NEH = 0.003 real_NEH= 31 ratio = 9.67741935483871e-05
#
# vals 0.001945012241947837
#
#  _DINQEVYNFLATAGAK_3 Time 3 ==================================>
# pxt*NEH = 0.0132 real_NEH= 31 ratio = 0.0004258064516129032
#
# vals -0.0012139154811049262
#
#  _DINQEVYNFLATAGAK_3 Time 6 ==================================>
# pxt*NEH = 0.1147 real_NEH= 31 ratio = 0.0036999999999999997
#
# vals 0.04488261362024775
#
#  _DINQEVYNFLATAGAK_3 Time 7 ==================================>
# pxt*NEH = 0.111 real_NEH= 31 ratio = 0.0035806451612903226
#
# vals 0.04619421508044358
#
#  _DINQEVYNFLATAGAK_3 Time 9 ==================================>
# pxt*NEH = 0.189 real_NEH= 31 ratio = 0.0060967741935483875
#
# vals 0.1068556056283255
#
#  _DINQEVYNFLATAGAK_3 Time 13 ==================================>
# pxt*NEH = 0.28200000000000003 real_NEH= 31 ratio = 0.009096774193548388
#
# vals 0.1589384379071634
#
#  _DINQEVYNFLATAGAK_3 Time 16 ==================================>
# pxt*NEH = 0.37120000000000003 real_NEH= 31 ratio = 0.011974193548387097
#
# vals 0.24508780401015254
#
#  _DINQEVYNFLATAGAK_3 Time 21 ==================================>
# pxt*NEH = 0.456300117 real_NEH= 31 ratio = 0.014719358612903227
#
# vals 0.30331759252337925
#
#  _DINQEVYNFLATAGAK_3 Time 24 ==================================>
# pxt*NEH = 0.5474 real_NEH= 31 ratio = 0.017658064516129033
#
# vals 0.3787904032516022
#
#  _DINQEVYNFLATAGAK_3 Time 31 ==================================>
# pxt*NEH = 0.7020996429999999 real_NEH= 31 ratio = 0.02264837558064516
#
# vals 0.4318991788111552
#
#  [0.003, 0.003, 0.0132, 0.1147, 0.111, 0.189, 0.28200000000000003, 0.37120000000000003, 0.456300117, 0.5474, 0.7020996429999999]
# ************** RMSE= 0.0003275250082246326 R square= 0.9999979312311761
# [0.003, 0.003, 0.0135, 0.114, 0.111, 0.189, 0.28200000000000003, 0.3705, 0.456, 0.5475, 0.7020000000000001]
#
#  estimated NEH 15
# True NEH = 31 	 estimated NEHs median 15
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _FKLEAPDADELPR_3 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 30 ratio = 0.0001
#
# vals -0.009665070557161126
#
#  _FKLEAPDADELPR_3 Time 2 ==================================>
# pxt*NEH = 0.019799999999999998 real_NEH= 30 ratio = 0.0006599999999999999
#
# vals 0.007017547515143218
#
#  _FKLEAPDADELPR_3 Time 3 ==================================>
# pxt*NEH = 0.054400000000000004 real_NEH= 30 ratio = 0.0018133333333333335
#
# vals 0.04768428214309307
#
#  _FKLEAPDADELPR_3 Time 6 ==================================>
# pxt*NEH = 0.135 real_NEH= 30 ratio = 0.0045000000000000005
#
# vals 0.07998267268617916
#
#  _FKLEAPDADELPR_3 Time 7 ==================================>
# pxt*NEH = 0.1457 real_NEH= 30 ratio = 0.004856666666666666
#
# vals 0.0743763294031678
#
#  _FKLEAPDADELPR_3 Time 9 ==================================>
# pxt*NEH = 0.201 real_NEH= 30 ratio = 0.0067
#
# vals 0.12951191781777
#
#  _FKLEAPDADELPR_3 Time 13 ==================================>
# pxt*NEH = 0.297 real_NEH= 30 ratio = 0.009899999999999999
#
# vals 0.15708278213651594
#
#  _FKLEAPDADELPR_3 Time 16 ==================================>
# pxt*NEH = 0.395200104 real_NEH= 30 ratio = 0.0131733368
#
# vals 0.2331167637942641
#
#  _FKLEAPDADELPR_3 Time 21 ==================================>
# pxt*NEH = 0.4452 real_NEH= 30 ratio = 0.014839999999999999
#
# vals 0.2754294822824041
#
#  _FKLEAPDADELPR_3 Time 24 ==================================>
# pxt*NEH = 0.5617997880000001 real_NEH= 30 ratio = 0.018726659600000004
#
# vals 0.3527673148226269
#
#  _FKLEAPDADELPR_3 Time 31 ==================================>
# pxt*NEH = 0.720999588 real_NEH= 30 ratio = 0.0240333196
#
# vals 0.4725944395526382
#
#  [0.003, 0.019799999999999998, 0.054400000000000004, 0.135, 0.1457, 0.201, 0.297, 0.395200104, 0.4452, 0.5617997880000001, 0.720999588]
# ************** RMSE= 0.0003826765338915574 R square= 0.9999970946707255
# [0.003, 0.0195, 0.054, 0.13499999999999998, 0.14550000000000002, 0.201, 0.29700000000000004, 0.3945, 0.4455, 0.5625, 0.7214999999999999]
#
#  estimated NEH 15
# True NEH = 30 	 estimated NEHs median 15
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _FNPETDFLTGK_2 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 14 ratio = 0.0002142857142857143
#
# vals 0.005262381232768191
#
#  _FNPETDFLTGK_2 Time 2 ==================================>
# pxt*NEH = 0.003 real_NEH= 14 ratio = 0.0002142857142857143
#
# vals -0.01341996100826433
#
#  _FNPETDFLTGK_2 Time 3 ==================================>
# pxt*NEH = 0.008000002 real_NEH= 14 ratio = 0.0005714287142857144
#
# vals 0.01127187598652559
#
#  _FNPETDFLTGK_2 Time 6 ==================================>
# pxt*NEH = 0.054 real_NEH= 14 ratio = 0.003857142857142857
#
# vals 0.04110420326942324
#
#  _FNPETDFLTGK_2 Time 7 ==================================>
# pxt*NEH = 0.0608 real_NEH= 14 ratio = 0.004342857142857143
#
# vals 0.051982275135697635
#
#  _FNPETDFLTGK_2 Time 9 ==================================>
# pxt*NEH = 0.117 real_NEH= 14 ratio = 0.008357142857142858
#
# vals 0.11518278001981727
#
#  _FNPETDFLTGK_2 Time 13 ==================================>
# pxt*NEH = 0.138 real_NEH= 14 ratio = 0.009857142857142858
#
# vals 0.1039937114916444
#
#  _FNPETDFLTGK_2 Time 16 ==================================>
# pxt*NEH = 0.192 real_NEH= 14 ratio = 0.013714285714285715
#
# vals 0.1864226682777131
#
#  _FNPETDFLTGK_2 Time 21 ==================================>
# pxt*NEH = 0.21389999999999998 real_NEH= 14 ratio = 0.015278571428571428
#
# vals 0.20797858573134678
#
#  _FNPETDFLTGK_2 Time 24 ==================================>
# pxt*NEH = 0.2666 real_NEH= 14 ratio = 0.019042857142857143
#
# vals 0.2500371173874443
#
#  _FNPETDFLTGK_2 Time 31 ==================================>
# pxt*NEH = 0.331500085 real_NEH= 14 ratio = 0.0236785775
#
# vals 0.2998187851268238
#
#  [0.003, 0.003, 0.008000002, 0.054, 0.0608, 0.117, 0.138, 0.192, 0.21389999999999998, 0.2666, 0.331500085]
# ************** RMSE= 0.00020447605043779406 R square= 0.9999964047456151
# [0.0029999999999999996, 0.0029999999999999996, 0.008, 0.054000000000000006, 0.061000000000000006, 0.117, 0.138, 0.19199999999999998, 0.214, 0.267, 0.332]
#
#  estimated NEH 10
# True NEH = 14 	 estimated NEHs median 10
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _IVYGHLDDPANQEIER_2 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 36 ratio = 8.333333333333333e-05
#
# vals 0.02992933345457636
#
#  _IVYGHLDDPANQEIER_2 Time 2 ==================================>
# pxt*NEH = 0.0341 real_NEH= 36 ratio = 0.0009472222222222221
#
# vals 0.0220078607157755
#
#  _IVYGHLDDPANQEIER_2 Time 3 ==================================>
# pxt*NEH = 0.024 real_NEH= 36 ratio = 0.0006666666666666666
#
# vals 0.003728603346402708
#
#  _IVYGHLDDPANQEIER_2 Time 6 ==================================>
# pxt*NEH = 0.111 real_NEH= 36 ratio = 0.0030833333333333333
#
# vals 0.03173110470360327
#
#  _IVYGHLDDPANQEIER_2 Time 7 ==================================>
# pxt*NEH = 0.14100000000000001 real_NEH= 36 ratio = 0.003916666666666667
#
# vals 0.02906357404254925
#
#  _IVYGHLDDPANQEIER_2 Time 9 ==================================>
# pxt*NEH = 0.228 real_NEH= 36 ratio = 0.006333333333333333
#
# vals 0.11889276441012976
#
#  _IVYGHLDDPANQEIER_2 Time 13 ==================================>
# pxt*NEH = 0.34800000000000003 real_NEH= 36 ratio = 0.009666666666666667
#
# vals 0.14324493016470266
#
#  _IVYGHLDDPANQEIER_2 Time 16 ==================================>
# pxt*NEH = 0.452200119 real_NEH= 36 ratio = 0.012561114416666666
#
# vals 0.2352192572320753
#
#  _IVYGHLDDPANQEIER_2 Time 21 ==================================>
# pxt*NEH = 0.5474 real_NEH= 36 ratio = 0.015205555555555555
#
# vals 0.31044498420457634
#
#  _IVYGHLDDPANQEIER_2 Time 24 ==================================>
# pxt*NEH = 0.630699762 real_NEH= 36 ratio = 0.01751943783333333
#
# vals 0.48965896987935453
#
#  _IVYGHLDDPANQEIER_2 Time 31 ==================================>
# pxt*NEH = 0.84679942 real_NEH= 36 ratio = 0.02352220611111111
#
# vals 0.46791949082458456
#
#  [0.003, 0.0341, 0.024, 0.111, 0.14100000000000001, 0.228, 0.34800000000000003, 0.452200119, 0.5474, 0.630699762, 0.84679942]
# ************** RMSE= 0.0002696409072021909 R square= 0.9999989951433554
# [0.0034000000000000002, 0.034, 0.023799999999999998, 0.1105, 0.1411, 0.2278, 0.34850000000000003, 0.4522, 0.5474, 0.6307, 0.8465999999999999]
#
#  estimated NEH 17
# True NEH = 36 	 estimated NEHs median 17
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _IVYGHLDDPANQEIER_3 Time 1 ==================================>
# pxt*NEH = 0.024 real_NEH= 36 ratio = 0.0006666666666666666
#
# vals 0.0570037254839244
#
#  _IVYGHLDDPANQEIER_3 Time 2 ==================================>
# pxt*NEH = 0.039599999999999996 real_NEH= 36 ratio = 0.0010999999999999998
#
# vals 0.06419823378347225
#
#  _IVYGHLDDPANQEIER_3 Time 3 ==================================>
# pxt*NEH = 0.055799999999999995 real_NEH= 36 ratio = 0.00155
#
# vals 0.07159855450724041
#
#  _IVYGHLDDPANQEIER_3 Time 6 ==================================>
# pxt*NEH = 0.138 real_NEH= 36 ratio = 0.0038333333333333336
#
# vals 0.10451888848810095
#
#  _IVYGHLDDPANQEIER_3 Time 7 ==================================>
# pxt*NEH = 0.171 real_NEH= 36 ratio = 0.004750000000000001
#
# vals 0.12588967735202505
#
#  _IVYGHLDDPANQEIER_3 Time 9 ==================================>
# pxt*NEH = 0.216 real_NEH= 36 ratio = 0.006
#
# vals 0.11634786470968814
#
#  _IVYGHLDDPANQEIER_3 Time 13 ==================================>
# pxt*NEH = 0.3744 real_NEH= 36 ratio = 0.0104
#
# vals 0.20129235537439708
#
#  _IVYGHLDDPANQEIER_3 Time 16 ==================================>
# pxt*NEH = 0.46020011800000005 real_NEH= 36 ratio = 0.012783336611111112
#
# vals 0.22546217494995718
#
#  _IVYGHLDDPANQEIER_3 Time 21 ==================================>
# pxt*NEH = 0.5236000000000001 real_NEH= 36 ratio = 0.014544444444444447
#
# vals 0.27891483451594296
#
#  _IVYGHLDDPANQEIER_3 Time 24 ==================================>
# pxt*NEH = 0.6425997619999999 real_NEH= 36 ratio = 0.017849993388888888
#
# vals 0.3131954758988494
#
#  _IVYGHLDDPANQEIER_3 Time 31 ==================================>
# pxt*NEH = 0.893199304 real_NEH= 36 ratio = 0.02481109177777778
#
# vals 0.44125347688096256
#
#  [0.024, 0.039599999999999996, 0.055799999999999995, 0.138, 0.171, 0.216, 0.3744, 0.46020011800000005, 0.5236000000000001, 0.6425997619999999, 0.893199304]
# ************** RMSE= 0.00034102814533061874 R square= 0.9999983985671762
# [0.023399999999999997, 0.0396, 0.055799999999999995, 0.1386, 0.17099999999999999, 0.216, 0.37439999999999996, 0.46080000000000004, 0.5238, 0.6426000000000001, 0.8927999999999999]
#
#  estimated NEH 18
# True NEH = 36 	 estimated NEHs median 18
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _LQLLEPFDKWDGK_3 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 19 ratio = 0.00015789473684210527
#
# vals 0.024095666236297122
#
#  _LQLLEPFDKWDGK_3 Time 2 ==================================>
# pxt*NEH = 0.005899997 real_NEH= 19 ratio = 0.0003105261578947368
#
# vals 0.04807444357182131
#
#  _LQLLEPFDKWDGK_3 Time 3 ==================================>
# pxt*NEH = 0.015200004 real_NEH= 19 ratio = 0.0008000002105263158
#
# vals 0.044959581995310825
#
#  _LQLLEPFDKWDGK_3 Time 6 ==================================>
# pxt*NEH = 0.093 real_NEH= 19 ratio = 0.004894736842105263
#
# vals 0.12020049689511361
#
#  _LQLLEPFDKWDGK_3 Time 7 ==================================>
# pxt*NEH = 0.093 real_NEH= 19 ratio = 0.004894736842105263
#
# vals 0.09558104983381836
#
#  _LQLLEPFDKWDGK_3 Time 9 ==================================>
# pxt*NEH = 0.1271 real_NEH= 19 ratio = 0.0066894736842105255
#
# vals 0.11407500950578613
#
#  _LQLLEPFDKWDGK_3 Time 13 ==================================>
# pxt*NEH = 0.228 real_NEH= 19 ratio = 0.012
#
# vals 0.18580700206209874
#
#  _LQLLEPFDKWDGK_3 Time 16 ==================================>
# pxt*NEH = 0.303 real_NEH= 19 ratio = 0.01594736842105263
#
# vals 0.20920962077273295
#
#  _LQLLEPFDKWDGK_3 Time 21 ==================================>
# pxt*NEH = 0.3696 real_NEH= 19 ratio = 0.019452631578947367
#
# vals 0.2845479188065762
#
#  _LQLLEPFDKWDGK_3 Time 24 ==================================>
# pxt*NEH = 0.4104 real_NEH= 19 ratio = 0.021599999999999998
#
# vals 0.3314893331315304
#
#  _LQLLEPFDKWDGK_3 Time 31 ==================================>
# pxt*NEH = 0.535799886 real_NEH= 19 ratio = 0.028199993999999996
#
# vals 0.4286976054907841
#
#  [0.003, 0.005899997, 0.015200004, 0.093, 0.093, 0.1271, 0.228, 0.303, 0.3696, 0.4104, 0.535799886]
# ************** RMSE= 0.00030450165143916513 R square= 0.9999969645808994
# [0.003, 0.006, 0.015, 0.093, 0.093, 0.1275, 0.228, 0.303, 0.369, 0.41100000000000003, 0.5355000000000001]
#
#  estimated NEH 15
# True NEH = 19 	 estimated NEHs median 15
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _SDFDPGQDTYQHPPK_3 Time 1 ==================================>
# pxt*NEH = 0.01119999 real_NEH= 30 ratio = 0.000373333
#
# vals 0.05986869084621647
#
#  _SDFDPGQDTYQHPPK_3 Time 2 ==================================>
# pxt*NEH = 0.03890008 real_NEH= 30 ratio = 0.0012966693333333332
#
# vals 0.09491553884457533
#
#  _SDFDPGQDTYQHPPK_3 Time 3 ==================================>
# pxt*NEH = 0.054 real_NEH= 30 ratio = 0.0018
#
# vals 0.09404394230414444
#
#  _SDFDPGQDTYQHPPK_3 Time 6 ==================================>
# pxt*NEH = 0.126 real_NEH= 30 ratio = 0.0042
#
# vals 0.1274214228972716
#
#  _SDFDPGQDTYQHPPK_3 Time 7 ==================================>
# pxt*NEH = 0.1488 real_NEH= 30 ratio = 0.00496
#
# vals 0.12597940683386483
#
#  _SDFDPGQDTYQHPPK_3 Time 9 ==================================>
# pxt*NEH = 0.189 real_NEH= 30 ratio = 0.0063
#
# vals 0.1406435828449286
#
#  _SDFDPGQDTYQHPPK_3 Time 13 ==================================>
# pxt*NEH = 0.315 real_NEH= 30 ratio = 0.0105
#
# vals 0.22622694993960388
#
#  _SDFDPGQDTYQHPPK_3 Time 16 ==================================>
# pxt*NEH = 0.44099999999999995 real_NEH= 30 ratio = 0.014699999999999998
#
# vals 0.2880644287515954
#
#  _SDFDPGQDTYQHPPK_3 Time 21 ==================================>
# pxt*NEH = 0.4876 real_NEH= 30 ratio = 0.01625333333333333
#
# vals 0.3238447567309106
#
#  _SDFDPGQDTYQHPPK_3 Time 24 ==================================>
# pxt*NEH = 0.593599788 real_NEH= 30 ratio = 0.0197866596
#
# vals 0.3820706168273441
#
#  _SDFDPGQDTYQHPPK_3 Time 31 ==================================>
# pxt*NEH = 0.770399465 real_NEH= 30 ratio = 0.025679982166666667
#
# vals 0.5474512507349758
#
#  [0.01119999, 0.03890008, 0.054, 0.126, 0.1488, 0.189, 0.315, 0.44099999999999995, 0.4876, 0.593599788, 0.770399465]
# ************** RMSE= 0.0003316693229529975 R square= 0.9999981061015432
# [0.010799999999999999, 0.0396, 0.054, 0.126, 0.1494, 0.189, 0.31500000000000006, 0.441, 0.4878, 0.5940000000000001, 0.7704]
#
#  estimated NEH 18
# True NEH = 30 	 estimated NEHs median 18
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _SQFTITPGSEQIR_2 Time 1 ==================================>
# pxt*NEH = 0.0128 real_NEH= 27 ratio = 0.0004740740740740741
#
# vals 0.011250333831047472
#
#  _SQFTITPGSEQIR_2 Time 2 ==================================>
# pxt*NEH = 0.0434 real_NEH= 27 ratio = 0.0016074074074074074
#
# vals 0.04226948075009327
#
#  _SQFTITPGSEQIR_2 Time 3 ==================================>
# pxt*NEH = 0.0465 real_NEH= 27 ratio = 0.0017222222222222222
#
# vals 0.02588661592728324
#
#  _SQFTITPGSEQIR_2 Time 6 ==================================>
# pxt*NEH = 0.099 real_NEH= 27 ratio = 0.003666666666666667
#
# vals 0.051259669484746175
#
#  _SQFTITPGSEQIR_2 Time 7 ==================================>
# pxt*NEH = 0.1178 real_NEH= 27 ratio = 0.0043629629629629635
#
# vals 0.05978132862275747
#
#  _SQFTITPGSEQIR_2 Time 9 ==================================>
# pxt*NEH = 0.165 real_NEH= 27 ratio = 0.006111111111111111
#
# vals 0.09268461567325342
#
#  _SQFTITPGSEQIR_2 Time 13 ==================================>
# pxt*NEH = 0.252 real_NEH= 27 ratio = 0.009333333333333334
#
# vals 0.16499510349527677
#
#  _SQFTITPGSEQIR_2 Time 16 ==================================>
# pxt*NEH = 0.3193 real_NEH= 27 ratio = 0.011825925925925925
#
# vals 0.22776677686045194
#
#  _SQFTITPGSEQIR_2 Time 21 ==================================>
# pxt*NEH = 0.383800101 real_NEH= 27 ratio = 0.014214818555555555
#
# vals 0.26762840393838877
#
#  _SQFTITPGSEQIR_2 Time 24 ==================================>
# pxt*NEH = 0.484099897 real_NEH= 27 ratio = 0.017929625814814814
#
# vals 0.35196269732051494
#
#  _SQFTITPGSEQIR_2 Time 31 ==================================>
# pxt*NEH = 0.611999694 real_NEH= 27 ratio = 0.022666655333333334
#
# vals 0.47374263941246714
#
#  [0.0128, 0.0434, 0.0465, 0.099, 0.1178, 0.165, 0.252, 0.3193, 0.383800101, 0.484099897, 0.611999694]
# ************** RMSE= 0.00022360271474323085 R square= 0.9999985978592757
# [0.0126, 0.0434, 0.0462, 0.0994, 0.1176, 0.16519999999999999, 0.252, 0.31920000000000004, 0.3836, 0.4844, 0.6118]
#
#  estimated NEH 14
# True NEH = 27 	 estimated NEHs median 14
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _VAMSHFEPSEYIR_2 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 29 ratio = 0.00010344827586206896
#
# vals -0.035748946501709976
#
#  _VAMSHFEPSEYIR_2 Time 2 ==================================>
# pxt*NEH = 0.003 real_NEH= 29 ratio = 0.00010344827586206896
#
# vals -0.02437409646904042
#
#  _VAMSHFEPSEYIR_2 Time 3 ==================================>
# pxt*NEH = 0.0372 real_NEH= 29 ratio = 0.001282758620689655
#
# vals 0.014578311770227682
#
#  _VAMSHFEPSEYIR_2 Time 6 ==================================>
# pxt*NEH = 0.096 real_NEH= 29 ratio = 0.003310344827586207
#
# vals 0.05400423590562106
#
#  _VAMSHFEPSEYIR_2 Time 7 ==================================>
# pxt*NEH = 0.1271 real_NEH= 29 ratio = 0.004382758620689655
#
# vals 0.062106095763119075
#
#  _VAMSHFEPSEYIR_2 Time 9 ==================================>
# pxt*NEH = 0.177 real_NEH= 29 ratio = 0.0061034482758620685
#
# vals 0.08770812017471276
#
#  _VAMSHFEPSEYIR_2 Time 13 ==================================>
# pxt*NEH = 0.252 real_NEH= 29 ratio = 0.008689655172413793
#
# vals 0.18556160562647972
#
#  _VAMSHFEPSEYIR_2 Time 16 ==================================>
# pxt*NEH = 0.32239999999999996 real_NEH= 29 ratio = 0.011117241379310343
#
# vals 0.14813618109975865
#
#  _VAMSHFEPSEYIR_2 Time 21 ==================================>
# pxt*NEH = 0.41600010400000004 real_NEH= 29 ratio = 0.014344831172413794
#
# vals 0.28609370123254946
#
#  _VAMSHFEPSEYIR_2 Time 24 ==================================>
# pxt*NEH = 0.4576 real_NEH= 29 ratio = 0.015779310344827588
#
# vals 0.2986652856233459
#
#  _VAMSHFEPSEYIR_2 Time 31 ==================================>
# pxt*NEH = 0.5984997900000001 real_NEH= 29 ratio = 0.02063792379310345
#
# vals 0.35716018373335257
#
#  [0.003, 0.003, 0.0372, 0.096, 0.1271, 0.177, 0.252, 0.32239999999999996, 0.41600010400000004, 0.4576, 0.5984997900000001]
# ************** RMSE= 0.00021744467528672927 R square= 0.9999987082909457
# [0.003, 0.003, 0.0375, 0.096, 0.1275, 0.177, 0.252, 0.32249999999999995, 0.4155, 0.4575, 0.5984999999999999]
#
#  estimated NEH 15
# True NEH = 29 	 estimated NEHs median 15
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _VAMSHFEPSEYIR_3 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 29 ratio = 0.00010344827586206896
#
# vals 0.01602661699724658
#
#  _VAMSHFEPSEYIR_3 Time 2 ==================================>
# pxt*NEH = 0.0068 real_NEH= 29 ratio = 0.00023448275862068965
#
# vals 0.027585000979405486
#
#  _VAMSHFEPSEYIR_3 Time 3 ==================================>
# pxt*NEH = 0.019200000000000002 real_NEH= 29 ratio = 0.0006620689655172415
#
# vals 0.04141310127138592
#
#  _VAMSHFEPSEYIR_3 Time 6 ==================================>
# pxt*NEH = 0.117 real_NEH= 29 ratio = 0.0040344827586206895
#
# vals 0.09726711161328518
#
#  _VAMSHFEPSEYIR_3 Time 7 ==================================>
# pxt*NEH = 0.1184 real_NEH= 29 ratio = 0.004082758620689656
#
# vals 0.11445395809731777
#
#  _VAMSHFEPSEYIR_3 Time 9 ==================================>
# pxt*NEH = 0.162 real_NEH= 29 ratio = 0.005586206896551724
#
# vals 0.11721321352212594
#
#  _VAMSHFEPSEYIR_3 Time 13 ==================================>
# pxt*NEH = 0.255 real_NEH= 29 ratio = 0.008793103448275863
#
# vals 0.20762151824625286
#
#  _VAMSHFEPSEYIR_3 Time 16 ==================================>
# pxt*NEH = 0.37079999999999996 real_NEH= 29 ratio = 0.012786206896551723
#
# vals 0.2578640802543953
#
#  _VAMSHFEPSEYIR_3 Time 21 ==================================>
# pxt*NEH = 0.405600104 real_NEH= 29 ratio = 0.013986210482758622
#
# vals 0.3143922047565051
#
#  _VAMSHFEPSEYIR_3 Time 24 ==================================>
# pxt*NEH = 0.483 real_NEH= 29 ratio = 0.016655172413793103
#
# vals 0.3623985751414479
#
#  _VAMSHFEPSEYIR_3 Time 31 ==================================>
# pxt*NEH = 0.611999694 real_NEH= 29 ratio = 0.02110343772413793
#
# vals 0.48238131330829753
#
#  [0.003, 0.0068, 0.019200000000000002, 0.117, 0.1184, 0.162, 0.255, 0.37079999999999996, 0.405600104, 0.483, 0.611999694]
# ************** RMSE= 0.0003075009097476616 R square= 0.999997618772489
# [0.003, 0.0075, 0.0195, 0.11699999999999999, 0.11850000000000001, 0.162, 0.255, 0.3705, 0.40499999999999997, 0.483, 0.6120000000000001]
#
#  estimated NEH 15
# True NEH = 29 	 estimated NEHs median 15
# ===============================================================
#
# ===============================================================
#
# ===============================================================
#
#
#  _WDGKDLEDLQILIK_3 Time 1 ==================================>
# pxt*NEH = 0.003 real_NEH= 20 ratio = 0.00015000000000000001
#
# vals -0.030126759995341465
#
#  _WDGKDLEDLQILIK_3 Time 2 ==================================>
# pxt*NEH = 0.04380017 real_NEH= 20 ratio = 0.0021900085
#
# vals 0.047689459795075086
#
#  _WDGKDLEDLQILIK_3 Time 3 ==================================>
# pxt*NEH = 0.0352 real_NEH= 20 ratio = 0.00176
#
# vals -0.024450421462196364
#
#  _WDGKDLEDLQILIK_3 Time 6 ==================================>
# pxt*NEH = 0.108 real_NEH= 20 ratio = 0.0054
#
# vals 0.036932951693365974
#
#  _WDGKDLEDLQILIK_3 Time 7 ==================================>
# pxt*NEH = 0.099 real_NEH= 20 ratio = 0.00495
#
# vals 0.019387510668553192
#
#  _WDGKDLEDLQILIK_3 Time 9 ==================================>
# pxt*NEH = 0.156 real_NEH= 20 ratio = 0.0078
#
# vals 0.052325429978005926
#
#  _WDGKDLEDLQILIK_3 Time 13 ==================================>
# pxt*NEH = 0.28200000000000003 real_NEH= 20 ratio = 0.014100000000000001
#
# vals 0.1816345122581281
#
#  _WDGKDLEDLQILIK_3 Time 16 ==================================>
# pxt*NEH = 0.34500000000000003 real_NEH= 20 ratio = 0.01725
#
# vals 0.22632508636226087
#
#  _WDGKDLEDLQILIK_3 Time 21 ==================================>
# pxt*NEH = 0.3978 real_NEH= 20 ratio = 0.019889999999999998
#
# vals 0.21773232542205911
#
#  _WDGKDLEDLQILIK_3 Time 24 ==================================>
# pxt*NEH = 0.48380000000000006 real_NEH= 20 ratio = 0.024190000000000003
#
# vals 0.3294247294133262
#
#  _WDGKDLEDLQILIK_3 Time 31 ==================================>
# pxt*NEH = 0.606899881 real_NEH= 20 ratio = 0.03034499405
#
# vals 0.4314869155386304
#
#  [0.003, 0.04380017, 0.0352, 0.108, 0.099, 0.156, 0.28200000000000003, 0.34500000000000003, 0.3978, 0.48380000000000006, 0.606899881]
# ************** RMSE= 0.0002558251610095293 R square= 0.9999982532209993
# [0.0026000000000000003, 0.044199999999999996, 0.0351, 0.1079, 0.0988, 0.156, 0.2821, 0.3445, 0.3978, 0.4836, 0.6071]
#
#  estimated NEH 13
# True NEH = 20 	 estimated NEHs median 13
# ===============================================================
#
# ===============================================================
#
# ===============================================================

# %%
res=pd.DataFrame(vals,columns=["Peptieds","True NEH","Estimated NEH"])
res["diff"]=abs(res["True NEH"]-res["Estimated NEH"])
res.sort_values(by="diff")
# Out:
#                Peptieds  True NEH  Estimated NEH  diff
# 3        _FNPETDFLTGK_2        14             10     4
# 6      _LQLLEPFDKWDGK_3        19             15     4
# 11    _WDGKDLEDLQILIK_3        20             13     7
# 0     _cTTDHISAAGPWLK_3        24             15     9
# 7    _SDFDPGQDTYQHPPK_3        30             18    12
# 8      _SQFTITPGSEQIR_2        27             14    13
# 9      _VAMSHFEPSEYIR_2        29             15    14
# 10     _VAMSHFEPSEYIR_3        29             15    14
# 2      _FKLEAPDADELPR_3        30             15    15
# 1   _DINQEVYNFLATAGAK_3        31             15    16
# 5   _IVYGHLDDPANQEIER_3        36             18    18
# 4   _IVYGHLDDPANQEIER_2        36             17    19

# %%
print( float(res[["diff"]].mean()),float(res[["diff"]].median()),float(res[["diff"]].std()))
# Out:
# 12.083333333333334 13.5 5.053501636279421

# %%
temp_kk
# Out:
# [[0.015,
#   0.0352,
#   0.066,
#   0.124,
#   0.138,
#   0.189,
#   0.243,
#   0.32,
#   0.372400098,
#   0.42419999999999997,
#   0.5399997999999999],
#  [0.003,
#   0.003,
#   0.0132,
#   0.1147,
#   0.111,
#   0.189,
#   0.28200000000000003,
#   0.37120000000000003,
#   0.456300117,
#   0.5474,
#   0.7020996429999999],
#  [0.003,
#   0.019799999999999998,
#   0.054400000000000004,
#   0.135,
#   0.1457,
#   0.201,
#   0.297,
#   0.395200104,
#   0.4452,
#   0.5617997880000001,
#   0.720999588],
#  [0.003,
#   0.003,
#   0.008000002,
#   0.054,
#   0.0608,
#   0.117,
#   0.138,
#   0.192,
#   0.21389999999999998,
#   0.2666,
#   0.331500085],
#  [0.003,
#   0.0341,
#   0.024,
#   0.111,
#   0.14100000000000001,
#   0.228,
#   0.34800000000000003,
#   0.452200119,
#   0.5474,
#   0.630699762,
#   0.84679942],
#  [0.024,
#   0.039599999999999996,
#   0.055799999999999995,
#   0.138,
#   0.171,
#   0.216,
#   0.3744,
#   0.46020011800000005,
#   0.5236000000000001,
#   0.6425997619999999,
#   0.893199304],
#  [0.003,
#   0.005899997,
#   0.015200004,
#   0.093,
#   0.093,
#   0.1271,
#   0.228,
#   0.303,
#   0.3696,
#   0.4104,
#   0.535799886],
#  [0.01119999,
#   0.03890008,
#   0.054,
#   0.126,
#   0.1488,
#   0.189,
#   0.315,
#   0.44099999999999995,
#   0.4876,
#   0.593599788,
#   0.770399465],
#  [0.0128,
#   0.0434,
#   0.0465,
#   0.099,
#   0.1178,
#   0.165,
#   0.252,
#   0.3193,
#   0.383800101,
#   0.484099897,
#   0.611999694],
#  [0.003,
#   0.003,
#   0.0372,
#   0.096,
#   0.1271,
#   0.177,
#   0.252,
#   0.32239999999999996,
#   0.41600010400000004,
#   0.4576,
#   0.5984997900000001],
#  [0.003,
#   0.0068,
#   0.019200000000000002,
#   0.117,
#   0.1184,
#   0.162,
#   0.255,
#   0.37079999999999996,
#   0.405600104,
#   0.483,
#   0.611999694],
#  [0.003,
#   0.04380017,
#   0.0352,
#   0.108,
#   0.099,
#   0.156,
#   0.28200000000000003,
#   0.34500000000000003,
#   0.3978,
#   0.48380000000000006,
#   0.606899881]]

# %%
temp_neh
# Out:
# [24, 31, 30, 14, 36, 36, 19, 30, 27, 29, 29, 20]

# %%
# data=pd.read_csv("C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_AAMLGQEDPPQHGLPR_3_24_FAS_MOUSE.csv")
data=pd.read_csv("C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug/_DPETLLGYSMVGcQR_2_24_FAS_MOUSE.csv")
# data=pd.read_csv("data/_DTSFEQHVLLHTGGK_3_21_FAS_MOUSE.csv")
data.head()

# %%
ph

# %%
# data["const"]=data.NEH*data.pxt
# data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
# data["new_neh"]=data.const/data.new_pxt
# data=data.sort_values(by="RMSE",ascending=True)
# data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]

# # data["temp"]= (data.new_neh*data.new_pxt)/( (1-ph)*(1-ph-data.new_pxt) )
# # data["temp2"]=(data["exp_t_A1/A0"]-data["theo_A1/A0"])

# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
# data.head(290)

# %%
data["const"]=data.NEH*data.pxt
data["new_pxt"]=1-ph- (data.const/( (1-ph)*(data["exp_t_A1/A0"]-data["theo_A1/A0"]) ) )
data["new_neh"]=data.const/data.new_pxt
data=data.sort_values(by=["RMSE"],ascending=True)

data["test"]= 1-ph-data.pxt == (data.NEH*data.pxt)/( (1-ph)*(data["exp_t_A1/A0"]-data["exp_A1/A0"]) )

data=data[(data.new_pxt>0) & (data.new_neh>0) & (data.new_neh<118)]



# data["h1"]=data.NEH*data.pxt
# data["h2"]=data.new_neh*data.new_pxt
data.head(20)

# %%
# np.dot(data[["NEH","pxt"]][318],data[["new_pxt","new_neh"]][318])/(norm(data[["NEH","pxt"]][318])*norm(data[["new_pxt","new_neh"]][318]))

from sklearn.decomposition import PCA

pca = PCA() # Compute PCA
pca.fit_transform(  data[["const","RMSE"]])
eigenvalues = pca.explained_variance_ # Get eigenvalues
eigenvalues = np.round(eigenvalues, 8) # Round off eigenvalues
eigenvalues

# %%
from matplotlib import pyplot as plt
# plt.figure(figsize=(15,6))
plt.scatter(data.const,data.RMSE,s=1)
print(data[data.new_pxt<0].shape)

# %%
tempdata=data[data.RMSE<2*min(data.RMSE)]
tempdata=tempdata[(tempdata.new_pxt>0) & (tempdata.new_neh>0) & (tempdata.new_neh<data.NH[0])]
tempdata["pxt_dif"]=(abs((tempdata.pxt) - (tempdata.new_pxt))) #(abs((tempdata.pxt) - (tempdata.new_pxt)))**2 + (abs((tempdata.NEH) - (tempdata.new_neh)))**2 
tempdata.sort_values(by=["pxt_dif"]).head(25)

# %%
plt.figure(figsize=(15,6))
plt.scatter(tempdata.const,tempdata.RMSE,s=1)

# %%
np.array(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5))

# %%
np.median(tempdata.sort_values(by=["pxt_dif"]).new_neh.head(5))

# %%
# plt.scatter(range(0,6),[3.94E+06,6.30E+06,8.23E+06,6.51E+06,3.99E+06,3.33E+06])

# %%
# plt.scatter(range(0,6),[4.77E+07,9.92E+07,1.11E+08,9.49E+07,5.45E+07,2.81E+07])

# %%
np.array([0.2475, 0.47250000000000003, 0.345, 1.3425, 0.9825, 1.2075, 1.0725, 1.1925000000000001, 1.1775, 1.1175, 1.335])/75

# %%
np.array([[0.16119999999999998, 0.3952, 0.41340000000000005, 0.9229999999999999, 0.9776, 0.9672, 1.0842, 1.183, 1.0608, 1.1258, 1.0972]])/26
